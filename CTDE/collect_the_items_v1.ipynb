# %% [markdown]
# # Item Collection

# %% [markdown]
# ## Environment definition

# %%
from typing import Set
from ray.rllib.env.multi_agent_env import MultiAgentEnv
import random as rnd
import math
from gymnasium.spaces import Discrete, Box, Sequence, Tuple
import numpy as np
from IPython.display import clear_output
from gymnasium.spaces.utils import flatten_space, flatten

from ray.rllib.utils.typing import AgentID

class EnvironmentConfiguration():
    def __init__(self, width, height, n_agents, n_items, max_steps=None):
        self.width = width
        self.height = height
        self.n_agents = n_agents
        self.n_items = n_items
        self.max_steps = max_steps

class ItemCollectionEnv(MultiAgentEnv):

    actions_encoding = ["UP","DOWN","RIGHT","LEFT"]
    actions_dict = [(0,-1),(0,1),(1,0),(-1,0)]

    def __init__(self, config: EnvironmentConfiguration):
        self.width = config.width
        self.height = config.height
        self.n_agents = config.n_agents
        self.n_items = config.n_items
        self.max_steps = config.max_steps
        self.original_observation_space = Tuple((
            Box(low=0, high=1, shape=(self.width, self.height), dtype=np.bool_), # agent
            Box(low=0, high=1, shape=(self.width, self.height), dtype=np.bool_), # other agents
            Box(low=0, high=1, shape=(self.width, self.height), dtype=np.bool_)  # items
        ))
        self.observation_space = self.observation_space('agent-0')
        self.action_space = self.action_space('agent-0')
        

        self.agents = ['agent-' + str(i) for i in range(self.n_agents)]

    def observation_space(self, agent):
        #coordinates_space = Box(low=np.array([0, 0]), high=np.array([self.width-1, self.height-1]), dtype=np.int32)
        return flatten_space(self.original_observation_space)

    def action_space(self, agent):
        return Discrete(len(self.actions_dict))

    def __get_random_point(self):
        return (rnd.randint(0, self.width-1), rnd.randint(0, self.height-1))
    
    def __get_observation(self, agent):
        myPosition = np.zeros((self.width, self.height), np.bool_)
        otherAgentsPositions = np.zeros((self.width, self.height), np.bool_)
        itemsPositions = np.zeros((self.width, self.height), np.bool_)
        myPosition[self.agent_pos[agent][0], self.agent_pos[agent][1]] = True
        for other_agent, position in self.agent_pos.items():
            if other_agent != agent:
                otherAgentsPositions[position[0], position[1]] = True
        for position in self.item_pos:
            itemsPositions[position[0], position[1]] = True

        return flatten(self.original_observation_space, (myPosition, otherAgentsPositions, itemsPositions))
        return (np.array(self.agent_pos[agent], dtype=np.int32),
                np.array([self.agent_pos[a] for a in self.agents if a != agent], dtype=np.int32),
                np.array(self.item_pos, dtype=np.int32))

    def __get_reward(self, agent):
        return -0.5 + self.__get_global_reward()
        """
        if self.agent_pos[agent] in self.item_pos:
            return 10/self.agent_pos.count(self.agent_pos[agent])
        else:
            return -1
        """
    
    def __get_global_reward(self):
        return (len((self.item_pos)) - len(set(self.item_pos) - set(self.agent_pos.values()))) * 10
    
    def __update_agent_position(self, agent, x, y):
        self.agent_pos[agent] = (max(min(self.agent_pos[agent][0] + x, self.width-1), 0),
                                 max(min(self.agent_pos[agent][1] + y, self.height-1), 0))

    def reset(self, seed=None, options=None):
        self.agent_pos = {agent: self.__get_random_point() for agent in self.agents}
        self.item_pos = [self.__get_random_point() for _ in range(self.n_items)]
        self.steps = 0;
        return {agent: self.__get_observation(agent) for agent in self.agents}, {}
     
    def step(self, actions):
        self.steps += 1
        observations, rewards, terminated, truncated, infos = {}, {}, {}, {}, {}

        for agent, action in actions.items():
            self.__update_agent_position(agent, self.actions_dict[action][0], self.actions_dict[action][1])

        for agent in actions.keys():
            observations[agent] = self.__get_observation(agent)
            rewards[agent] = self.__get_reward(agent)
            terminated[agent] = False
            truncated[agent] = False
            infos[agent] = {}
        
        self.item_pos = list(set(self.item_pos) - set(self.agent_pos.values()))

        terminated['__all__'] = len(self.item_pos) == 0
        if self.max_steps != None and self.steps == self.max_steps and not terminated['__all__']:
            truncated['__all__'] = True
        else:
            truncated['__all__'] = False

        return observations, rewards, terminated, truncated, infos
     
    def render(self, mode='text'):
        str = '_' * (self.width+2) + '\n'
        for i in range(self.height):
            str = str + "|"
            for j in range(self.width):
                if (j,i) in self.agent_pos.values():
                    str = str + 'o'
                elif (j,i) in self.item_pos:
                    str = str + 'x'
                else:
                    str = str + ' '
            str = str + '|\n'
        str = str + '‾' * (self.width+2)
        print(str)

    def get_agent_ids(self):
       return self.agents
    
env = ItemCollectionEnv(EnvironmentConfiguration(width=50, height=10, n_agents=2, n_items=10))
print(env.reset()[0]['agent-1'])
env.render()
# Out:
# [False False False ... False False False]
# ____________________________________________________
# |                          x        x              |
# |                                            x     |
# |      x     x                      o              |
# |                      x              x            |
# |                         x                        |
# |                                      x           |
# |                                                  |
# |                                              x   |
# |                                                  |
# |                                                o |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾

# %%
import ray
ray.shutdown()
ray.init()
# Out:
# 2024-05-15 15:42:11,853	INFO worker.py:1740 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.11.9', ray_version='2.21.0', ray_commit='a912be84d6944bc32cfe84a9a3fe0b0227574536')

# %% [markdown]
# ## Single Agent

# %%
from ray.rllib.algorithms.ppo import PPOConfig
from ray.tune.logger import pretty_print
from ray.tune.registry import register_env
from gymnasium.wrappers.time_limit import TimeLimit


register_env("my_env", lambda _: ItemCollectionEnv(EnvironmentConfiguration(width=10, height=10, n_agents=1, n_items=1, max_steps=30)))

algo = (
    PPOConfig()
    .training(gamma=0.99, lr=0.001, kl_coeff=0.5, train_batch_size=4096, sgd_minibatch_size=256, num_sgd_iter=10)
    .env_runners(num_env_runners=1)
    .resources(num_gpus=0)
    .environment(env="my_env")
    .build()
)

for i in range(20):
    result = algo.train()
    print(result["sampler_results"])
    #print(result["info"]["learner"]["default_policy"]["learner_stats"]["total_loss"])
    print(f"[{i}]")
    if i % 5 == 0:
        checkpoint_dir = algo.save().checkpoint.path
        print(f"Checkpoint saved in directory {checkpoint_dir}")
# Out:
# 2024-05-15 15:49:51,242	WARNING deprecation.py:50 -- DeprecationWarning: `WorkerSet(num_workers=... OR local_worker=...)` has been deprecated. Use `EnvRunnerGroup(num_env_runners=... AND local_env_runner=...)` instead. This will raise an error in the future!
# (raylet) [2024-05-15 15:50:11,822 E 17720 17720] (raylet) node_manager.cc:3002: 17 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 15:51:11,823 E 17720 17720] (raylet) node_manager.cc:3002: 33 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 15:52:11,830 E 17720 17720] (raylet) node_manager.cc:3002: 33 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 15:53:11,837 E 17720 17720] (raylet) node_manager.cc:3002: 46 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 15:54:11,843 E 17720 17720] (raylet) node_manager.cc:3002: 43 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 15:55:11,849 E 17720 17720] (raylet) node_manager.cc:3002: 20 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 15:56:11,856 E 17720 17720] (raylet) node_manager.cc:3002: 46 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 15:57:11,863 E 17720 17720] (raylet) node_manager.cc:3002: 34 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 15:58:11,869 E 17720 17720] (raylet) node_manager.cc:3002: 30 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 15:59:11,880 E 17720 17720] (raylet) node_manager.cc:3002: 40 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:00:11,884 E 17720 17720] (raylet) node_manager.cc:3002: 41 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:01:11,885 E 17720 17720] (raylet) node_manager.cc:3002: 45 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:02:11,886 E 17720 17720] (raylet) node_manager.cc:3002: 25 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:03:11,888 E 17720 17720] (raylet) node_manager.cc:3002: 52 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:04:11,891 E 17720 17720] (raylet) node_manager.cc:3002: 85 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:05:11,897 E 17720 17720] (raylet) node_manager.cc:3002: 43 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:06:11,903 E 17720 17720] (raylet) node_manager.cc:3002: 32 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:07:11,907 E 17720 17720] (raylet) node_manager.cc:3002: 13 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:08:11,917 E 17720 17720] (raylet) node_manager.cc:3002: 33 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:09:11,918 E 17720 17720] (raylet) node_manager.cc:3002: 35 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:11:11,948 E 17720 17720] (raylet) node_manager.cc:3002: 13 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:12:11,949 E 17720 17720] (raylet) node_manager.cc:3002: 12 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:13:11,953 E 17720 17720] (raylet) node_manager.cc:3002: 100 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:14:11,956 E 17720 17720] (raylet) node_manager.cc:3002: 40 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:15:11,957 E 17720 17720] (raylet) node_manager.cc:3002: 36 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:16:11,966 E 17720 17720] (raylet) node_manager.cc:3002: 68 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:17:11,976 E 17720 17720] (raylet) node_manager.cc:3002: 40 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:18:11,979 E 17720 17720] (raylet) node_manager.cc:3002: 72 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-05-15 16:19:11,984 E 17720 17720] (raylet) node_manager.cc:3002: 58 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 5577bdd9e19e4822eb7190edbd5fdec7a5e58167cd6cf69f465a8ec5, IP: 172.18.183.133) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.18.183.133`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 15
#       4 from gymnasium.wrappers.time_limit import TimeLimit
#       7 register_env("my_env", lambda _: ItemCollectionEnv(EnvironmentConfiguration(width=10, height=10, n_agents=1, n_items=1, max_steps=30)))
#       9 algo = (
#      10     PPOConfig()
#      11     .training(gamma=0.99, lr=0.001, kl_coeff=0.5, train_batch_size=4096, sgd_minibatch_size=256, num_sgd_iter=10)
#      12     .env_runners(num_env_runners=1)
#      13     .resources(num_gpus=0)
#      14     .environment(env="my_env")
# ---> 15     .build()
#      16 )
#      18 for i in range(20):
#      19     result = algo.train()
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm_config.py:859, in AlgorithmConfig.build(self, env, logger_creator, use_copy)
#     856 if isinstance(self.algo_class, str):
#     857     algo_class = get_trainable_cls(self.algo_class)
# --> 859 return algo_class(
#     860     config=self if not use_copy else copy.deepcopy(self),
#     861     logger_creator=self.logger_creator,
#     862 )
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:554, in Algorithm.__init__(self, config, env, logger_creator, **kwargs)
#     536 # Initialize common evaluation_metrics to nan, before they become
#     537 # available. We want to make sure the metrics are always present
#     538 # (although their values may be nan), so that Tune does not complain
#     539 # when we use these as stopping criteria.
#     540 self.evaluation_metrics = {
#     541     # TODO: Don't dump sampler results into top-level.
#     542     "evaluation": {
#    (...)
#     551     },
#     552 }
# --> 554 super().__init__(
#     555     config=config,
#     556     logger_creator=logger_creator,
#     557     **kwargs,
#     558 )
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/tune/trainable/trainable.py:158, in Trainable.__init__(self, config, logger_creator, storage)
#     154     logger.debug(f"StorageContext on the TRAINABLE:\n{storage}")
#     156 self._open_logfiles(stdout_file, stderr_file)
# --> 158 self.setup(copy.deepcopy(self.config))
#     159 setup_time = time.time() - self._start_time
#     160 if setup_time > SETUP_TIME_THRESHOLD:
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:640, in Algorithm.setup(self, config)
#     637     self.config.off_policy_estimation_methods = ope_dict
#     639 # Create a set of env runner actors via a EnvRunnerGroup.
# --> 640 self.workers = EnvRunnerGroup(
#     641     env_creator=self.env_creator,
#     642     validate_env=self.validate_env,
#     643     default_policy_class=self.get_default_policy_class(self.config),
#     644     config=self.config,
#     645     num_workers=self.config.num_env_runners,
#     646     local_worker=True,
#     647     logdir=self.logdir,
#     648 )
#     650 # Ensure remote workers are initially in sync with the local worker.
#     651 self.workers.sync_weights(inference_only=True)
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/rllib/env/env_runner_group.py:169, in EnvRunnerGroup.__init__(self, env_creator, validate_env, default_policy_class, config, num_env_runners, local_env_runner, logdir, _setup, num_workers, local_worker)
#     167 if _setup:
#     168     try:
# --> 169         self._setup(
#     170             validate_env=validate_env,
#     171             config=config,
#     172             num_env_runners=num_env_runners,
#     173             local_env_runner=local_env_runner,
#     174         )
#     175     # EnvRunnerGroup creation possibly fails, if some (remote) workers cannot
#     176     # be initialized properly (due to some errors in the EnvRunners's
#     177     # constructor).
#     178     except RayActorError as e:
#     179         # In case of an actor (remote worker) init failure, the remote worker
#     180         # may still exist and will be accessible, however, e.g. calling
#     181         # its `sample.remote()` would result in strange "property not found"
#     182         # errors.
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/rllib/env/env_runner_group.py:239, in EnvRunnerGroup._setup(self, validate_env, config, num_env_runners, local_env_runner)
#     236     self._ds_shards = None
#     238 # Create a number of @ray.remote workers.
# --> 239 self.add_workers(
#     240     num_env_runners,
#     241     validate=config.validate_env_runners_after_construction,
#     242 )
#     244 # If num_workers > 0 and we don't have an env on the local worker,
#     245 # get the observation- and action spaces for each policy from
#     246 # the first remote worker (which does have an env).
#     247 if (
#     248     local_env_runner
#     249     and self._worker_manager.num_actors() > 0
#    (...)
#     252     and (not config.observation_space or not config.action_space)
#     253 ):
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/rllib/env/env_runner_group.py:748, in EnvRunnerGroup.add_workers(self, num_workers, validate)
#     745 # Validate here, whether all remote workers have been constructed properly
#     746 # and are "up and running". Establish initial states.
#     747 if validate:
# --> 748     for result in self._worker_manager.foreach_actor(
#     749         lambda w: w.assert_healthy()
#     750     ):
#     751         # Simiply raise the error, which will get handled by the try-except
#     752         # clause around the _setup().
#     753         if not result.ok:
#     754             raise result.get()
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/rllib/utils/actor_manager.py:622, in FaultTolerantActorManager.foreach_actor(self, func, healthy_only, remote_actor_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     616 remote_calls = self._call_actors(
#     617     func=func,
#     618     remote_actor_ids=remote_actor_ids,
#     619 )
#     621 # Collect remote request results (if available given timeout and/or errors).
# --> 622 _, remote_results = self._fetch_result(
#     623     remote_actor_ids=remote_actor_ids,
#     624     remote_calls=remote_calls,
#     625     tags=[None] * len(remote_calls),
#     626     timeout_seconds=timeout_seconds,
#     627     return_obj_refs=return_obj_refs,
#     628     mark_healthy=mark_healthy,
#     629 )
#     631 return remote_results
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/rllib/utils/actor_manager.py:476, in FaultTolerantActorManager._fetch_result(self, remote_actor_ids, remote_calls, tags, timeout_seconds, return_obj_refs, mark_healthy)
#     473 if not remote_calls:
#     474     return [], RemoteCallResults()
# --> 476 ready, _ = ray.wait(
#     477     remote_calls,
#     478     num_returns=len(remote_calls),
#     479     timeout=timeout,
#     480     # Make sure remote results are fetched locally in parallel.
#     481     fetch_local=not return_obj_refs,
#     482 )
#     484 # Remote data should already be fetched to local object store at this point.
#     485 remote_results = RemoteCallResults()
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/_private/auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/_private/worker.py:2854, in wait(ray_waitables, num_returns, timeout, fetch_local)
#    2852 timeout = timeout if timeout is not None else 10**6
#    2853 timeout_milliseconds = int(timeout * 1000)
# -> 2854 ready_ids, remaining_ids = worker.core_worker.wait(
#    2855     ray_waitables,
#    2856     num_returns,
#    2857     timeout_milliseconds,
#    2858     worker.current_task_id,
#    2859     fetch_local,
#    2860 )
#    2861 return ready_ids, remaining_ids
#
# File python/ray/_raylet.pyx:3812, in ray._raylet.CoreWorker.wait()
#
# File python/ray/_raylet.pyx:571, in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %%
from IPython.display import clear_output
import time
import torch
from gymnasium.spaces.utils import flatdim

env = ItemCollectionEnv(EnvironmentConfiguration(width=50, height=10, n_agents=3, n_items=10, max_steps=100))
obs, _ = env.reset()
env.render()

for i in range(100):
    actions = algo.compute_actions(obs)
    print(actions, "\n")
    
    obs, reward, terminated, truncated, info = env.step(actions)
    clear_output()
    print(f"[{i}]")
    env.render()
    print(obs)
    print(reward)
    time.sleep(0.5)

    if terminated['__all__'] or truncated['__all__']:
        break
# Out:
# [30]
# ____________________________________________________
# |            x                                     |
# |                          x                       |
# |                                                  |
# |                              x           x       |
# |                                     x            |
# |                     o                            |
# |                              x               x   |
# |                    o    x                 o      |
# |                          x                       |
# |                                            x     |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# {'agent-0': array([False, False, False, ..., False, False, False]), 'agent-1': array([False, False, False, ..., False, False, False]), 'agent-2': array([False, False, False, ..., False, False, False])}
# {'agent-0': -0.5, 'agent-1': -0.5, 'agent-2': -0.5}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 20
#      18 print(obs)
#      19 print(reward)
# ---> 20 time.sleep(0.5)
#      22 if terminated['__all__'] or truncated['__all__']:
#      23     break
#
# KeyboardInterrupt:
