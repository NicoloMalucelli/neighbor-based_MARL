# %% [markdown]
# ## Ring Formation

# %% [markdown]
# ### utils

# %%
from utils.vectors import Vector2D
from utils.canvas import CanvasWithBorders
from utils.algo_utils import (save_algo, load_algo)
from utils.simulations import (simulate_episode, simulate_random_episode, ppo_result_format, sac_result_format)

# %% [markdown]
# ### environment

# %%
from typing import Set
from ray.rllib.env.multi_agent_env import MultiAgentEnv
import random as rnd
from gymnasium.spaces import Discrete, Box, Dict, Tuple, MultiDiscrete
from gymnasium.spaces.utils import flatten, flatten_space
import numpy as np
from IPython.display import clear_output
import math
from ipycanvas import Canvas, hold_canvas
from enum import Enum

class EnvironmentConfiguration: 
    def __init__(self, slave_agents, ring_radius, spawn_area=100, max_steps=None, cache_size=1):
        # parameters that shouldn't affect the agents' behaviour
        self.spawn_area = spawn_area
        self.max_steps = max_steps
        # parameters that affect the agents' behavious
        self.ring_radius = ring_radius
        # parameters that affect the observation space
        self.slave_agents = slave_agents
        self.cache_size = cache_size

class RingFormation(MultiAgentEnv):
    canvas = None
    CANVAS_WIDTH, CANVAS_HEIGHT = 300.0, 300.0

    Task = Enum('Task', ['DISTANCE_FROM_CENTER', 'DISTANCE_FROM_NEIGHBOURS'])

    def __init__(self, config: EnvironmentConfiguration):
        assert config.slave_agents >= 3
        
        self.current_task = self.Task.DISTANCE_FROM_CENTER

        # parameters that shouldn't affect the agents' behaviour
        self.spawn_area = config.spawn_area
        self.max_steps = config.max_steps
        # parameters that affect the agents' behavious
        self.ring_radius = config.ring_radius
        # parameters that affect the observation space
        self.slave_agents = config.slave_agents
        self.cache_size = config.cache_size

        self.agent_ids = ['agent-' + str(i) for i in range(self.slave_agents)]
        self.agent_colors = {agent: self.rgb_to_hex(rnd.randint(0, 255), rnd.randint(0, 255), rnd.randint(0, 255)) for agent in self.agent_ids}


        #circumference = (2 * self.ring_radius * np.pi)
        self.ideal_distance = 2 * self.ring_radius * math.sin(np.pi/self.slave_agents) #circumference / self.slave_agents

        self.observation_space = self.observation_space('agent-0')
        self.action_space = self.action_space("")

    def unflatten_observation_space(self, agent):
        direction = Box(low=-1, high=1, shape=(2,1), dtype=np.float32)
        #direction = Box(low=-np.pi, high=np.pi, shape=(1,1), dtype=np.float32)
        distance = Box(low=-np.inf, high=np.inf, shape=(1,1), dtype=np.float32)

        time_t_obs = Dict({"prev": Dict({'direction': direction, 'distance': distance}),
                           "next": Dict({'direction': direction, 'distance': distance}),
                           "center": Dict({'direction': direction, 'distance': distance})})
        
        return Dict({f"t[-{t}]": time_t_obs for t in range(0, self.cache_size)})

    def observation_space(self, agent):
        return flatten_space(self.unflatten_observation_space(agent))

    def action_space(self, agent):
        direction = Box(low=-1.0, high=1.0, shape=(2,1), dtype=np.float32)
        #direction = Box(low=-np.pi, high=np.pi, shape=(1,1), dtype=np.float32)
        speed = Box(0.0, 1.0, dtype=np.float32)
        return flatten_space(Tuple([direction, speed]))
    
    def reset(self, seed=None, options=None):
        self.steps = 0
        self.agent_pos = {agent: Vector2D.get_random_point(max_x=self.spawn_area, max_y=self.spawn_area) for agent in self.agent_ids}
        self.agent_old_pos = dict(self.agent_pos)

        self.old_distance_from_nbrs = {agent: self.__get_distance_from_nbrs(agent) for agent in self.agent_ids}

        self.center_pos = Vector2D.sum(
            Vector2D.get_random_point(max_x=int(self.spawn_area * 2.0/3), max_y=int(self.spawn_area * 2.0/3)),
            Vector2D(self.spawn_area * 1.0/6, self.spawn_area * 1.0/6)
        )
        self.info = {agent: {} for agent in self.agent_ids}
        self.observation_cache = {agent: [] for agent in self.agent_ids}
        return {agent: self.__get_observation(agent) for agent in self.agent_ids}, {}

    def __update_agent_position(self, agent, action):
        #direction, speed = action
        #unit_movement = Vector2D.from_rad(direction)
        speed = action[2]
        unit_movement = Vector2D.unit_vector(Vector2D(action[0], action[1]))
        self.agent_old_pos[agent] = self.agent_pos[agent]
        self.agent_pos[agent] = Vector2D.sum(self.agent_pos[agent], Vector2D.mul(unit_movement, speed))

    def __get_time_t_observation(self, agent):
        prev_distance_vector = Vector2D.distance_vector(self.agent_pos[agent], self.agent_old_pos[self.__prev_agent(agent)])
        prev = {
            "direction": Vector2D.unit_vector(prev_distance_vector).to_np_array(), #math.atan2(prev_distance_vector.y, prev_distance_vector.x),
            "distance": np.log(1 + abs(Vector2D.norm(prev_distance_vector))) #1 - np.exp(-alpha * x)
        }

        next_distance_vector = Vector2D.distance_vector(self.agent_pos[agent], self.agent_old_pos[self.__next_agent(agent)])
        next = {
            "direction": Vector2D.unit_vector(next_distance_vector).to_np_array(), #math.atan2(next_distance_vector.y, next_distance_vector.x),
            "distance": np.log(1 + abs(Vector2D.norm(next_distance_vector))) #1 - np.exp(-alpha * x)
        }

        center_distance_vector = Vector2D.distance_vector(self.agent_pos[agent], self.center_pos)
        center = {
            "direction": Vector2D.unit_vector(center_distance_vector).to_np_array(), #math.atan2(center_distance_vector.y, center_distance_vector.x),
            "distance": np.log(1 + abs(Vector2D.norm(center_distance_vector))) #1 - np.exp(-alpha * x)
        }
    
        obs = {"prev": prev, "next": next, "center": center}
        return obs

    def __get_observation(self, agent):
        if len(self.observation_cache[agent]) == 0:
            self.observation_cache[agent] = [self.__get_time_t_observation(agent)]*self.cache_size
        else:
            self.observation_cache[agent] = [self.__get_time_t_observation(agent)] + self.observation_cache[agent]
            self.observation_cache[agent].pop()

        obs = {
            f"t[-{t}]": self.observation_cache[agent][t]
            for t in range(0, self.cache_size)
        }

        return flatten(self.unflatten_observation_space(agent), obs)

    def rgb_to_hex(self, r, g, b):
        return f'#{r:02x}{g:02x}{b:02x}'

    def __get_distance_from_nbrs(self, agent):
        return [Vector2D.distance(self.agent_pos[agent], self.agent_pos[nbr]) for nbr in [self.__prev_agent(agent), self.__next_agent(agent)]]

    def __get_local_reward(self, agent, action):
        
        old_distance_from_target = abs(Vector2D.distance(self.agent_old_pos[agent], self.center_pos) - self.ring_radius)
        distance_from_target = abs(Vector2D.distance(self.agent_pos[agent], self.center_pos) - self.ring_radius)  

        #reward 1: bonus if the agent moves toward the target, malus otherwise
        reward_1 = (old_distance_from_target - distance_from_target)

        self.info[agent]["distance_from_target"] = distance_from_target
        #reward 2: bonus if very close to the target
        reward_2 = max(20*(0.05-distance_from_target), 0) * 10
        #reward_2 = 10 if distance_from_target < 0.05 else 0
        #if reward_2 == 0:
        #    reward_2 = - np.log(1 + distance_from_target)
        
        #reward 3: collision malus
        #reward_3 = sum([-1 if Vector2D.distance(self.agent_pos[agent], self.agent_pos[nbr]) < 0.5 else 0 for nbr in self.__get_other_agents(agent)])

        #reward 4: penalize movement
        #reward_4 = -action[2]

        #reward 5: if the agent is not in the bonus target area it gets a malus
        reward_5 = -1 if reward_2 == 0 else 0 

        #reward 6: the agent is at the target distance
        reward_6 = 100 if distance_from_target <= 0.05 else 0
        
        # reward 7: distance improvement from prev and next
        distance_from_nbrs = self.__get_distance_from_nbrs(agent)
        #reward_7 = abs(np.mean(self.old_distance_from_nbrs[agent]) - self.ideal_distance) - abs(np.mean(distance_from_nbrs) - self.ideal_distance)
        reward_7 = -np.mean([abs(dst - self.ideal_distance) for dst in distance_from_nbrs])
        self.old_distance_from_nbrs[agent] = distance_from_nbrs

        # reward 8: very negative reward if not in position
        reward_8 = -100 if distance_from_target > 0.5 else 0

        # reward 9: penalize the agent if the old distance was optimal and the current is not
        reward_9 = -10 if old_distance_from_target <= 0.05 and distance_from_target > 0.05 else 0

        # update info
        self.info[agent]["steps_at_ideal_distance"] = reward_2 > 0

        if self.current_task == self.Task.DISTANCE_FROM_CENTER:
            return reward_1 + reward_2 #+ reward_9
        else:
            return reward_1 + reward_2 + reward_7

    def __get_global_reward(self):
        return 0
        #return self.global_reward * 100
    
    def __get_other_agents(self, agent):
        return [other for other in self.agent_ids if other != agent]

    def __prev_agent(self, agent):
        agent_id = int(agent.split("-")[1])
        return f"agent-{(agent_id-1) % self.slave_agents}"

    def __next_agent(self, agent):
        agent_id = int(agent.split("-")[1])
        return f"agent-{(agent_id+1) % self.slave_agents}"

    def step(self, actions):
        self.steps += 1
        observations, rewards, terminated, truncated, infos = {}, {}, {}, {}, {}

        for agent, action in actions.items():
            self.__update_agent_position(agent, action)

        for agent, action in actions.items():
            observations[agent] = self.__get_observation(agent)
            rewards[agent] = self.__get_local_reward(agent, action) + self.__get_global_reward()
            terminated[agent] = False
            truncated[agent] = False
            infos[agent] = self.info[agent]

        truncated['__all__'] = False
        if self.max_steps != None and self.steps == self.max_steps:
            terminated['__all__'] = True
            for agent in self.agent_ids:
                terminated[agent] = True
        else:
            terminated['__all__'] = False

        return observations, rewards, terminated, truncated, infos
     
    def rgb_to_hex(self, r, g, b):
        return f'#{r:02x}{g:02x}{b:02x}'

    def render(self):
        pass

    def get_agent_ids(self):
       return self.agents
    
    def set_task(self, task):
        self.current_task = task


class RenderableRingFormation(RingFormation):
    def render(self):
        if self.canvas is None:
            self.canvas = CanvasWithBorders(width=self.CANVAS_WIDTH, height=self.CANVAS_HEIGHT)
            display(self.canvas)
        
        with hold_canvas():
            unit = self.CANVAS_WIDTH/float(self.spawn_area)
            agent_render_size = max(unit,1)
            top_left, bottom_right = (0.0,0.0), (self.spawn_area, self.spawn_area)
            self.canvas.clear()

            raw_pos = self.center_pos.to_np_array()
            color = "red"
            
            agent_pos_in_frame = [((raw_pos[0]-top_left[0])/(bottom_right[0]-top_left[0]))*self.CANVAS_WIDTH,
                        ((raw_pos[1]-top_left[1])/(bottom_right[1]-top_left[1]))*self.CANVAS_HEIGHT,]

            self.canvas.fill_style = color
            self.canvas.fill_circle(
                agent_pos_in_frame[0],
                agent_pos_in_frame[1],
                agent_render_size/2.0
            )
            
            self.canvas.stroke_style = "black"
            self.canvas.stroke_circle(
                agent_pos_in_frame[0],
                agent_pos_in_frame[1],
                agent_render_size/2.0
            )

            self.canvas.stroke_style = "red"
            self.canvas.stroke_circle(
                agent_pos_in_frame[0],
                agent_pos_in_frame[1],
                self.ring_radius*unit
            )

            for agent in self.agent_ids:
                raw_pos = self.agent_pos[agent].to_np_array()
                color = self.agent_colors[agent]
                
                agent_pos_in_frame = [((raw_pos[0]-top_left[0])/(bottom_right[0]-top_left[0]))*self.CANVAS_WIDTH,
                            ((raw_pos[1]-top_left[1])/(bottom_right[1]-top_left[1]))*self.CANVAS_HEIGHT,]

                self.canvas.fill_style = color
                self.canvas.fill_circle(
                    agent_pos_in_frame[0],
                    agent_pos_in_frame[1],
                    agent_render_size/2.0
                )
                
                self.canvas.stroke_style = "black"
                self.canvas.stroke_circle(
                    agent_pos_in_frame[0],
                    agent_pos_in_frame[1],
                    agent_render_size/2.0
                )

# %%
from time import sleep
config = EnvironmentConfiguration(3, 10, 50)
env = RenderableRingFormation(config)
env.reset()

for i in range(0,50):
    obs, rew, _, _, info = env.step({"agent-0": [-1,-1,1]})
    #print(info["agent-0"])
    print(info["agent-0"]["distance_from_target"])
    print(rew, "\n")    
    env.render()
    sleep(0.1)
# Out:
# 20.17625392897625
# {'agent-0': 0.9828360591618583}
# CanvasWithBorders(height=300, width=300)
# 19.19458363264016
# {'agent-0': 0.981670296336091}
#
# 18.214200782237064
# {'agent-0': 0.980382850403096}
#
# 17.23524441009393
# {'agent-0': 0.9789563721431342}
#
# 16.25787406426344
# {'agent-0': 0.9773703458304901}
#
# 15.282273684775358
# {'agent-0': 0.9756003794880819}
#
# 14.30865637934459
# {'agent-0': 0.9736173054307677}
#
# 13.337270347369603
# {'agent-0': 0.971386031974987}
#
# 12.368406281257109
# {'agent-0': 0.968864066112495}
#
# 11.402406683841619
# {'agent-0': 0.9659995974154896}
#
# 10.439677692119176
# {'agent-0': 0.9627289917224431}
#
# 9.480704208392474
# {'agent-0': 0.9589734837267017}
#
# 8.526069436122874
# {'agent-0': 0.9546347722695998}
#
# 7.576480337348887
# {'agent-0': 0.9495890987739877}
#
# 6.632801127482345
# {'agent-0': 0.9436792098665414}
#
# 5.6960977839571285
# {'agent-0': 0.9367033435252168}
#
# 4.767697787424746
# {'agent-0': 0.9283999965323826}
#
# 3.8492711085412576
# {'agent-0': 0.9184266788834883}
#
# 2.942941031119684
# {'agent-0': 0.9063300774215737}
#
# 2.051437044278467
# {'agent-0': 0.8915039868412169}
#
# 1.1783069885100748
# {'agent-0': 0.8731300557683923}
#
# 0.32821182134347104
# {'agent-0': 4.285858740297183}
#
# 0.4926674759055132
# {'agent-0': -0.017805172672305858}
#
# 1.2760797790860874
# {'agent-0': -0.7834123031805742}
#
# 2.0109952861425553
# {'agent-0': -0.7349155070564679}
#
# 2.6827868272680293
# {'agent-0': -0.671791541125474}
#
# 3.272517490742316
# {'agent-0': -0.5897306634742865}
#
# 3.75688914005735
# {'agent-0': -0.48437164931503407}
#
# 4.10985182642239
# {'agent-0': -0.35296268636504013}
#
# 4.306911400314815
# {'agent-0': -0.19705957389242457}
#
# 4.331784222435494
# {'agent-0': -0.024872822120679317}
#
# 4.182261401695932
# {'agent-0': 0.1495228207395618}
#
# 3.8710935155312782
# {'agent-0': 0.31116788616465385}
#
# 3.421177385540135
# {'agent-0': 0.44991612999114317}
#
# 2.858689245685053
# {'agent-0': 0.5624881398550823}
#
# 2.2079699957674634
# {'agent-0': 0.6507192499175893}
#
# 1.4892336488406706
# {'agent-0': 0.7187363469267929}
#
# 0.7182676088355322
# {'agent-0': 0.7709660400051384}
#
# 0.09296628738833412
# {'agent-0': 8.765975573680516}
#
# 0.9355100830058802
# {'agent-0': -0.8425437956175461}
#
# 1.802660423509991
# {'agent-0': -0.8671503405041108}
#
# 2.689373718582603
# {'agent-0': -0.886713295072612}
#
# 3.5918217199542717
# {'agent-0': -0.9024480013716687}
#
# 4.507068275988312
# {'agent-0': -0.9152465560340399}
#
# 5.432836494350358
# {'agent-0': -0.9257682183620464}
#
# 6.367341096174361
# {'agent-0': -0.9345046018240026}
#
# 7.309167133507142
# {'agent-0': -0.9418260373327811}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[107], line 12
#      10 print(rew, "\n")
#      11 env.render()
# ---> 12 sleep(0.1)
#
# KeyboardInterrupt:

# %%
config = EnvironmentConfiguration(3, 10, 100)
env = RenderableRingFormation(config)
print(env.reset())
env.render()
#simulate_random_episode(env, 100, 0.03, print_info=False)
# Out:
# ({'agent-0': array([ 0.7677255 ,  0.6407788 ,  4.0278707 ,  0.99763036,  0.06880209,
#         3.4034908 ,  0.8849182 , -0.46574643,  3.1122217 ], dtype=float32), 'agent-1': array([ 0.37139067,  0.9284767 ,  3.6082413 , -0.6401844 , -0.76822126,
#         2.8106368 , -0.99763036, -0.06880209,  3.4034908 ], dtype=float32), 'agent-2': array([ 0.45764342,  0.88913584,  3.9509714 , -0.8849182 ,  0.46574643,
#         3.1122217 ,  0.6401844 ,  0.76822126,  2.8106368 ], dtype=float32)}, {})
# CanvasWithBorders(height=300, width=300)

# %% [markdown]
# ## Policy training

# %%
import ray
ray.shutdown()

# %% [markdown]
# ### 3 agents, PPO

# %%
from ray.tune.registry import register_env

config = EnvironmentConfiguration(3, 10, 50, max_steps=300, cache_size=2)
env = RingFormation(config)
register_env("ring_formation?agents=3&algo=PPO", lambda _: RingFormation(config))

# %%
from ray.rllib.algorithms.ppo import PPOConfig
from ray.tune.logger import pretty_print
from gymnasium.wrappers.time_limit import TimeLimit

trainin_steps = 50

algo = (
    PPOConfig()
    .training(gamma = 0.925, 
            lr = 0.0005,
            train_batch_size = 4096*2, 
            sgd_minibatch_size = 256, 
            num_sgd_iter = 30,
            #entropy_coeff=0.005,
    )
    #.env_runners(num_env_runners=4)
    .resources(num_gpus=0)
    .environment(env="ring_formation?agents=3&algo=PPO")
    #.callbacks(CustomMetricsCallback)
    .build()
)
clear_output()

out = ""
for i in range(trainin_steps):
    """
    if i == 30:
        out += "updating task to DISTANCE_FROM_NEIGHBOURS\n"
        algo.workers.foreach_worker(
            lambda ev: ev.foreach_env(
                lambda env: env.set_task(RingFormation.Task.DISTANCE_FROM_NEIGHBOURS)))
    """
    result = algo.train()
    clear_output()
    out += ppo_result_format(result) + "\n"
    print(out)
    simulate_episode(RenderableRingFormation(config), algo, 200, sleep_between_frames=0.03, print_reward=True, print_action=True)
# Out:
# iteration [1] => episode_reward_mean: 8.086963805695733, episode_len_mean: 300.0, agent_steps_trained: 24576, env_steps_trained: 8192, entropy: 4.208974745372931, learning_rate: 0.0005000000000000001
# iteration [2] => episode_reward_mean: 26.956670970055274, episode_len_mean: 300.0, agent_steps_trained: 49152, env_steps_trained: 16384, entropy: 4.1447681092553665, learning_rate: 0.0005000000000000001
# iteration [3] => episode_reward_mean: 38.74642361237552, episode_len_mean: 300.0, agent_steps_trained: 73728, env_steps_trained: 24576, entropy: 4.080778366492854, learning_rate: 0.0005000000000000001
# iteration [4] => episode_reward_mean: 51.17005199772458, episode_len_mean: 300.0, agent_steps_trained: 98304, env_steps_trained: 32768, entropy: 4.020288323362668, learning_rate: 0.0005000000000000001
# iteration [5] => episode_reward_mean: 77.09068909403591, episode_len_mean: 300.0, agent_steps_trained: 122880, env_steps_trained: 40960, entropy: 3.988818285614252, learning_rate: 0.0005000000000000001
# iteration [6] => episode_reward_mean: 96.19229973643449, episode_len_mean: 300.0, agent_steps_trained: 147456, env_steps_trained: 49152, entropy: 3.984878401458263, learning_rate: 0.0005000000000000001
# iteration [7] => episode_reward_mean: 116.75388230714438, episode_len_mean: 300.0, agent_steps_trained: 172032, env_steps_trained: 57344, entropy: 3.982775867316458, learning_rate: 0.0005000000000000001
# iteration [8] => episode_reward_mean: 125.7562229428584, episode_len_mean: 300.0, agent_steps_trained: 196608, env_steps_trained: 65536, entropy: 3.9786520167357393, learning_rate: 0.0005000000000000001
# iteration [9] => episode_reward_mean: 139.95903652795866, episode_len_mean: 300.0, agent_steps_trained: 221184, env_steps_trained: 73728, entropy: 3.9567721489402983, learning_rate: 0.0005000000000000001
# iteration [10] => episode_reward_mean: 154.2003819279303, episode_len_mean: 300.0, agent_steps_trained: 245760, env_steps_trained: 81920, entropy: 3.936810605062379, learning_rate: 0.0005000000000000001
# iteration [11] => episode_reward_mean: 168.83139864203326, episode_len_mean: 300.0, agent_steps_trained: 270336, env_steps_trained: 90112, entropy: 3.864705848114358, learning_rate: 0.0005000000000000001
# iteration [12] => episode_reward_mean: 174.2963221280962, episode_len_mean: 300.0, agent_steps_trained: 294912, env_steps_trained: 98304, entropy: 3.843781647251712, learning_rate: 0.0005000000000000001
# iteration [13] => episode_reward_mean: 177.10420842940866, episode_len_mean: 300.0, agent_steps_trained: 319488, env_steps_trained: 106496, entropy: 3.776807815415992, learning_rate: 0.0005000000000000001
# iteration [14] => episode_reward_mean: 178.99000645513047, episode_len_mean: 300.0, agent_steps_trained: 344064, env_steps_trained: 114688, entropy: 3.8118654910061096, learning_rate: 0.0005000000000000001
# iteration [15] => episode_reward_mean: 181.21534845596096, episode_len_mean: 300.0, agent_steps_trained: 368640, env_steps_trained: 122880, entropy: 3.806689347161187, learning_rate: 0.0005000000000000001
# iteration [16] => episode_reward_mean: 183.18666119625684, episode_len_mean: 300.0, agent_steps_trained: 393216, env_steps_trained: 131072, entropy: 3.70149710956547, learning_rate: 0.0005000000000000001
# iteration [17] => episode_reward_mean: 195.3382307130321, episode_len_mean: 300.0, agent_steps_trained: 417792, env_steps_trained: 139264, entropy: 3.717652699020174, learning_rate: 0.0005000000000000001
# iteration [18] => episode_reward_mean: 208.13108833272065, episode_len_mean: 300.0, agent_steps_trained: 442368, env_steps_trained: 147456, entropy: 3.586948410504394, learning_rate: 0.0005000000000000001
# iteration [19] => episode_reward_mean: 222.58188804833802, episode_len_mean: 300.0, agent_steps_trained: 466944, env_steps_trained: 155648, entropy: 3.5612802127169236, learning_rate: 0.0005000000000000001
# iteration [20] => episode_reward_mean: 234.02502532328802, episode_len_mean: 300.0, agent_steps_trained: 491520, env_steps_trained: 163840, entropy: 3.4695224510298837, learning_rate: 0.0005000000000000001
# iteration [21] => episode_reward_mean: 246.03385608157143, episode_len_mean: 300.0, agent_steps_trained: 516096, env_steps_trained: 172032, entropy: 3.470284444838762, learning_rate: 0.0005000000000000001
# iteration [22] => episode_reward_mean: 262.0728466786643, episode_len_mean: 300.0, agent_steps_trained: 540672, env_steps_trained: 180224, entropy: 3.303730067362388, learning_rate: 0.0005000000000000001
# iteration [23] => episode_reward_mean: 272.13243155947663, episode_len_mean: 300.0, agent_steps_trained: 565248, env_steps_trained: 188416, entropy: 3.3182969346642492, learning_rate: 0.0005000000000000001
# iteration [24] => episode_reward_mean: 278.7224685508168, episode_len_mean: 300.0, agent_steps_trained: 589824, env_steps_trained: 196608, entropy: 3.291240902410613, learning_rate: 0.0005000000000000001
# iteration [25] => episode_reward_mean: 282.8243457019698, episode_len_mean: 300.0, agent_steps_trained: 614400, env_steps_trained: 204800, entropy: 3.307535608112812, learning_rate: 0.0005000000000000001
# iteration [26] => episode_reward_mean: 287.5221306881056, episode_len_mean: 300.0, agent_steps_trained: 638976, env_steps_trained: 212992, entropy: 3.2990891815059715, learning_rate: 0.0005000000000000001
# iteration [27] => episode_reward_mean: 295.04633830585465, episode_len_mean: 300.0, agent_steps_trained: 663552, env_steps_trained: 221184, entropy: 3.2037858286665544, learning_rate: 0.0005000000000000001
# iteration [28] => episode_reward_mean: 309.07330690703805, episode_len_mean: 300.0, agent_steps_trained: 688128, env_steps_trained: 229376, entropy: 3.285088280505604, learning_rate: 0.0005000000000000001
# iteration [29] => episode_reward_mean: 313.327251160418, episode_len_mean: 300.0, agent_steps_trained: 712704, env_steps_trained: 237568, entropy: 3.094781910876433, learning_rate: 0.0005000000000000001
# iteration [30] => episode_reward_mean: 315.1882517402071, episode_len_mean: 300.0, agent_steps_trained: 737280, env_steps_trained: 245760, entropy: 3.0948417482276755, learning_rate: 0.0005000000000000001
# iteration [31] => episode_reward_mean: 319.4787584090135, episode_len_mean: 300.0, agent_steps_trained: 761856, env_steps_trained: 253952, entropy: 3.021793398509423, learning_rate: 0.0005000000000000001
# iteration [32] => episode_reward_mean: 319.3109071934879, episode_len_mean: 300.0, agent_steps_trained: 786432, env_steps_trained: 262144, entropy: 3.120587258040905, learning_rate: 0.0005000000000000001
# iteration [33] => episode_reward_mean: 337.09574692327965, episode_len_mean: 300.0, agent_steps_trained: 811008, env_steps_trained: 270336, entropy: 2.9717420257627962, learning_rate: 0.0005000000000000001
# iteration [34] => episode_reward_mean: 348.16345305515745, episode_len_mean: 300.0, agent_steps_trained: 835584, env_steps_trained: 278528, entropy: 2.9827188497616186, learning_rate: 0.0005000000000000001
# iteration [35] => episode_reward_mean: 367.0518377199613, episode_len_mean: 300.0, agent_steps_trained: 860160, env_steps_trained: 286720, entropy: 2.860050932152404, learning_rate: 0.0005000000000000001
# iteration [36] => episode_reward_mean: 373.4433052116235, episode_len_mean: 300.0, agent_steps_trained: 884736, env_steps_trained: 294912, entropy: 2.953558081140121, learning_rate: 0.0005000000000000001
# iteration [37] => episode_reward_mean: 389.45219480690236, episode_len_mean: 300.0, agent_steps_trained: 909312, env_steps_trained: 303104, entropy: 2.8161945800814365, learning_rate: 0.0005000000000000001
# iteration [38] => episode_reward_mean: 394.46721088672007, episode_len_mean: 300.0, agent_steps_trained: 933888, env_steps_trained: 311296, entropy: 2.8886113732225365, learning_rate: 0.0005000000000000001
# iteration [39] => episode_reward_mean: 390.80359072592285, episode_len_mean: 300.0, agent_steps_trained: 958464, env_steps_trained: 319488, entropy: 2.9100075074368053, learning_rate: 0.0005000000000000001
# iteration [40] => episode_reward_mean: 384.46113616347554, episode_len_mean: 300.0, agent_steps_trained: 983040, env_steps_trained: 327680, entropy: 2.8597304166191155, learning_rate: 0.0005000000000000001
# iteration [41] => episode_reward_mean: 375.65954371506996, episode_len_mean: 300.0, agent_steps_trained: 1007616, env_steps_trained: 335872, entropy: 2.9010053983993, learning_rate: 0.0005000000000000001
# iteration [42] => episode_reward_mean: 370.52191310551234, episode_len_mean: 300.0, agent_steps_trained: 1032192, env_steps_trained: 344064, entropy: 2.954093213296599, learning_rate: 0.0005000000000000001
# iteration [43] => episode_reward_mean: 384.54999982266554, episode_len_mean: 300.0, agent_steps_trained: 1056768, env_steps_trained: 352256, entropy: 2.855041023054057, learning_rate: 0.0005000000000000001
# iteration [44] => episode_reward_mean: 384.14185077793644, episode_len_mean: 300.0, agent_steps_trained: 1081344, env_steps_trained: 360448, entropy: 2.7511304616100256, learning_rate: 0.0005000000000000001
# iteration [45] => episode_reward_mean: 387.9515838343118, episode_len_mean: 300.0, agent_steps_trained: 1105920, env_steps_trained: 368640, entropy: 2.7760194041662745, learning_rate: 0.0005000000000000001
# iteration [46] => episode_reward_mean: 399.6118689526871, episode_len_mean: 300.0, agent_steps_trained: 1130496, env_steps_trained: 376832, entropy: 2.712523723186718, learning_rate: 0.0005000000000000001
# iteration [47] => episode_reward_mean: 406.00565754791575, episode_len_mean: 300.0, agent_steps_trained: 1155072, env_steps_trained: 385024, entropy: 2.6636876076459886, learning_rate: 0.0005000000000000001
# iteration [48] => episode_reward_mean: 424.3042037460311, episode_len_mean: 300.0, agent_steps_trained: 1179648, env_steps_trained: 393216, entropy: 2.8365270216845806, learning_rate: 0.0005000000000000001
# iteration [49] => episode_reward_mean: 425.6799876784007, episode_len_mean: 300.0, agent_steps_trained: 1204224, env_steps_trained: 401408, entropy: 2.686417746212747, learning_rate: 0.0005000000000000001
# iteration [50] => episode_reward_mean: 427.0449132704647, episode_len_mean: 300.0, agent_steps_trained: 1228800, env_steps_trained: 409600, entropy: 2.784695533083545, learning_rate: 0.0005000000000000001
# CanvasWithBorders(height=300, width=300)
# action:  {'agent-0': array([ 1.       , -1.       ,  0.8208726], dtype=float32), 'agent-1': array([-0.67236066,  0.25055313,  0.24013585], dtype=float32), 'agent-2': array([0.25559998, 1.        , 1.        ], dtype=float32)}
# reward:  {'agent-0': 0.8201755031686915, 'agent-1': 0.18025747589430097, 'agent-2': 0.9696277046904154}
#
# action:  {'agent-0': array([ 1., -1.,  1.], dtype=float32), 'agent-1': array([-1.        ,  1.        ,  0.25777608], dtype=float32), 'agent-2': array([0.28699255, 1.        , 0.49432746], dtype=float32)}
# reward:  {'agent-0': 0.9990939454599221, 'agent-1': 0.10270205664080123, 'agent-2': 0.48538157160446005}
#
# action:  {'agent-0': array([ 1.        , -0.79195297,  1.        ], dtype=float32), 'agent-1': array([-1.      ,  0.311316,  0.37472 ], dtype=float32), 'agent-2': array([-0.18007141,  1.        ,  1.        ], dtype=float32)}
# reward:  {'agent-0': 0.9972927196821715, 'agent-1': 0.28895338587054553, 'agent-2': 0.8247858817470703}
#
# action:  {'agent-0': array([ 0.22543573, -0.39996284,  0.8759747 ], dtype=float32), 'agent-1': array([-1.        ,  0.60698235,  0.27444932], dtype=float32), 'agent-2': array([0.17429972, 1.        , 0.37684408], dtype=float32)}
# reward:  {'agent-0': 0.8320545981733254, 'agent-1': 0.16041927631649955, 'agent-2': 0.3687803774851117}
#
# action:  {'agent-0': array([ 1., -1.,  1.], dtype=float32), 'agent-1': array([-0.64788103, -0.09118468,  0.9211018 ], dtype=float32), 'agent-2': array([-0.33901757,  1.        ,  0.99717546], dtype=float32)}
# reward:  {'agent-0': 0.998634909856662, 'agent-1': 0.8866832822421102, 'agent-2': 0.7850941426192133}
#
# action:  {'agent-0': array([ 0.5209639, -0.7998914,  0.       ], dtype=float32), 'agent-1': array([-1.        , -0.78619397,  0.16760248], dtype=float32), 'agent-2': array([-0.25601584,  0.5327282 ,  1.        ], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': 0.16254603888159025, 'agent-2': 0.7561606656426569}
#
# action:  {'agent-0': array([ 1.        , -0.24895316,  0.21742606], dtype=float32), 'agent-1': array([-1.        ,  0.24126565,  0.37301487], dtype=float32), 'agent-2': array([0.4915619 , 1.        , 0.94056505], dtype=float32)}
# reward:  {'agent-0': 0.1918225661287991, 'agent-1': 0.294154302663884, 'agent-2': -0.04802433841567755}
#
# action:  {'agent-0': array([ 1.        , -1.        ,  0.56621283], dtype=float32), 'agent-1': array([-1.        , -0.96741956,  0.64818275], dtype=float32), 'agent-2': array([-0.2644484 ,  0.52480567,  0.6931492 ], dtype=float32)}
# reward:  {'agent-0': 0.5655140791192821, 'agent-1': 0.6104168015747042, 'agent-2': -0.531745030542389}
#
# action:  {'agent-0': array([ 0.968271, -0.898667,  1.      ], dtype=float32), 'agent-1': array([-1.        ,  0.23776865,  1.        ], dtype=float32), 'agent-2': array([-1.        ,  0.46920097,  1.        ], dtype=float32)}
# reward:  {'agent-0': 0.9999115938115999, 'agent-1': 0.7825648115834127, 'agent-2': -0.26956644311589706}
#
# action:  {'agent-0': array([ 1.        , -0.22327453,  1.        ], dtype=float32), 'agent-1': array([-1.        , -0.50470114,  0.32280305], dtype=float32), 'agent-2': array([-0.7587522,  0.561023 ,  1.       ], dtype=float32)}
# reward:  {'agent-0': 0.8647790302160203, 'agent-1': 0.3227900862734625, 'agent-2': -0.5236978857455465}
#
# action:  {'agent-0': array([ 1.       , -0.8710776,  0.9178442], dtype=float32), 'agent-1': array([-1.        , -0.42342228,  0.8116567 ], dtype=float32), 'agent-2': array([-1.        , -0.39862776,  0.5456699 ], dtype=float32)}
# reward:  {'agent-0': 0.9170549984763454, 'agent-1': 0.8102238012676981, 'agent-2': 0.21601392266924435}
#
# action:  {'agent-0': array([ 1., -1.,  0.], dtype=float32), 'agent-1': array([-0.91631913,  0.6367258 ,  0.44243658], dtype=float32), 'agent-2': array([-0.1446796 , -0.7935457 ,  0.93890655], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': 0.20750349032043758, 'agent-2': 0.9234620411217751}
#
# action:  {'agent-0': array([ 1., -1.,  1.], dtype=float32), 'agent-1': array([-1.        , -0.88888097,  0.22890988], dtype=float32), 'agent-2': array([1.        , 0.44223094, 0.13038614], dtype=float32)}
# reward:  {'agent-0': 0.9996334445965651, 'agent-1': 0.22238243536143898, 'agent-2': -0.05231859293314933}
#
# action:  {'agent-0': array([ 1.       , -0.8083221,  1.       ], dtype=float32), 'agent-1': array([-1.        , -0.69308007,  0.59822   ], dtype=float32), 'agent-2': array([-1.        , -0.14676952,  0.937591  ], dtype=float32)}
# reward:  {'agent-0': 0.9968104521333849, 'agent-1': 0.5936673323410719, 'agent-2': 0.09753898017104312}
#
# action:  {'agent-0': array([1.        , 0.14967275, 1.        ], dtype=float32), 'agent-1': array([-0.6717036, -0.9928423,  0.7527488], dtype=float32), 'agent-2': array([-0.42522955, -0.6383687 ,  0.84436756], dtype=float32)}
# reward:  {'agent-0': 0.596364671273605, 'agent-1': 0.6568997997658563, 'agent-2': 6.05413102327417}
#
# action:  {'agent-0': array([ 1.        , -0.5463264 ,  0.36632526], dtype=float32), 'agent-1': array([-1.        , -0.47170687,  0.79539275], dtype=float32), 'agent-2': array([-0.21680915,  0.35954523,  1.        ], dtype=float32)}
# reward:  {'agent-0': 0.3490713438034909, 'agent-1': 0.7953444277641069, 'agent-2': -0.8809195277769781}
#
# action:  {'agent-0': array([ 1.       , -0.6050171,  1.       ], dtype=float32), 'agent-1': array([-0.48343003, -0.73423237,  0.85322976], dtype=float32), 'agent-2': array([ 0.1525482 , -0.70912766,  1.        ], dtype=float32)}
# reward:  {'agent-0': 0.9624692958918359, 'agent-1': 0.7248228404073362, 'agent-2': 0.8080894755188215}
#
# action:  {'agent-0': array([ 1.        , -0.07033765,  1.        ], dtype=float32), 'agent-1': array([-1.        ,  0.10835314,  0.        ], dtype=float32), 'agent-2': array([-0.15428257,  0.2586757 ,  0.8630382 ], dtype=float32)}
# reward:  {'agent-0': 0.7126183021497923, 'agent-1': 0.0, 'agent-2': -0.6187975774449086}
#
# action:  {'agent-0': array([ 1.        , -0.6305218 ,  0.93431634], dtype=float32), 'agent-1': array([-0.5781698 , -1.        ,  0.33664674], dtype=float32), 'agent-2': array([-0.44218057, -1.        ,  0.35358214], dtype=float32)}
# reward:  {'agent-0': 0.8881377556827985, 'agent-1': 0.26942618131643314, 'agent-2': 0.2866638469467766}
#
# action:  {'agent-0': array([ 1.        , -0.3046373 ,  0.07332247], dtype=float32), 'agent-1': array([0.10485327, 0.7851875 , 0.38390362], dtype=float32), 'agent-2': array([-1.        , -0.20585322,  0.47449228], dtype=float32)}
# reward:  {'agent-0': 0.06079415874088312, 'agent-1': -0.1981146803181577, 'agent-2': -0.018316942109063206}
#
# action:  {'agent-0': array([ 0.78210056, -1.        ,  0.17226976], dtype=float32), 'agent-1': array([-1.        , -0.03537989,  0.6524232 ], dtype=float32), 'agent-2': array([-0.55838484, -0.01782137,  0.8321347 ], dtype=float32)}
# reward:  {'agent-0': 0.17224523626375543, 'agent-1': 0.6007065435562957, 'agent-2': -0.22245312101495607}
#
# action:  {'agent-0': array([ 1., -1.,  1.], dtype=float32), 'agent-1': array([-0.11147708,  0.97398007,  0.15398371], dtype=float32), 'agent-2': array([ 0.48421383, -0.93020886,  0.        ], dtype=float32)}
# reward:  {'agent-0': 0.9941368931551313, 'agent-1': -0.051536102742941736, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 0.7475929 , -1.        ,  0.16453326], dtype=float32), 'agent-1': array([-0.44235945,  0.8081504 ,  0.6605655 ], dtype=float32), 'agent-2': array([-0.46831006,  0.0508256 ,  0.        ], dtype=float32)}
# reward:  {'agent-0': 0.16445156659051108, 'agent-1': 0.0046662971537045905, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 1.        , -0.72451615,  0.36709207], dtype=float32), 'agent-1': array([-0.90015996,  0.07084894,  0.3452329 ], dtype=float32), 'agent-2': array([ 0.9520434 , -0.12187648,  0.        ], dtype=float32)}
# reward:  {'agent-0': 0.35342477125031024, 'agent-1': 0.28228225171074506, 'agent-2': 0.0}
#
# action:  {'agent-0': array([1.        , 0.25265145, 1.        ], dtype=float32), 'agent-1': array([-0.4334911 ,  0.24932551,  0.        ], dtype=float32), 'agent-2': array([ 0.171175 , -0.1422354,  0.       ], dtype=float32)}
# reward:  {'agent-0': 0.3751809886045283, 'agent-1': 0.0, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 0.6959171, -0.6007056,  0.6157418], dtype=float32), 'agent-1': array([0.20251489, 0.0086894 , 0.3914255 ], dtype=float32), 'agent-2': array([ 0.43242264, -1.        ,  0.27363563], dtype=float32)}
# reward:  {'agent-0': 0.5938044772753788, 'agent-1': -0.34486572673385574, 'agent-2': 0.2729898544463758}
#
# action:  {'agent-0': array([ 0.5188867 , -1.        ,  0.74891305], dtype=float32), 'agent-1': array([-1.       ,  1.       ,  0.4276423], dtype=float32), 'agent-2': array([-0.7954163 ,  0.48993552,  0.2693888 ], dtype=float32)}
# reward:  {'agent-0': 0.7444505262625416, 'agent-1': 0.10118380961935003, 'agent-2': -0.21078811214438353}
#
# action:  {'agent-0': array([ 0.10232615, -0.12360662,  1.        ], dtype=float32), 'agent-1': array([-0.4719293 , -0.46315444,  0.19006324], dtype=float32), 'agent-2': array([-0.52356875, -0.38157976,  0.13174832], dtype=float32)}
# reward:  {'agent-0': 0.9945201268554253, 'agent-1': 0.18582741525852242, 'agent-2': 0.035052890348742594}
#
# action:  {'agent-0': array([ 0.32262588, -0.03434515,  0.7299837 ], dtype=float32), 'agent-1': array([-0.50209117,  0.11017573,  0.62849313], dtype=float32), 'agent-2': array([ 1.        , -0.34812713,  0.5627344 ], dtype=float32)}
# reward:  {'agent-0': 0.4483274834636042, 'agent-1': 0.024055510751471942, 'agent-2': 0.35412313813416496}
#
# action:  {'agent-0': array([-0.3936268 ,  0.732538  ,  0.48327968], dtype=float32), 'agent-1': array([ 0.08297086, -0.01780999,  0.74271876], dtype=float32), 'agent-2': array([0.31122875, 0.06435537, 0.24878377], dtype=float32)}
# reward:  {'agent-0': -0.4829993724364847, 'agent-1': -0.1080440881404936, 'agent-2': 0.02691436154918847}
#
# action:  {'agent-0': array([0.55050826, 0.14179015, 0.3607633 ], dtype=float32), 'agent-1': array([-0.3521461 ,  1.        ,  0.60259783], dtype=float32), 'agent-2': array([ 1.        , -0.13114977,  0.1714828 ], dtype=float32)}
# reward:  {'agent-0': 0.09213995425459309, 'agent-1': -0.14597285311271868, 'agent-2': 0.07037645260279568}
#
# action:  {'agent-0': array([ 1.        , -0.7589085 ,  0.70380354], dtype=float32), 'agent-1': array([ 0.14485049, -0.63003737,  0.41662246], dtype=float32), 'agent-2': array([-0.5342655 ,  0.07907498,  0.76241624], dtype=float32)}
# reward:  {'agent-0': 0.6363226546202032, 'agent-1': 0.14936157897652969, 'agent-2': -0.341958570246371}
#
# action:  {'agent-0': array([ 0.43905878, -0.36552042,  0.        ], dtype=float32), 'agent-1': array([-0.99046874,  0.10351837,  0.35795736], dtype=float32), 'agent-2': array([0.5680524 , 0.09452927, 0.14860678], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': 3.257565878859499, 'agent-2': 0.026476417405355335}
#
# action:  {'agent-0': array([-0.12861991,  0.62286556,  0.        ], dtype=float32), 'agent-1': array([-0.3503362 , -0.08970165,  0.33156306], dtype=float32), 'agent-2': array([ 0.27241588, -0.31114358,  0.22971368], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': -0.24112600354416003, 'agent-2': 0.21278750617792497}
#
# action:  {'agent-0': array([-0.03520542, -0.43651974,  0.21134281], dtype=float32), 'agent-1': array([-0.46644664, -0.6694181 ,  0.40785462], dtype=float32), 'agent-2': array([-0.6121539, -0.5682614,  1.       ], dtype=float32)}
# reward:  {'agent-0': 9.589540769952281, 'agent-1': -0.3814297455813751, 'agent-2': 0.07999402092225338}
#
# action:  {'agent-0': array([0.16929758, 0.0208863 , 0.2924767 ], dtype=float32), 'agent-1': array([0.23752117, 0.09172535, 0.39694515], dtype=float32), 'agent-2': array([-0.5681607,  0.6273328,  0.934788 ], dtype=float32)}
# reward:  {'agent-0': -0.09753438580614748, 'agent-1': 0.38741967649564124, 'agent-2': -0.6078207462771665}
#
# action:  {'agent-0': array([-0.8791741,  0.2132647,  0.5084095], dtype=float32), 'agent-1': array([-0.3692758 , -0.55963385,  0.84038574], dtype=float32), 'agent-2': array([ 0.37843013, -0.71247303,  0.5214075 ], dtype=float32)}
# reward:  {'agent-0': -0.12901687413461183, 'agent-1': -0.7666543215055572, 'agent-2': 0.5209705696560807}
#
# action:  {'agent-0': array([-0.67242897,  1.        ,  0.42208016], dtype=float32), 'agent-1': array([0.30180168, 0.94099915, 0.53181875], dtype=float32), 'agent-2': array([0.35899282, 0.06136751, 0.2333385 ], dtype=float32)}
# reward:  {'agent-0': -0.41986047059187115, 'agent-1': 0.4084826089350617, 'agent-2': 0.061328993948920996}
#
# action:  {'agent-0': array([ 1.        , -0.5935059 ,  0.37695673], dtype=float32), 'agent-1': array([-0.1604209 ,  0.82922196,  0.11683619], dtype=float32), 'agent-2': array([-1.        ,  0.13444126,  0.95402163], dtype=float32)}
# reward:  {'agent-0': 0.32075160803169744, 'agent-1': 0.045336555651381616, 'agent-2': -0.5356697103925878}
#
# action:  {'agent-0': array([-1.        , -0.4347697 ,  0.12650669], dtype=float32), 'agent-1': array([0.38204193, 1.        , 0.65007484], dtype=float32), 'agent-2': array([-0.9824723 , -0.3638715 ,  0.24084371], dtype=float32)}
# reward:  {'agent-0': -0.008663950391406772, 'agent-1': 1.8481874009939827, 'agent-2': -0.03749178486474669}
#
# action:  {'agent-0': array([0.80829585, 0.04923499, 0.61784154], dtype=float32), 'agent-1': array([-1.        ,  0.8383144 ,  0.42438617], dtype=float32), 'agent-2': array([ 0.25926006, -0.73462147,  0.        ], dtype=float32)}
# reward:  {'agent-0': 0.2384297809971727, 'agent-1': -0.09241151366659217, 'agent-2': 0.0}
#
# action:  {'agent-0': array([1.        , 0.88949394, 0.2544579 ], dtype=float32), 'agent-1': array([1.        , 0.17798066, 0.02916628], dtype=float32), 'agent-2': array([1.        , 0.19803452, 0.        ], dtype=float32)}
# reward:  {'agent-0': -0.07762126429130412, 'agent-1': 0.025627635874178267, 'agent-2': 0.0}
#
# action:  {'agent-0': array([0.39267898, 0.42540002, 0.4781741 ], dtype=float32), 'agent-1': array([0.39845538, 0.93581676, 0.4032458 ], dtype=float32), 'agent-2': array([ 1.        , -0.8070793 ,  0.07707709], dtype=float32)}
# reward:  {'agent-0': -0.20429933931782607, 'agent-1': -0.13613200646120305, 'agent-2': 0.07183405021808831}
#
# action:  {'agent-0': array([1.       , 0.772061 , 0.5012692], dtype=float32), 'agent-1': array([-0.06831896, -0.79926795,  0.10893974], dtype=float32), 'agent-2': array([ 0.23717165, -0.45584   ,  0.05740133], dtype=float32)}
# reward:  {'agent-0': -0.15641084793420568, 'agent-1': 0.07609523984571176, 'agent-2': 0.05735579698431792}
#
# action:  {'agent-0': array([ 0.3729205 , -0.80293167,  0.3819165 ], dtype=float32), 'agent-1': array([-0.79738796, -0.09680271,  0.        ], dtype=float32), 'agent-2': array([-0.38498044,  0.64642215,  0.5690845 ], dtype=float32)}
# reward:  {'agent-0': 0.3791915776161314, 'agent-1': 0.0, 'agent-2': -0.5690022681588882}
#
# action:  {'agent-0': array([1.        , 0.05078387, 0.19536817], dtype=float32), 'agent-1': array([-0.59728557,  0.17214441,  0.33407536], dtype=float32), 'agent-2': array([-0.01854634, -0.30294067,  0.14573747], dtype=float32)}
# reward:  {'agent-0': 0.04890141662562897, 'agent-1': 6.909544171809916, 'agent-2': 0.1214760363524583}
#
# action:  {'agent-0': array([1.        , 0.22271788, 0.6475425 ], dtype=float32), 'agent-1': array([0.04627037, 0.03348184, 0.        ], dtype=float32), 'agent-2': array([ 0.23087418, -0.72697455,  0.06096005], dtype=float32)}
# reward:  {'agent-0': 0.027980233663869924, 'agent-1': 6.755488981073512, 'agent-2': 0.059478522657300914}
#
# action:  {'agent-0': array([-0.57389563,  0.6864852 ,  1.        ], dtype=float32), 'agent-1': array([ 0.4156698 , -0.6108126 ,  0.46655688], dtype=float32), 'agent-2': array([ 0.26406717, -0.94935393,  0.32585245], dtype=float32)}
# reward:  {'agent-0': -0.9025625668763126, 'agent-1': -0.04234897304382912, 'agent-2': 0.31476658487061115}
#
# action:  {'agent-0': array([ 1., -1.,  1.], dtype=float32), 'agent-1': array([-1.       , -0.7510322,  0.386114 ], dtype=float32), 'agent-2': array([ 0.37674522, -0.10473299,  0.50803185], dtype=float32)}
# reward:  {'agent-0': 0.8587421554857624, 'agent-1': -0.38602610933195614, 'agent-2': 0.3612735432946863}
#
# action:  {'agent-0': array([-0.30344987,  0.16173232,  0.04306269], dtype=float32), 'agent-1': array([0.12098038, 0.4530939 , 0.30701226], dtype=float32), 'agent-2': array([-0.65126497,  0.63833296,  0.6332702 ], dtype=float32)}
# reward:  {'agent-0': -0.028197094548856327, 'agent-1': 0.24726038394246785, 'agent-2': -0.6078756250519213}
#
# action:  {'agent-0': array([0.435817  , 0.04349089, 0.78117764], dtype=float32), 'agent-1': array([-0.02728772,  0.46913695,  0.35730278], dtype=float32), 'agent-2': array([-1.        , -1.        ,  0.48798698], dtype=float32)}
# reward:  {'agent-0': 0.06863310441185178, 'agent-1': 6.906250972371545, 'agent-2': 0.11797221365149468}
#
# action:  {'agent-0': array([ 0.9291841 , -0.47087646,  1.        ], dtype=float32), 'agent-1': array([-0.6020027 , -0.25934732,  0.42941105], dtype=float32), 'agent-2': array([-0.08144438, -0.13597775,  0.5428058 ], dtype=float32)}
# reward:  {'agent-0': -0.37556478869055177, 'agent-1': -0.3757306815863348, 'agent-2': 0.23380608311971862}
#
# action:  {'agent-0': array([1.       , 0.3284148, 0.4353437], dtype=float32), 'agent-1': array([-1.        ,  0.5296712 ,  0.49919602], dtype=float32), 'agent-2': array([ 1.        , -0.02543044,  0.99782294], dtype=float32)}
# reward:  {'agent-0': 0.1185675890399942, 'agent-1': -0.1626571294894532, 'agent-2': 6.345700867414513}
#
# action:  {'agent-0': array([0.63475394, 0.59160185, 1.        ], dtype=float32), 'agent-1': array([-0.6708654,  0.7587557,  0.3192038], dtype=float32), 'agent-2': array([ 0.8970281 , -0.61037254,  0.4241283 ], dtype=float32)}
# reward:  {'agent-0': -0.011157166746084357, 'agent-1': 0.02217512433303881, 'agent-2': -0.33900848012923923}
#
# action:  {'agent-0': array([1.       , 0.0321635, 1.       ], dtype=float32), 'agent-1': array([ 0.07448435, -0.1149354 ,  0.49769992], dtype=float32), 'agent-2': array([0.29769528, 0.34296632, 0.        ], dtype=float32)}
# reward:  {'agent-0': -0.13179426147261886, 'agent-1': -0.10353730828035346, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 0.12696958, -0.24788213,  0.46443596], dtype=float32), 'agent-1': array([0.38451338, 0.98493266, 0.41885233], dtype=float32), 'agent-2': array([0.10570824, 0.5065738 , 0.        ], dtype=float32)}
# reward:  {'agent-0': 0.3741567425317811, 'agent-1': 0.3805984657658463, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 1.        , -0.11232698,  0.27873886], dtype=float32), 'agent-1': array([-0.35607803, -0.0850367 ,  0.282174  ], dtype=float32), 'agent-2': array([0.4162879 , 0.77648306, 0.67887473], dtype=float32)}
# reward:  {'agent-0': -0.021184221027747085, 'agent-1': -0.2405391300289459, 'agent-2': 5.929387218856814}
#
# action:  {'agent-0': array([-0.48563457, -0.22330439,  0.31147546], dtype=float32), 'agent-1': array([0.13652039, 0.60067666, 0.2991933 ], dtype=float32), 'agent-2': array([-0.39418715, -0.30649853,  0.2279431 ], dtype=float32)}
# reward:  {'agent-0': 0.1694574485474002, 'agent-1': 0.25555262911887944, 'agent-2': 5.476759837250452}
#
# action:  {'agent-0': array([1.       , 0.5577463, 0.8148807], dtype=float32), 'agent-1': array([-0.10761845, -0.00126868,  0.22422612], dtype=float32), 'agent-2': array([-0.4019537 ,  1.        ,  0.34286445], dtype=float32)}
# reward:  {'agent-0': -0.4355442886923129, 'agent-1': -0.15541989680577828, 'agent-2': -0.29621408162286045}
#
# action:  {'agent-0': array([1.        , 0.07385683, 0.        ], dtype=float32), 'agent-1': array([-4.8542023e-04,  3.1755674e-01,  5.8840430e-01], dtype=float32), 'agent-2': array([ 0.5521302 , -1.        ,  0.56445026], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': 1.6154542658402247, 'agent-2': 0.0735228709713791}
#
# action:  {'agent-0': array([-1.        , -0.13912565,  0.29632884], dtype=float32), 'agent-1': array([ 0.32397318, -0.07059753,  0.01368171], dtype=float32), 'agent-2': array([ 0.6168575 , -0.01230061,  0.5148514 ], dtype=float32)}
# reward:  {'agent-0': 0.10483534515262605, 'agent-1': -0.006461715508569554, 'agent-2': -0.23140314719616661}
#
# action:  {'agent-0': array([-0.16673231, -0.60682297,  0.71767235], dtype=float32), 'agent-1': array([-1.        , -0.14937103,  0.1823386 ], dtype=float32), 'agent-2': array([-0.5555857 ,  0.66996646,  0.68734246], dtype=float32)}
# reward:  {'agent-0': 0.044170125044439956, 'agent-1': -0.03661242950944654, 'agent-2': 0.28934614111969914}
#
# action:  {'agent-0': array([0.6511967 , 1.        , 0.84113353], dtype=float32), 'agent-1': array([-0.9983424 ,  0.57068086,  0.        ], dtype=float32), 'agent-2': array([-0.37374532, -0.34686697,  1.        ], dtype=float32)}
# reward:  {'agent-0': -0.11602135006202907, 'agent-1': 0.0, 'agent-2': 0.1175013352648886}
#
# action:  {'agent-0': array([-0.26931185,  0.11517704,  0.4336654 ], dtype=float32), 'agent-1': array([0.06862438, 0.01868296, 0.15815258], dtype=float32), 'agent-2': array([-0.07112908, -0.3876438 ,  0.5795762 ], dtype=float32)}
# reward:  {'agent-0': -0.0816924055410837, 'agent-1': 1.3876940412568275, 'agent-2': -0.4289151893340577}
#
# action:  {'agent-0': array([-0.10178351, -0.01395309,  0.8126553 ], dtype=float32), 'agent-1': array([ 0.30884504, -0.36748588,  0.09487864], dtype=float32), 'agent-2': array([-0.4410603 ,  0.09400952,  0.1924504 ], dtype=float32)}
# reward:  {'agent-0': 0.2350744354685652, 'agent-1': 4.443219853798001, 'agent-2': 0.13718736786489671}
#
# action:  {'agent-0': array([ 0.670182  , -0.15442264,  0.51579195], dtype=float32), 'agent-1': array([-0.45129442, -0.7929604 ,  0.39143384], dtype=float32), 'agent-2': array([-0.85907114, -0.4915104 ,  0.63594633], dtype=float32)}
# reward:  {'agent-0': 0.04215454715291145, 'agent-1': -0.32792243397440224, 'agent-2': 0.06579887971291498}
#
# action:  {'agent-0': array([ 1.        , -0.21377194,  0.        ], dtype=float32), 'agent-1': array([-0.05511415,  0.17314029,  0.36517584], dtype=float32), 'agent-2': array([-0.8592653 ,  0.84098244,  0.        ], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': 0.19316424162992973, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 1.       , -0.7560303,  0.8555902], dtype=float32), 'agent-1': array([-0.9885882 ,  0.57653797,  0.63206154], dtype=float32), 'agent-2': array([0.31489086, 0.0561142 , 0.01412565], dtype=float32)}
# reward:  {'agent-0': 0.1490743351937187, 'agent-1': -0.0816307572352084, 'agent-2': -0.006510272378932314}
#
# action:  {'agent-0': array([0.63860905, 0.42783368, 0.4885601 ], dtype=float32), 'agent-1': array([ 0.56574035, -0.03207129,  0.42906523], dtype=float32), 'agent-2': array([ 0.05856419, -0.19575071,  0.        ], dtype=float32)}
# reward:  {'agent-0': -0.15296714897442243, 'agent-1': 8.915978511865386, 'agent-2': 0.0}
#
# action:  {'agent-0': array([-0.56768215, -0.2830689 ,  0.90359974], dtype=float32), 'agent-1': array([-0.02052975,  0.71481013,  0.19372553], dtype=float32), 'agent-2': array([0.5122509 , 0.42318034, 0.37878135], dtype=float32)}
# reward:  {'agent-0': -0.06601518407426887, 'agent-1': -0.13690464102719346, 'agent-2': 0.020921280507023354}
#
# action:  {'agent-0': array([-0.6189079 ,  0.07395887,  0.7031499 ], dtype=float32), 'agent-1': array([-1.       ,  0.5300623,  0.       ], dtype=float32), 'agent-2': array([ 1.        , -0.17537677,  0.31012285], dtype=float32)}
# reward:  {'agent-0': -0.03811161048904843, 'agent-1': 0.0, 'agent-2': -0.2176429956125414}
#
# action:  {'agent-0': array([-0.9580608 ,  0.95160306,  0.40603033], dtype=float32), 'agent-1': array([-0.63879144, -1.        ,  0.42758542], dtype=float32), 'agent-2': array([0.38691914, 1.        , 0.5610336 ], dtype=float32)}
# reward:  {'agent-0': 0.24951346875905323, 'agent-1': -0.13909651072384754, 'agent-2': 0.33165562847115737}
#
# action:  {'agent-0': array([-0.19428039,  0.81348693,  0.8241845 ], dtype=float32), 'agent-1': array([-0.6545938 , -0.5532613 ,  0.19199562], dtype=float32), 'agent-2': array([-0.64164984,  0.4710747 ,  0.        ], dtype=float32)}
# reward:  {'agent-0': -0.5507774893398825, 'agent-1': -0.18744126313953657, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 0.571699  , -0.35657144,  0.63660467], dtype=float32), 'agent-1': array([0.5567477 , 0.31001222, 0.8358426 ], dtype=float32), 'agent-2': array([0.32219923, 0.33687806, 0.3966019 ], dtype=float32)}
# reward:  {'agent-0': 0.27825616884754645, 'agent-1': 0.16939657904929817, 'agent-2': 0.11001015154245053}
#
# action:  {'agent-0': array([ 1.        , -0.40500844,  0.78864884], dtype=float32), 'agent-1': array([ 0.5517342, -0.2544651,  0.5637161], dtype=float32), 'agent-2': array([-0.69447374,  1.        ,  0.42348394], dtype=float32)}
# reward:  {'agent-0': 0.16816749180446244, 'agent-1': -0.15331051188725908, 'agent-2': -0.3067589163343829}
#
# action:  {'agent-0': array([-1.        ,  0.70184207,  0.18672672], dtype=float32), 'agent-1': array([-0.7173737, -1.       ,  0.       ], dtype=float32), 'agent-2': array([-0.11547005, -0.56666243,  0.0822795 ], dtype=float32)}
# reward:  {'agent-0': -0.07491526411666172, 'agent-1': 0.0, 'agent-2': 0.06212477753977552}
#
# action:  {'agent-0': array([ 0.85587966, -0.33525765,  0.0868392 ], dtype=float32), 'agent-1': array([-1.        ,  0.18027842,  0.2043621 ], dtype=float32), 'agent-2': array([0.6106914 , 0.50032604, 0.748894  ], dtype=float32)}
# reward:  {'agent-0': 0.015408277384384661, 'agent-1': 0.10627363342245033, 'agent-2': -0.15258218207643637}
#
# action:  {'agent-0': array([0.5906713 , 0.48088777, 0.45212942], dtype=float32), 'agent-1': array([-0.5548906 ,  0.08721793,  0.68542415], dtype=float32), 'agent-2': array([ 0.72059155, -0.10495204,  0.48442566], dtype=float32)}
# reward:  {'agent-0': -0.3530502027315574, 'agent-1': 10.332114764848102, 'agent-2': 0.26182624003421573}
#
# action:  {'agent-0': array([ 1.        , -0.6470933 ,  0.34523603], dtype=float32), 'agent-1': array([-0.5017698 , -0.58535415,  0.4401458 ], dtype=float32), 'agent-2': array([-0.01738238, -0.8338052 ,  0.10270357], dtype=float32)}
# reward:  {'agent-0': 0.11278761044544616, 'agent-1': -0.43957260933921916, 'agent-2': 0.09337688918481035}
#
# action:  {'agent-0': array([-0.26081795, -0.50914156,  0.78168464], dtype=float32), 'agent-1': array([-0.0208739,  0.7116077,  0.6359854], dtype=float32), 'agent-2': array([0.77615166, 0.14969134, 0.34706643], dtype=float32)}
# reward:  {'agent-0': 0.27642530554619604, 'agent-1': 0.3790328715252542, 'agent-2': 4.214565853792071}
#
# action:  {'agent-0': array([0.69740367, 0.5983951 , 0.60767984], dtype=float32), 'agent-1': array([-0.8176892,  0.5641762,  0.6394855], dtype=float32), 'agent-2': array([-0.37816578, -0.16793478,  0.        ], dtype=float32)}
# reward:  {'agent-0': -0.014447070259427264, 'agent-1': -0.012348713794676058, 'agent-2': 4.144474906736165}
#
# action:  {'agent-0': array([1.        , 0.04752946, 0.2631693 ], dtype=float32), 'agent-1': array([-0.42461002,  0.12678349,  0.3081497 ], dtype=float32), 'agent-2': array([0.33107567, 0.19690967, 0.2066037 ], dtype=float32)}
# reward:  {'agent-0': -0.08624728398263137, 'agent-1': 9.542804878803148, 'agent-2': -0.03490097714474061}
#
# action:  {'agent-0': array([ 0.48230958, -0.5325775 ,  0.09642076], dtype=float32), 'agent-1': array([-0.09229076,  0.9989922 ,  0.3256777 ], dtype=float32), 'agent-2': array([-0.32776785,  0.07782125,  0.53225523], dtype=float32)}
# reward:  {'agent-0': 0.04894525850008513, 'agent-1': -0.2624042066488794, 'agent-2': -0.3054762124150141}
#
# action:  {'agent-0': array([1.        , 0.46023142, 1.        ], dtype=float32), 'agent-1': array([-0.6295167 ,  0.05798244,  0.13902813], dtype=float32), 'agent-2': array([1.        , 0.32761443, 0.6400276 ], dtype=float32)}
# reward:  {'agent-0': -0.6976134098240561, 'agent-1': 0.055001694056832307, 'agent-2': 0.03321193197661465}
#
# action:  {'agent-0': array([-0.86927414, -0.09985936,  0.8704601 ], dtype=float32), 'agent-1': array([0.1008631 , 0.35205173, 0.13996348], dtype=float32), 'agent-2': array([-0.0701952, -0.5794556,  0.5205969], dtype=float32)}
# reward:  {'agent-0': 0.3804240771095504, 'agent-1': -0.1368335937332521, 'agent-2': 0.2086656869038137}
#
# action:  {'agent-0': array([-1.        , -0.28510094,  0.67197245], dtype=float32), 'agent-1': array([ 0.29521263, -0.1734243 ,  0.3523367 ], dtype=float32), 'agent-2': array([-0.6398722 ,  0.33788705,  0.45262277], dtype=float32)}
# reward:  {'agent-0': 0.35231633794074213, 'agent-1': 0.00868149633750015, 'agent-2': -0.08792786267820851}
#
# action:  {'agent-0': array([-0.93399763, -0.44031352,  1.        ], dtype=float32), 'agent-1': array([ 0.15024686, -0.11778039,  0.30159637], dtype=float32), 'agent-2': array([0.7332146, 0.1876334, 0.       ], dtype=float32)}
# reward:  {'agent-0': -0.0844256973308628, 'agent-1': 0.03815080905623347, 'agent-2': 0.0}
#
# action:  {'agent-0': array([0.7123796 , 0.19734704, 0.61865044], dtype=float32), 'agent-1': array([-0.6928736 , -0.99038726,  0.30466098], dtype=float32), 'agent-2': array([-1.        , -0.11957598,  0.66202366], dtype=float32)}
# reward:  {'agent-0': 0.2774374220637732, 'agent-1': 9.477355786599464, 'agent-2': -0.19695134553491656}
#
# action:  {'agent-0': array([1.        , 0.45967913, 0.3695827 ], dtype=float32), 'agent-1': array([ 1.        , -0.19065952,  0.34084472], dtype=float32), 'agent-2': array([ 0.45539558, -0.6141176 ,  0.06690255], dtype=float32)}
# reward:  {'agent-0': -0.09618773009414383, 'agent-1': -0.11765800728668374, 'agent-2': 0.06573515526226004}
#
# action:  {'agent-0': array([-1.        , -0.03729922,  0.8249342 ], dtype=float32), 'agent-1': array([-0.44422394, -1.        ,  0.        ], dtype=float32), 'agent-2': array([ 1.       , -0.4876656,  0.       ], dtype=float32)}
# reward:  {'agent-0': 1.9106299304214844, 'agent-1': 0.0, 'agent-2': 0.0}
#
# action:  {'agent-0': array([-1.        , -0.01994246,  0.8811497 ], dtype=float32), 'agent-1': array([ 0.29307997, -0.30226618,  0.4619745 ], dtype=float32), 'agent-2': array([0.6798723 , 0.09923708, 0.6139839 ], dtype=float32)}
# reward:  {'agent-0': -0.13014483645516606, 'agent-1': 3.745767276393821, 'agent-2': 0.16777801303657291}
#
# action:  {'agent-0': array([0.0241431, 0.3635279, 0.7515614], dtype=float32), 'agent-1': array([-0.5995722 , -0.14084208,  0.14233187], dtype=float32), 'agent-2': array([1.        , 0.14888144, 0.536991  ], dtype=float32)}
# reward:  {'agent-0': -0.4090522948253206, 'agent-1': -0.04379526828062552, 'agent-2': 0.11677181154400174}
#
# action:  {'agent-0': array([0.65201616, 0.18601573, 1.        ], dtype=float32), 'agent-1': array([-0.21674615,  0.05111647,  0.2740555 ], dtype=float32), 'agent-2': array([-0.37499326,  0.3830166 ,  0.6620479 ], dtype=float32)}
# reward:  {'agent-0': -0.39293431737111284, 'agent-1': -0.09995952546748654, 'agent-2': -0.6043605904348155}
#
# action:  {'agent-0': array([ 1.        , -0.73842764,  0.94235146], dtype=float32), 'agent-1': array([-0.02766871, -0.12497985,  0.29927346], dtype=float32), 'agent-2': array([-0.6012753 ,  0.25096822,  0.        ], dtype=float32)}
# reward:  {'agent-0': 0.3914891305831514, 'agent-1': -0.2779445153172304, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 0.07130122, -0.25680804,  0.68881214], dtype=float32), 'agent-1': array([0.36607778, 0.14557445, 0.3979349 ], dtype=float32), 'agent-2': array([ 1.        , -0.55066884,  0.5699561 ], dtype=float32)}
# reward:  {'agent-0': 8.428829098432502, 'agent-1': 0.3333877859686396, 'agent-2': 0.4292176342047185}
#
# action:  {'agent-0': array([ 0.7435205 , -0.18117452,  0.44529405], dtype=float32), 'agent-1': array([-0.5506702 ,  0.4158082 ,  0.67691654], dtype=float32), 'agent-2': array([ 0.8567469 , -0.5376235 ,  0.79410017], dtype=float32)}
# reward:  {'agent-0': 6.334428716881723, 'agent-1': 0.03727868564982906, 'agent-2': -0.12993996909412964}
#
# action:  {'agent-0': array([0.3479303, 0.2622887, 0.8432704], dtype=float32), 'agent-1': array([-0.30731523, -0.33032393,  0.07434228], dtype=float32), 'agent-2': array([0.94386196, 0.7673824 , 0.29100525], dtype=float32)}
# reward:  {'agent-0': -0.70724377139884, 'agent-1': -0.07296898370450045, 'agent-2': 0.11785592432645231}
#
# action:  {'agent-0': array([-0.7042027 , -0.15082657,  0.7523617 ], dtype=float32), 'agent-1': array([-0.35036623, -0.05182189,  0.06029323], dtype=float32), 'agent-2': array([0.37968636, 0.01412988, 0.39005032], dtype=float32)}
# reward:  {'agent-0': 0.39422734945423876, 'agent-1': -0.038869612479398796, 'agent-2': -0.07562178144017295}
#
# action:  {'agent-0': array([ 0.77347267, -0.34058046,  0.2440755 ], dtype=float32), 'agent-1': array([-0.58856714,  1.        ,  0.24514592], dtype=float32), 'agent-2': array([-0.96905583,  0.40683603,  0.1156894 ], dtype=float32)}
# reward:  {'agent-0': 0.022716833745002774, 'agent-1': 0.11717726891304281, 'agent-2': 0.06674118410806251}
#
# action:  {'agent-0': array([ 0.9114101 , -0.22698951,  0.87659585], dtype=float32), 'agent-1': array([-0.8988872 , -0.6160315 ,  0.15728319], dtype=float32), 'agent-2': array([-1.        ,  0.17754745,  0.19865805], dtype=float32)}
# reward:  {'agent-0': -0.11477825196647551, 'agent-1': -0.14204503789552447, 'agent-2': 0.07870663331340566}
#
# action:  {'agent-0': array([-0.67779845,  0.11684442,  0.5499764 ], dtype=float32), 'agent-1': array([-0.15119362,  0.4458444 ,  0.63063884], dtype=float32), 'agent-2': array([0.05083847, 0.3627714 , 0.2232616 ], dtype=float32)}
# reward:  {'agent-0': 0.12038920396260444, 'agent-1': 0.011558915170118311, 'agent-2': 4.573977458477219}
#
# action:  {'agent-0': array([-1.       ,  0.8001652,  0.7812016], dtype=float32), 'agent-1': array([-0.32859004,  0.2266165 ,  0.5752626 ], dtype=float32), 'agent-2': array([ 0.9256393 , -0.01373196,  0.42771173], dtype=float32)}
# reward:  {'agent-0': -0.2641089050753376, 'agent-1': -0.0889403736317611, 'agent-2': -0.040352514183497945}
#
# action:  {'agent-0': array([ 0.49112427, -0.33275288,  0.7495306 ], dtype=float32), 'agent-1': array([ 0.6695193 , -0.32323694,  0.7944608 ], dtype=float32), 'agent-2': array([0.6078018 , 0.71725655, 0.34257728], dtype=float32)}
# reward:  {'agent-0': 0.19714268854905015, 'agent-1': -0.007671354694286592, 'agent-2': -0.08160950495711283}
#
# action:  {'agent-0': array([-1.        ,  0.72357166,  0.47739604], dtype=float32), 'agent-1': array([ 0.26055622, -0.12274027,  0.39167172], dtype=float32), 'agent-2': array([-1.        ,  0.15461373,  0.695564  ], dtype=float32)}
# reward:  {'agent-0': -0.13392619556019447, 'agent-1': -0.030013444265907907, 'agent-2': -0.23851980103440162}
#
# action:  {'agent-0': array([-1.        ,  0.03609037,  0.8866652 ], dtype=float32), 'agent-1': array([-0.3636626 , -0.13419896,  0.14478764], dtype=float32), 'agent-2': array([ 0.03283072, -0.7640518 ,  0.52991694], dtype=float32)}
# reward:  {'agent-0': 0.21323507785569262, 'agent-1': 0.11204594490446418, 'agent-2': 0.25638173903481487}
#
# action:  {'agent-0': array([ 1.      , -1.      ,  0.525669], dtype=float32), 'agent-1': array([-0.18799657, -0.66149986,  0.06994605], dtype=float32), 'agent-2': array([-1.        ,  0.53240335,  0.6743009 ], dtype=float32)}
# reward:  {'agent-0': 4.906578665449547, 'agent-1': 0.06775630181342152, 'agent-2': -0.19666218201168384}
#
# action:  {'agent-0': array([ 0.16830945, -0.0169735 ,  0.6154901 ], dtype=float32), 'agent-1': array([ 0.5588136 , -0.41628766,  0.12699026], dtype=float32), 'agent-2': array([0.05966878, 0.44136107, 0.7611441 ], dtype=float32)}
# reward:  {'agent-0': -0.12921048696321336, 'agent-1': 0.013360996944905779, 'agent-2': -0.6989790795648769}
#
# action:  {'agent-0': array([-1.       , -0.3376131,  0.2521863], dtype=float32), 'agent-1': array([ 0.54106224, -0.52438605,  0.        ], dtype=float32), 'agent-2': array([ 0.45892262, -0.8658529 ,  1.        ], dtype=float32)}
# reward:  {'agent-0': 9.77775700837943, 'agent-1': 0.0, 'agent-2': 0.9714121593933971}
#
# action:  {'agent-0': array([-1.       ,  0.0298202,  0.505077 ], dtype=float32), 'agent-1': array([ 1.       , -0.2280556,  0.3819457], dtype=float32), 'agent-2': array([ 1.        , -0.3747183 ,  0.82191133], dtype=float32)}
# reward:  {'agent-0': -0.12982943370433198, 'agent-1': -0.1254237982001154, 'agent-2': -0.3239129226178825}
#
# action:  {'agent-0': array([-0.81123877, -0.15121496,  0.91943777], dtype=float32), 'agent-1': array([-0.04464412, -1.        ,  0.47277504], dtype=float32), 'agent-2': array([-0.05087709,  0.51367044,  0.84770584], dtype=float32)}
# reward:  {'agent-0': -0.3699629385359611, 'agent-1': 0.12901116085584619, 'agent-2': -0.08571514954454607}
#
# action:  {'agent-0': array([0.38235664, 0.38794255, 0.6538691 ], dtype=float32), 'agent-1': array([-0.2691722 ,  0.16090381,  0.03117016], dtype=float32), 'agent-2': array([ 0.03109097, -0.50683755,  0.37444797], dtype=float32)}
# reward:  {'agent-0': 0.9589717199928641, 'agent-1': -0.0018811827819966709, 'agent-2': 0.3725592751762221}
#
# action:  {'agent-0': array([ 0.04520142, -0.21078694,  0.9849151 ], dtype=float32), 'agent-1': array([-0.53639686,  0.31943488,  0.27673578], dtype=float32), 'agent-2': array([-0.74404633, -0.72217387,  0.10979432], dtype=float32)}
# reward:  {'agent-0': -0.7895118814107391, 'agent-1': -0.012849772056549469, 'agent-2': 3.847117922451915}
#
# action:  {'agent-0': array([1.       , 0.3432815, 1.       ], dtype=float32), 'agent-1': array([-0.02905011, -0.00123417,  0.24041146], dtype=float32), 'agent-2': array([ 0.19725001, -0.03822678,  0.12669533], dtype=float32)}
# reward:  {'agent-0': 0.5981254295966227, 'agent-1': -0.13612306075193814, 'agent-2': 7.351936434946394}
#
# action:  {'agent-0': array([0.5939071 , 0.6046231 , 0.09441361], dtype=float32), 'agent-1': array([-0.3817076 ,  0.17519104,  0.16488397], dtype=float32), 'agent-2': array([-0.00953084, -0.53252345,  0.39797205], dtype=float32)}
# ...
#
# action:  {'agent-0': array([-0.9199666 , -0.09975445,  0.        ], dtype=float32), 'agent-1': array([0.06380892, 0.16171968, 0.8424812 ], dtype=float32), 'agent-2': array([ 0.70403886, -0.47233737,  0.6407512 ], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': -0.18827612503841884, 'agent-2': -0.4386404112766549}
#
# action:  {'agent-0': array([-0.7825534 , -0.07233989,  0.29941157], dtype=float32), 'agent-1': array([-1.        , -0.7629684 ,  0.79813874], dtype=float32), 'agent-2': array([-0.99335885,  0.14560795,  0.42406854], dtype=float32)}
# reward:  {'agent-0': 9.727096734073566, 'agent-1': 9.464471606410633, 'agent-2': 0.1299615153171647}
#
# action:  {'agent-0': array([-0.23064941,  0.08131909,  0.54611135], dtype=float32), 'agent-1': array([-0.25297976, -0.3631295 ,  0.72848743], dtype=float32), 'agent-2': array([0.8717849 , 0.6246942 , 0.43818292], dtype=float32)}
# reward:  {'agent-0': 3.052188188480763, 'agent-1': -0.5633956832932618, 'agent-2': 0.19261935536422037}
#
# action:  {'agent-0': array([-0.24371815, -0.61319554,  0.47103658], dtype=float32), 'agent-1': array([0.8645103 , 0.58000946, 0.20493132], dtype=float32), 'agent-2': array([-0.29917383,  0.6611875 ,  0.72563076], dtype=float32)}
# reward:  {'agent-0': -0.3979491464611229, 'agent-1': 0.10201758156438956, 'agent-2': -0.4647583960191586}
#
# action:  {'agent-0': array([ 0.42597127, -0.24604392,  0.11505234], dtype=float32), 'agent-1': array([-0.66987836,  0.7509953 ,  0.38415626], dtype=float32), 'agent-2': array([ 0.12420571, -0.77274346,  0.24838454], dtype=float32)}
# reward:  {'agent-0': -0.030929463825030368, 'agent-1': 0.30449737611073147, 'agent-2': 0.24837983621156212}
#
# action:  {'agent-0': array([-0.17209971,  0.53942513,  0.10814279], dtype=float32), 'agent-1': array([-1.        ,  0.24657464,  0.24225521], dtype=float32), 'agent-2': array([ 0.4805541 , -0.4177202 ,  0.46548542], dtype=float32)}
# reward:  {'agent-0': 0.09143831687559789, 'agent-1': 0.08034163385816306, 'agent-2': 6.1286200561541975}
#
# action:  {'agent-0': array([-1.        , -0.13167965,  0.372402  ], dtype=float32), 'agent-1': array([-0.7181121 , -0.22555506,  0.38668954], dtype=float32), 'agent-2': array([-0.7269005 ,  0.5717348 ,  0.59428835], dtype=float32)}
# reward:  {'agent-0': -0.13264501132255901, 'agent-1': -0.06819371797414497, 'agent-2': -0.39365530418255545}
#
# action:  {'agent-0': array([-0.41345346, -0.1965431 ,  0.86949974], dtype=float32), 'agent-1': array([-0.70077974,  0.5489571 ,  0.71292526], dtype=float32), 'agent-2': array([ 0.16208744, -0.4698587 ,  0.28114825], dtype=float32)}
# reward:  {'agent-0': -0.5059106959000399, 'agent-1': -0.22875633361263326, 'agent-2': 0.27761277044471555}
#
# action:  {'agent-0': array([0.03310156, 0.7510942 , 0.52393645], dtype=float32), 'agent-1': array([-0.2992344 , -0.03069615,  0.37856993], dtype=float32), 'agent-2': array([ 0.71179116, -0.50739264,  0.        ], dtype=float32)}
# reward:  {'agent-0': 0.5217321911076329, 'agent-1': -0.041397332812424636, 'agent-2': 0.0}
#
# action:  {'agent-0': array([-0.1697768 ,  0.51766527,  1.        ], dtype=float32), 'agent-1': array([-1.        , -0.5519329 ,  0.22190922], dtype=float32), 'agent-2': array([-0.59947085,  0.24282515,  1.        ], dtype=float32)}
# reward:  {'agent-0': 0.06821303066405626, 'agent-1': 0.05794043261828996, 'agent-2': -0.5616596794817301}
#
# action:  {'agent-0': array([ 0.32090878, -0.5478736 ,  0.76528037], dtype=float32), 'agent-1': array([-1.        , -0.647081  ,  0.22409779], dtype=float32), 'agent-2': array([ 1., -1.,  1.], dtype=float32)}
# reward:  {'agent-0': 0.22912788885322577, 'agent-1': 0.06911588861155593, 'agent-2': 0.5500000063875898}
#
# action:  {'agent-0': array([ 0.49320984, -0.16933602,  0.735885  ], dtype=float32), 'agent-1': array([0.3414985, 0.755739 , 0.3535161], dtype=float32), 'agent-2': array([-0.11743915,  0.52572155,  0.5950198 ], dtype=float32)}
# reward:  {'agent-0': -0.11479911632927653, 'agent-1': -0.2738256682391871, 'agent-2': -0.2976514662636447}
#
# action:  {'agent-0': array([-0.20635188, -0.33652842,  0.00074029], dtype=float32), 'agent-1': array([ 0.30416274, -1.        ,  0.4787523 ], dtype=float32), 'agent-2': array([-0.17782295, -0.24250978,  0.        ], dtype=float32)}
# reward:  {'agent-0': -0.0006982584985397722, 'agent-1': 0.47823141388512447, 'agent-2': 0.0}
#
# action:  {'agent-0': array([0.8343617, 1.       , 0.5515399], dtype=float32), 'agent-1': array([-1.        ,  0.49711835,  0.        ], dtype=float32), 'agent-2': array([ 1.        , -0.3243668 ,  0.11422834], dtype=float32)}
# reward:  {'agent-0': 0.12254261680942236, 'agent-1': 0.0, 'agent-2': 0.05566779481218376}
#
# action:  {'agent-0': array([-0.04064566, -0.21812224,  0.        ], dtype=float32), 'agent-1': array([ 0.4472084, -0.2030446,  0.3344678], dtype=float32), 'agent-2': array([ 0.72102   , -0.83390784,  0.4386683 ], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': -0.02818249332370648, 'agent-2': 7.812703791474231}
#
# action:  {'agent-0': array([ 0.17869925, -0.32746994,  0.        ], dtype=float32), 'agent-1': array([-1.       ,  0.7262378,  0.2382837], dtype=float32), 'agent-2': array([1.        , 0.00161684, 0.6234062 ], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': 0.053277700319444676, 'agent-2': -0.05899326650679626}
#
# action:  {'agent-0': array([-0.23074746, -0.25193608,  0.5055154 ], dtype=float32), 'agent-1': array([-1.       ,  0.5228058,  0.       ], dtype=float32), 'agent-2': array([ 0.18658626, -0.04955304,  0.62513816], dtype=float32)}
# reward:  {'agent-0': -0.07046728642865219, 'agent-1': 0.0, 'agent-2': -0.20639792812219504}
#
# action:  {'agent-0': array([-0.960417  , -0.53007925,  0.6567714 ], dtype=float32), 'agent-1': array([-0.32327414, -0.49290007,  0.        ], dtype=float32), 'agent-2': array([-0.40561342,  0.46763766,  0.5406756 ], dtype=float32)}
# reward:  {'agent-0': -0.41784988550498525, 'agent-1': 0.0, 'agent-2': 0.12637688038199713}
#
# action:  {'agent-0': array([ 0.1334486 , -0.16963881,  0.8430843 ], dtype=float32), 'agent-1': array([-0.51712704, -0.69237304,  0.59819174], dtype=float32), 'agent-2': array([ 1.       , -0.1806829,  0.7772051], dtype=float32)}
# reward:  {'agent-0': -0.550236774017387, 'agent-1': -0.24417146960603908, 'agent-2': 6.439316900907791}
#
# action:  {'agent-0': array([0.41426337, 0.9115094 , 0.43606597], dtype=float32), 'agent-1': array([0.06928468, 0.31691754, 0.5794214 ], dtype=float32), 'agent-2': array([0.40272856, 0.07621825, 0.6148186 ], dtype=float32)}
# reward:  {'agent-0': 0.4279814740256267, 'agent-1': 0.1027755764260867, 'agent-2': -0.09285830704553888}
#
# action:  {'agent-0': array([1.        , 0.5455613 , 0.28170902], dtype=float32), 'agent-1': array([-0.9692688, -0.4422803,  0.253641 ], dtype=float32), 'agent-2': array([ 0.3795203 , -0.32413322,  0.22851503], dtype=float32)}
# reward:  {'agent-0': 0.19179457329752303, 'agent-1': 0.040100000180551376, 'agent-2': 4.974559791693369}
#
# action:  {'agent-0': array([-0.20086372,  0.83083963,  0.5994563 ], dtype=float32), 'agent-1': array([0.46491265, 0.10704792, 0.        ], dtype=float32), 'agent-2': array([ 1.        , -0.5259183 ,  0.38775387], dtype=float32)}
# reward:  {'agent-0': 0.5308567372772899, 'agent-1': 0.0, 'agent-2': -0.14828877404182883}
#
# action:  {'agent-0': array([-0.96590847,  0.37652063,  0.        ], dtype=float32), 'agent-1': array([ 0.3593247 , -0.4659196 ,  0.35454407], dtype=float32), 'agent-2': array([0.33510482, 0.32852602, 0.87240034], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': 0.00042994668657314605, 'agent-2': -0.34219870928984086}
#
# action:  {'agent-0': array([-0.15017557,  0.01207304,  0.9670132 ], dtype=float32), 'agent-1': array([1.        , 0.65806055, 0.05641335], dtype=float32), 'agent-2': array([ 0.43997145, -0.9687613 ,  0.76546234], dtype=float32)}
# reward:  {'agent-0': -0.0992890839756928, 'agent-1': 0.017549191277590026, 'agent-2': 0.40464128888659445}
#
# action:  {'agent-0': array([0.5218483, 1.       , 0.5325738], dtype=float32), 'agent-1': array([-0.56336766,  0.72061634,  0.01434743], dtype=float32), 'agent-2': array([0.5070727 , 0.6073642 , 0.38005912], dtype=float32)}
# reward:  {'agent-0': -0.15913792221780554, 'agent-1': 0.013213271129794535, 'agent-2': -0.11406303385894567}
#
# action:  {'agent-0': array([ 0.4200437 , -0.6731212 ,  0.37782207], dtype=float32), 'agent-1': array([1.        , 0.5430629 , 0.47410566], dtype=float32), 'agent-2': array([ 0.560539  , -0.38424647,  0.6541065 ], dtype=float32)}
# reward:  {'agent-0': 0.8417267287169589, 'agent-1': 7.5294352372474105, 'agent-2': 9.710729625672514}
#
# action:  {'agent-0': array([-0.15258217, -0.18926817,  0.24470574], dtype=float32), 'agent-1': array([0.62683773, 0.4965061 , 0.07630962], dtype=float32), 'agent-2': array([0.5173857 , 0.01134813, 0.2804681 ], dtype=float32)}
# reward:  {'agent-0': -0.1193641737445823, 'agent-1': 5.86295397678513, 'agent-2': -0.08795170301631217}
#
# action:  {'agent-0': array([-0.03282851, -0.5462402 ,  0.        ], dtype=float32), 'agent-1': array([ 0.5594349, -0.5091351,  0.6601166], dtype=float32), 'agent-2': array([-0.57288677, -0.6818601 ,  1.        ], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': -0.48741947153246024, 'agent-2': -0.7366281235312027}
#
# action:  {'agent-0': array([0.19789481, 0.17523599, 0.6004184 ], dtype=float32), 'agent-1': array([0.366207  , 0.4845004 , 0.23466009], dtype=float32), 'agent-2': array([0.93771803, 0.8058896 , 0.78969824], dtype=float32)}
# reward:  {'agent-0': -0.1400043966492177, 'agent-1': 0.16208781920105508, 'agent-2': 0.6652265388002014}
#
# action:  {'agent-0': array([-1.        , -0.41410983,  0.8514917 ], dtype=float32), 'agent-1': array([0.65568876, 0.7068424 , 0.23025203], dtype=float32), 'agent-2': array([ 0.03018224, -0.95231146,  0.38617057], dtype=float32)}
# reward:  {'agent-0': 0.16216716574428247, 'agent-1': 0.14476784652590347, 'agent-2': -0.3624555619659269}
#
# action:  {'agent-0': array([-0.5246893 ,  0.10773528,  0.60901517], dtype=float32), 'agent-1': array([-0.435799  ,  0.44848847,  0.12075233], dtype=float32), 'agent-2': array([-0.15027463,  1.        ,  0.45781124], dtype=float32)}
# reward:  {'agent-0': 0.06314514270707683, 'agent-1': 0.09731559214047891, 'agent-2': 0.40900046301677584}
#
# action:  {'agent-0': array([-1.       , -0.8944053,  0.       ], dtype=float32), 'agent-1': array([-1.        , -0.22664285,  0.8371102 ], dtype=float32), 'agent-2': array([ 0.7727059 , -0.5256965 ,  0.44484824], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': -0.03304200970304372, 'agent-2': -0.11837226622218466}
#
# action:  {'agent-0': array([-1.       , -0.2159468,  0.5824223], dtype=float32), 'agent-1': array([-0.23462266,  0.17647588,  0.5321142 ], dtype=float32), 'agent-2': array([-0.41718274, -0.12973386,  0.28858846], dtype=float32)}
# reward:  {'agent-0': -0.14533413311828092, 'agent-1': -0.1387853962318335, 'agent-2': -0.1722373081960562}
#
# action:  {'agent-0': array([-0.05911636,  0.03489876,  0.52198505], dtype=float32), 'agent-1': array([ 0.44024312, -0.48770672,  0.5588741 ], dtype=float32), 'agent-2': array([0.40204406, 0.3268156 , 0.28810668], dtype=float32)}
# reward:  {'agent-0': 1.3634403318386838, 'agent-1': 0.057821097296386625, 'agent-2': 0.24495856735569177}
#
# action:  {'agent-0': array([-1.        , -0.31871116,  0.15172225], dtype=float32), 'agent-1': array([0.21308625, 0.53152955, 0.        ], dtype=float32), 'agent-2': array([-0.9811024 ,  0.36921263,  0.38855144], dtype=float32)}
# reward:  {'agent-0': 9.225764872338504, 'agent-1': 0.0, 'agent-2': 0.014767690711082082}
#
# action:  {'agent-0': array([ 0.13389051, -0.68243074,  0.39735618], dtype=float32), 'agent-1': array([0.5826981, 0.7623557, 0.5178307], dtype=float32), 'agent-2': array([ 0.9520639 , -0.5106917 ,  0.42922968], dtype=float32)}
# reward:  {'agent-0': -0.38488100353594135, 'agent-1': 0.10016777779751251, 'agent-2': -0.0720379591719933}
#
# action:  {'agent-0': array([-1.        ,  0.12643886,  0.43044198], dtype=float32), 'agent-1': array([-1.        ,  0.10566115,  0.31476697], dtype=float32), 'agent-2': array([-0.15149873,  0.3541454 ,  0.16740346], dtype=float32)}
# reward:  {'agent-0': 0.0815588088268413, 'agent-1': -0.09704164211082222, 'agent-2': 0.12319675980748812}
#
# action:  {'agent-0': array([0.67753506, 0.05666387, 0.08218157], dtype=float32), 'agent-1': array([ 0.42464137, -0.29736805,  0.6329502 ], dtype=float32), 'agent-2': array([-0.33254498,  0.09996343,  0.18037754], dtype=float32)}
# reward:  {'agent-0': 7.967362505567621e-05, 'agent-1': -0.029836844086283065, 'agent-2': -0.005894168292835289}
#
# action:  {'agent-0': array([-1.       , -0.1123839,  0.5846315], dtype=float32), 'agent-1': array([-0.05356014,  0.32368708,  0.68493813], dtype=float32), 'agent-2': array([-0.9661782 ,  0.19587755,  0.3888358 ], dtype=float32)}
# reward:  {'agent-0': -0.0020582451883779385, 'agent-1': -0.1956400051063092, 'agent-2': -0.03726835121367067}
#
# action:  {'agent-0': array([0.19926572, 0.47357702, 0.7177134 ], dtype=float32), 'agent-1': array([ 0.0745753 , -0.6291811 ,  0.55956733], dtype=float32), 'agent-2': array([ 0.7665169 , -0.8714717 ,  0.23014107], dtype=float32)}
# reward:  {'agent-0': -0.004540926535725021, 'agent-1': 0.322008618970564, 'agent-2': -0.12284728318087268}
#
# action:  {'agent-0': array([-1.        , -0.23251903,  0.21446109], dtype=float32), 'agent-1': array([0.68761206, 0.24070644, 0.63175553], dtype=float32), 'agent-2': array([-0.14437002,  0.13804162,  0.30807424], dtype=float32)}
# reward:  {'agent-0': 0.024642787582459746, 'agent-1': 9.889327790899634, 'agent-2': 0.1424531008387433}
#
# action:  {'agent-0': array([-1.        , -0.76816624,  0.42925218], dtype=float32), 'agent-1': array([0.6602744, 0.6407542, 0.8824298], dtype=float32), 'agent-2': array([-0.1939528 , -0.09957361,  0.3252587 ], dtype=float32)}
# reward:  {'agent-0': 0.21071611694051384, 'agent-1': -0.5559871112976307, 'agent-2': -0.21700134707217877}
#
# action:  {'agent-0': array([0.17434645, 1.        , 0.22808743], dtype=float32), 'agent-1': array([-0.40444636, -0.28347778,  0.37804723], dtype=float32), 'agent-2': array([0.00599945, 0.67012215, 0.4999809 ], dtype=float32)}
# reward:  {'agent-0': -0.21582885495401172, 'agent-1': 0.19544100272993958, 'agent-2': 0.18436156176604612}
#
# action:  {'agent-0': array([-0.65516126, -0.01539183,  0.3249251 ], dtype=float32), 'agent-1': array([ 0.7789054 , -1.        ,  0.23057806], dtype=float32), 'agent-2': array([ 0.00321972, -0.68078053,  0.4333318 ], dtype=float32)}
# reward:  {'agent-0': -0.0470261704845214, 'agent-1': 0.19231839866483824, 'agent-2': -0.11811642304341596}
#
# action:  {'agent-0': array([-0.6196363 ,  0.26907647,  0.        ], dtype=float32), 'agent-1': array([ 0.5072566, -0.3076321,  0.7577238], dtype=float32), 'agent-2': array([-0.15320575,  0.26181722,  0.40916127], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': -0.07964040127153993, 'agent-2': 4.679830113768756}
#
# action:  {'agent-0': array([-1.        , -0.7187618 ,  0.09542423], dtype=float32), 'agent-1': array([1.        , 0.48247886, 1.        ], dtype=float32), 'agent-2': array([-0.14780194, -0.58484364,  0.04853594], dtype=float32)}
# reward:  {'agent-0': 0.04018917469788619, 'agent-1': 0.030370255107454724, 'agent-2': 5.867121419764304}
#
# action:  {'agent-0': array([-0.10909629, -0.06712472,  0.3538707 ], dtype=float32), 'agent-1': array([-0.84146416,  0.06954193,  0.52320516], dtype=float32), 'agent-2': array([-0.779393  , -0.37405443,  0.25232637], dtype=float32)}
# reward:  {'agent-0': 0.1189040183915715, 'agent-1': -0.014219027768088921, 'agent-2': -0.1529788873790512}
#
# action:  {'agent-0': array([ 1.        , -0.21255493,  0.617937  ], dtype=float32), 'agent-1': array([ 0.86102176, -0.345824  ,  0.3601062 ], dtype=float32), 'agent-2': array([0.10713446, 0.532364  , 0.12283641], dtype=float32)}
# reward:  {'agent-0': 0.12023514535451696, 'agent-1': 0.11857880402514454, 'agent-2': 0.12283497923327324}

# %%
save_algo(algo, "ring_formation?agents=3&algo=PPO&phase=1")
# Out:
# An Algorithm checkpoint has been created inside directory: 'TrainingResult(checkpoint=Checkpoint(filesystem=local, path=/mnt/c/Users/nicol/Desktop/Università/tesi/experiments/RL_experiments/algos/ring_formation?agents=3&algo=PPO&phase=1), metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 7.685452235324515, 'cur_kl_coeff': 1.0125, 'cur_lr': 0.0005000000000000001, 'total_loss': 4.969661102692286, 'policy_loss': -0.008522659237496556, 'vf_loss': 4.96145134040465, 'vf_explained_var': 0.07497475184500217, 'kl': 0.01652585773659265, 'entropy': 2.784695533083545, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 256.0, 'num_grad_updates_lifetime': 142560.5, 'diff_num_grad_updates_vs_sampler_policy': 1439.5}}, 'num_env_steps_sampled': 409600, 'num_env_steps_trained': 409600, 'num_agent_steps_sampled': 1228800, 'num_agent_steps_trained': 1228800}, 'sampler_results': {'episode_reward_max': 609.7749250197895, 'episode_reward_min': 218.82138281429175, 'episode_reward_mean': 427.0449132704647, 'episode_len_mean': 300.0, 'episode_media': {}, 'episodes_this_iter': 26, 'episodes_timesteps_total': 30000, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [478.5576994372388, 464.79372046865296, 311.59394573444683, 375.97843416774487, 483.1600923389602, 393.85769325625034, 475.7930477354616, 448.7169817926661, 457.92507344453577, 350.7682798616488, 518.1994428671582, 427.9136920792587, 331.1584970979605, 531.8991530400818, 443.2501898758921, 581.4455903397812, 475.34128514428573, 280.84633241980526, 247.10146653512993, 398.3295079156444, 450.13034120283044, 518.1780490633939, 386.00783170566893, 609.7749250197895, 547.3487882046661, 367.2009132928247, 390.79991254630704, 464.98725210832254, 256.16334682224306, 322.3439144972435, 477.43765119195444, 280.49537862671616, 408.0627294733521, 453.6893566823901, 439.89993564796737, 582.6371936615594, 409.4883008988008, 458.00858189201637, 506.07231981309917, 393.5348258220155, 326.90777751731525, 436.25778322556533, 551.4431537026935, 291.16978053843013, 499.14243148300494, 500.76563870474604, 360.580050095853, 379.1475958846388, 299.3726043487995, 379.54316234315047, 381.9704606607127, 593.5661774712954, 607.1117690354621, 439.98266898193157, 387.03485252498365, 406.94363875524203, 430.5229712129553, 591.6369486921742, 349.36522118075493, 373.222402115477, 417.17130449147083, 362.1733936536662, 566.9336202371439, 412.3723301914593, 311.6774938807415, 441.9842751535373, 309.1177663522734, 447.8385756965773, 470.23989857910976, 464.405505898567, 303.6408503877222, 548.6275522587724, 491.4512255347978, 448.72400540747157, 365.99864276757523, 356.12290770039084, 429.21220086931623, 360.1363576361489, 494.05034073771526, 550.3153110852729, 448.72767155957155, 342.5614983873268, 425.40728249496436, 468.76514700952356, 365.3886865355023, 283.2969155277134, 561.7053002674078, 598.5400447797261, 398.54440676637427, 222.59504126135417, 218.82138281429175, 320.33341021217234, 442.10404569338766, 592.3009594866892, 558.4264236931563, 348.6808670118239, 564.2885791664362, 334.6238170676962, 325.1713912215474, 547.4361353691194], 'episode_lengths': [300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.6562749080696867, 'mean_inference_ms': 1.2201706757953164, 'mean_action_processing_ms': 0.3978660782116179, 'mean_en ...

# %%
from ray.rllib.algorithms.ppo import PPOConfig
from ray.tune.logger import pretty_print
from gymnasium.wrappers.time_limit import TimeLimit

trainin_steps = 30

algo = load_algo("ring_formation?agents=3&algo=PPO&phase=1")
clear_output()

algo.workers.foreach_worker(
    lambda ev: ev.foreach_env(
        lambda env: env.set_task(RingFormation.Task.DISTANCE_FROM_NEIGHBOURS)))

out = ""
for i in range(trainin_steps):
    result = algo.train()
    clear_output()
    out += ppo_result_format(result) + "\n"
    print(out)
    simulate_episode(RenderableRingFormation(config), algo, 200, sleep_between_frames=0.03, print_reward=True, print_action=True)
# Out:
# iteration [51] => episode_reward_mean: -595.035641479298, episode_len_mean: 300.0, agent_steps_trained: 1253376, env_steps_trained: 417792, entropy: 2.7272518075174754, learning_rate: 0.0005000000000000001
# iteration [52] => episode_reward_mean: -580.077361686813, episode_len_mean: 300.0, agent_steps_trained: 1277952, env_steps_trained: 425984, entropy: 2.7143479217257767, learning_rate: 0.0005000000000000001
# iteration [53] => episode_reward_mean: -564.2013487637489, episode_len_mean: 300.0, agent_steps_trained: 1302528, env_steps_trained: 434176, entropy: 2.6577868813027936, learning_rate: 0.0005000000000000001
# iteration [54] => episode_reward_mean: -590.0828583142396, episode_len_mean: 300.0, agent_steps_trained: 1327104, env_steps_trained: 442368, entropy: 2.6654861602104374, learning_rate: 0.0005000000000000001
# iteration [55] => episode_reward_mean: -593.1136960408238, episode_len_mean: 300.0, agent_steps_trained: 1351680, env_steps_trained: 450560, entropy: 2.7420337500671548, learning_rate: 0.0005000000000000001
# iteration [56] => episode_reward_mean: -614.5819632042802, episode_len_mean: 300.0, agent_steps_trained: 1376256, env_steps_trained: 458752, entropy: 2.747224015494188, learning_rate: 0.0005000000000000001
# iteration [57] => episode_reward_mean: -620.7359960753512, episode_len_mean: 300.0, agent_steps_trained: 1400832, env_steps_trained: 466944, entropy: 2.6983045344965326, learning_rate: 0.0005000000000000001
# iteration [58] => episode_reward_mean: -580.7637262467298, episode_len_mean: 300.0, agent_steps_trained: 1425408, env_steps_trained: 475136, entropy: 2.803182966179318, learning_rate: 0.0005000000000000001
# iteration [59] => episode_reward_mean: -550.1642534733269, episode_len_mean: 300.0, agent_steps_trained: 1449984, env_steps_trained: 483328, entropy: 2.870654370635748, learning_rate: 0.0005000000000000001
# iteration [60] => episode_reward_mean: -520.8023854618058, episode_len_mean: 300.0, agent_steps_trained: 1474560, env_steps_trained: 491520, entropy: 2.9712884838796323, learning_rate: 0.0005000000000000001
# iteration [61] => episode_reward_mean: -488.56365333617947, episode_len_mean: 300.0, agent_steps_trained: 1499136, env_steps_trained: 499712, entropy: 2.931156848039892, learning_rate: 0.0005000000000000001
# iteration [62] => episode_reward_mean: -472.4514053468501, episode_len_mean: 300.0, agent_steps_trained: 1523712, env_steps_trained: 507904, entropy: 2.7252478304008645, learning_rate: 0.0005000000000000001
# iteration [63] => episode_reward_mean: -470.911507280591, episode_len_mean: 300.0, agent_steps_trained: 1548288, env_steps_trained: 516096, entropy: 2.8169675521966484, learning_rate: 0.0005000000000000001
# iteration [64] => episode_reward_mean: -458.14599012314443, episode_len_mean: 300.0, agent_steps_trained: 1572864, env_steps_trained: 524288, entropy: 3.072354189885987, learning_rate: 0.0005000000000000001
# iteration [65] => episode_reward_mean: -494.1512011736847, episode_len_mean: 300.0, agent_steps_trained: 1597440, env_steps_trained: 532480, entropy: 2.7907717608743243, learning_rate: 0.0005000000000000001
# iteration [66] => episode_reward_mean: -491.89108550354337, episode_len_mean: 300.0, agent_steps_trained: 1622016, env_steps_trained: 540672, entropy: 3.0395284099297393, learning_rate: 0.0005000000000000001
# CanvasWithBorders(height=300, width=300)
# action:  {'agent-0': array([-1., -1.,  1.], dtype=float32), 'agent-1': array([-0.28370523,  1.        ,  1.        ], dtype=float32), 'agent-2': array([1.        , 1.        , 0.37425423], dtype=float32)}
# reward:  {'agent-0': 0.850294849427268, 'agent-1': 0.9102400475882142, 'agent-2': -0.16494274732264813}
#
# action:  {'agent-0': array([-1.        , -0.9384874 ,  0.18040425], dtype=float32), 'agent-1': array([0.25716949, 1.        , 1.        ], dtype=float32), 'agent-2': array([0.13385928, 1.        , 0.96851724], dtype=float32)}
# reward:  {'agent-0': 0.14859728167277808, 'agent-1': 0.5593903048434221, 'agent-2': -0.8453717750092808}
#
# action:  {'agent-0': array([-1., -1.,  1.], dtype=float32), 'agent-1': array([-0.91787934,  1.        ,  1.        ], dtype=float32), 'agent-2': array([-0.15176296,  0.15703273,  0.        ], dtype=float32)}
# reward:  {'agent-0': 0.8312757423563681, 'agent-1': 0.9999973665604536, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 0.81421185, -1.        ,  1.        ], dtype=float32), 'agent-1': array([-0.33597493,  0.9794047 ,  0.9251183 ], dtype=float32), 'agent-2': array([ 0.62153864, -1.        ,  0.6069146 ], dtype=float32)}
# reward:  {'agent-0': 0.6324988489459216, 'agent-1': 0.845882322323483, 'agent-2': 0.6006224428090361}
#
# action:  {'agent-0': array([-0.8719407, -1.       ,  0.       ], dtype=float32), 'agent-1': array([-1.,  1.,  1.], dtype=float32), 'agent-2': array([-0.37462163,  0.16420662,  0.23505175], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': 0.9995053699839431, 'agent-2': -0.17197845497646647}
#
# action:  {'agent-0': array([-0.05931079, -1.        ,  0.3358115 ], dtype=float32), 'agent-1': array([-1.       ,  1.       ,  0.8146734], dtype=float32), 'agent-2': array([1.       , 1.       , 0.7003602], dtype=float32)}
# reward:  {'agent-0': 0.33108450779194953, 'agent-1': 0.8142399726730716, 'agent-2': -0.23809418846223185}
#
# action:  {'agent-0': array([ 0.25061512, -0.4433902 ,  1.        ], dtype=float32), 'agent-1': array([-1.        ,  0.33870673,  1.        ], dtype=float32), 'agent-2': array([ 0.83911276, -1.        ,  0.83129406], dtype=float32)}
# reward:  {'agent-0': 0.7216143582581971, 'agent-1': 0.8765638963906319, 'agent-2': 0.813405473379075}
#
# action:  {'agent-0': array([ 0.756832 , -0.7985617,  1.       ], dtype=float32), 'agent-1': array([-0.35878968,  1.        ,  1.        ], dtype=float32), 'agent-2': array([ 0.12642252, -0.27420044,  0.6118848 ], dtype=float32)}
# reward:  {'agent-0': 0.49019241207171227, 'agent-1': 0.9227187362265283, 'agent-2': 0.6105495542702446}
#
# action:  {'agent-0': array([-0.23866093, -0.4344356 ,  0.51849747], dtype=float32), 'agent-1': array([-1.       ,  0.7982867,  1.       ], dtype=float32), 'agent-2': array([ 0.38965607, -1.        ,  0.79189646], dtype=float32)}
# reward:  {'agent-0': 0.5103891970752308, 'agent-1': 0.9885094496910263, 'agent-2': 0.5061540340859949}
#
# action:  {'agent-0': array([ 0.47611952, -0.54003954,  0.3822817 ], dtype=float32), 'agent-1': array([-0.70895916,  0.3012613 ,  1.        ], dtype=float32), 'agent-2': array([ 0.5638852 , -1.        ,  0.30889422], dtype=float32)}
# reward:  {'agent-0': 0.18818372975272268, 'agent-1': 0.9059204693641476, 'agent-2': -0.3087830476990199}
#
# action:  {'agent-0': array([-0.5377185 , -0.24049908,  0.6271356 ], dtype=float32), 'agent-1': array([-1.        ,  0.48581958,  1.        ], dtype=float32), 'agent-2': array([-0.51293766,  1.        ,  1.        ], dtype=float32)}
# reward:  {'agent-0': 0.4272975530632568, 'agent-1': 0.9183047555634012, 'agent-2': -0.10223450904508269}
#
# action:  {'agent-0': array([-0.45922506, -0.09042114,  0.6732774 ], dtype=float32), 'agent-1': array([-0.45210046,  1.        ,  1.        ], dtype=float32), 'agent-2': array([-0.14194554, -0.884094  ,  0.12452155], dtype=float32)}
# reward:  {'agent-0': 0.31453172093658743, 'agent-1': 0.9598957687251506, 'agent-2': 0.09960641461148256}
#
# action:  {'agent-0': array([-0.2834109, -0.8892183,  0.8569732], dtype=float32), 'agent-1': array([-1.        ,  0.91664445,  0.7772607 ], dtype=float32), 'agent-2': array([-0.6114359, -0.6690958,  0.       ], dtype=float32)}
# reward:  {'agent-0': 0.8563021381146942, 'agent-1': 0.7721244454010616, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 0.81296146, -0.68938065,  0.31697387], dtype=float32), 'agent-1': array([-0.658644,  1.      ,  1.      ], dtype=float32), 'agent-2': array([ 1.       , -1.       ,  0.7705211], dtype=float32)}
# reward:  {'agent-0': 0.13053846774287692, 'agent-1': 0.9912067713410337, 'agent-2': 0.16533773523281958}
#
# action:  {'agent-0': array([-0.31696266,  0.5262929 ,  0.67578983], dtype=float32), 'agent-1': array([-1.        ,  1.        ,  0.90975344], dtype=float32), 'agent-2': array([-1.        ,  0.07431698,  0.66225994], dtype=float32)}
# reward:  {'agent-0': -0.46439052672036496, 'agent-1': 0.9076366225197869, 'agent-2': 0.22637740208264567}
#
# action:  {'agent-0': array([-1.       , -1.       ,  0.5877345], dtype=float32), 'agent-1': array([-1.        ,  0.30060732,  1.        ], dtype=float32), 'agent-2': array([ 1.       , -1.       ,  0.5723381], dtype=float32)}
# reward:  {'agent-0': 0.5027336503587332, 'agent-1': 0.835779996596834, 'agent-2': -0.4221324348498694}
#
# action:  {'agent-0': array([0.09396648, 0.522158  , 0.34892702], dtype=float32), 'agent-1': array([-1.        ,  0.68090427,  0.53147805], dtype=float32), 'agent-2': array([0.6629189, 1.       , 1.       ], dtype=float32)}
# reward:  {'agent-0': -0.34848507035323983, 'agent-1': 0.5079069606688407, 'agent-2': 5.952542641541747}
#
# action:  {'agent-0': array([ 0.17784, -1.     ,  1.     ], dtype=float32), 'agent-1': array([-1.       ,  0.2893312,  0.6339504], dtype=float32), 'agent-2': array([-0.68137825,  1.        ,  0.22020543], dtype=float32)}
# reward:  {'agent-0': 0.9132845068175239, 'agent-1': 0.5108857105909959, 'agent-2': -0.17489760834031642}
#
# action:  {'agent-0': array([ 0.4219774 , -0.16702342,  0.37350947], dtype=float32), 'agent-1': array([-1.,  1.,  1.], dtype=float32), 'agent-2': array([0.6604079 , 0.58189344, 0.9168594 ], dtype=float32)}
# reward:  {'agent-0': 0.037938811997985766, 'agent-1': 0.9889616128041663, 'agent-2': -0.11412642736640954}
#
# action:  {'agent-0': array([-0.99566066,  0.14159977,  0.        ], dtype=float32), 'agent-1': array([-1.        ,  1.        ,  0.91026044], dtype=float32), 'agent-2': array([-0.91766167,  0.22731018,  1.        ], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': 0.8986209037552708, 'agent-2': -0.7529088525020153}
#
# action:  {'agent-0': array([-0.21550989, -1.        ,  0.00458616], dtype=float32), 'agent-1': array([-0.32011747, -0.14159375,  0.        ], dtype=float32), 'agent-2': array([ 0.04277313, -0.01739717,  0.        ], dtype=float32)}
# reward:  {'agent-0': 0.004572162378581268, 'agent-1': 0.0, 'agent-2': 0.0}
#
# action:  {'agent-0': array([-0.40430862, -0.7674067 ,  1.        ], dtype=float32), 'agent-1': array([-1.       ,  0.7437438,  1.       ], dtype=float32), 'agent-2': array([-1., -1.,  0.], dtype=float32)}
# reward:  {'agent-0': 0.9794808611778336, 'agent-1': 0.9474742104223441, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 0.18825018, -0.9127367 ,  0.3917135 ], dtype=float32), 'agent-1': array([-1.        , -0.00695503,  0.53300893], dtype=float32), 'agent-2': array([1.        , 0.48332357, 0.38263735], dtype=float32)}
# reward:  {'agent-0': 0.34658120443248386, 'agent-1': 0.2849754045855466, 'agent-2': 0.05509984912698229}
#
# action:  {'agent-0': array([-0.7840748 ,  0.17980897,  0.40612125], dtype=float32), 'agent-1': array([ 0.16032457, -0.55772275,  0.831041  ], dtype=float32), 'agent-2': array([-1.       , -1.       ,  0.4602598], dtype=float32)}
# reward:  {'agent-0': 0.018501848199518278, 'agent-1': -0.8029871250391931, 'agent-2': 0.08902041018822615}
#
# action:  {'agent-0': array([-0.6482998, -1.       ,  0.9215641], dtype=float32), 'agent-1': array([-1.        ,  0.28539014,  0.11554861], dtype=float32), 'agent-2': array([-0.88401365, -0.8470124 ,  0.92819154], dtype=float32)}
# reward:  {'agent-0': 0.7666513391801715, 'agent-1': 0.0833387532489347, 'agent-2': 0.22736122052732277}
#
# action:  {'agent-0': array([-1.        , -0.4119112 ,  0.11256355], dtype=float32), 'agent-1': array([0.2649312 , 0.83637834, 0.50480986], dtype=float32), 'agent-2': array([-0.92189723,  1.        ,  0.8493713 ], dtype=float32)}
# reward:  {'agent-0': -0.06438631282571272, 'agent-1': 0.33411985614177375, 'agent-2': -0.8138447378775648}
#
# action:  {'agent-0': array([-0.62577546, -0.16982675,  0.19541991], dtype=float32), 'agent-1': array([-0.5433628,  1.       ,  0.3401883], dtype=float32), 'agent-2': array([-0.8915739, -1.       ,  1.       ], dtype=float32)}
# reward:  {'agent-0': -0.08845328621702464, 'agent-1': 0.3395602742108803, 'agent-2': 0.43888721545021525}
#
# action:  {'agent-0': array([-0.70984924, -1.        ,  0.92282176], dtype=float32), 'agent-1': array([0.13930607, 0.66246736, 0.23663324], dtype=float32), 'agent-2': array([ 0.4621837, -1.       ,  0.3009618], dtype=float32)}
# reward:  {'agent-0': -0.8341090537611784, 'agent-1': 0.16915423083344194, 'agent-2': 0.29963229306695105}
#
# action:  {'agent-0': array([1., 1., 1.], dtype=float32), 'agent-1': array([-1.      ,  0.565784,  0.      ], dtype=float32), 'agent-2': array([-0.04694164, -0.87280405,  0.3024625 ], dtype=float32)}
# reward:  {'agent-0': 0.8248564221114627, 'agent-1': 0.0, 'agent-2': 0.2799760523073651}
#
# action:  {'agent-0': array([-0.25245893,  0.11657083,  0.46085882], dtype=float32), 'agent-1': array([-1.        ,  0.95769465,  0.12382361], dtype=float32), 'agent-2': array([-0.28902793,  0.5056331 ,  0.        ], dtype=float32)}
# reward:  {'agent-0': 0.11013046698855611, 'agent-1': 0.12046432198736312, 'agent-2': 0.0}
#
# action:  {'agent-0': array([-0.10346687,  0.5227463 ,  0.3704474 ], dtype=float32), 'agent-1': array([-1.        ,  0.6173061 ,  0.80567104], dtype=float32), 'agent-2': array([ 1.       , -0.4166289,  0.       ], dtype=float32)}
# reward:  {'agent-0': -0.14012105495813643, 'agent-1': 0.31252684358169525, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 1., -1.,  0.], dtype=float32), 'agent-1': array([-0.20274287,  0.2657652 ,  0.79399896], dtype=float32), 'agent-2': array([-0.8492268 , -1.        ,  0.05057198], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': -0.788297942199641, 'agent-2': 0.026035064747057746}
#
# action:  {'agent-0': array([ 0.35074532, -0.9270078 ,  0.30166876], dtype=float32), 'agent-1': array([-0.5425361,  1.       ,  0.6155179], dtype=float32), 'agent-2': array([-0.3015753 , -0.19461465,  0.41837522], dtype=float32)}
# reward:  {'agent-0': 6.728313939533537, 'agent-1': -0.6152300514411593, 'agent-2': 0.1117832819020208}
#
# action:  {'agent-0': array([ 0.4279691 , -0.11291355,  0.5664774 ], dtype=float32), 'agent-1': array([ 1., -1.,  0.], dtype=float32), 'agent-2': array([-1.        , -0.8759501 ,  0.14497352], dtype=float32)}
# reward:  {'agent-0': -0.033365517469807315, 'agent-1': 0.0, 'agent-2': 0.062336784929065914}
#
# action:  {'agent-0': array([-0.42779815, -0.5839232 ,  0.5570845 ], dtype=float32), 'agent-1': array([0.95358133, 0.30726504, 0.0218575 ], dtype=float32), 'agent-2': array([1.        , 0.20195532, 0.0611726 ], dtype=float32)}
# reward:  {'agent-0': -0.5094960923707124, 'agent-1': 0.004734426210980303, 'agent-2': 0.004400958830087731}
#
# action:  {'agent-0': array([ 1.        , -0.40022343,  0.7667674 ], dtype=float32), 'agent-1': array([-0.32864988, -0.46109676,  0.00596648], dtype=float32), 'agent-2': array([-0.14788365,  0.7624159 ,  0.98494273], dtype=float32)}
# reward:  {'agent-0': -0.10408341588160219, 'agent-1': 0.0024359540028164872, 'agent-2': -0.9811855650332078}
#
# action:  {'agent-0': array([-1.        ,  1.        ,  0.39217266], dtype=float32), 'agent-1': array([-0.10130894, -0.4694773 ,  0.        ], dtype=float32), 'agent-2': array([ 0.6883613, -1.       ,  0.7962464], dtype=float32)}
# reward:  {'agent-0': 0.19432781995357296, 'agent-1': 0.0, 'agent-2': 0.7593319092268054}
#
# action:  {'agent-0': array([1.        , 0.21307659, 0.7405996 ], dtype=float32), 'agent-1': array([ 1.        , -0.10082698,  1.        ], dtype=float32), 'agent-2': array([ 0.8488009 , -0.55350006,  0.47829288], dtype=float32)}
# reward:  {'agent-0': 0.35041959190098737, 'agent-1': 0.6262635481195886, 'agent-2': 0.3756542774425782}
#
# action:  {'agent-0': array([-1.        , -0.10083848,  0.5771721 ], dtype=float32), 'agent-1': array([1.        , 0.48230863, 1.        ], dtype=float32), 'agent-2': array([-1.        ,  1.        ,  0.19644493], dtype=float32)}
# reward:  {'agent-0': -0.21920980145575442, 'agent-1': 0.22266886251003548, 'agent-2': -0.17696597792291868}
#
# action:  {'agent-0': array([0.70386505, 0.2615844 , 0.61596197], dtype=float32), 'agent-1': array([-0.01874876, -0.69867307,  0.        ], dtype=float32), 'agent-2': array([-0.44052613, -1.        ,  0.7744096 ], dtype=float32)}
# reward:  {'agent-0': 4.251103470836467, 'agent-1': 0.0, 'agent-2': 0.032137388452568416}
#
# action:  {'agent-0': array([ 0.65824234, -0.8285631 ,  0.49547374], dtype=float32), 'agent-1': array([-0.13749981, -0.4309504 ,  0.        ], dtype=float32), 'agent-2': array([-1.        , -0.24924147,  0.44910544], dtype=float32)}
# reward:  {'agent-0': -0.2054556895361639, 'agent-1': 0.0, 'agent-2': 0.006548618873575052}
#
# action:  {'agent-0': array([-0.10961705,  0.11419344,  0.33927286], dtype=float32), 'agent-1': array([-0.19352913, -1.        ,  1.        ], dtype=float32), 'agent-2': array([-0.88783526,  0.78669226,  0.7338425 ], dtype=float32)}
# reward:  {'agent-0': 0.15285283714929143, 'agent-1': 0.6392506937321905, 'agent-2': -0.05639991024118629}
#
# action:  {'agent-0': array([ 1.        , -0.78772247,  1.        ], dtype=float32), 'agent-1': array([-1.        ,  0.32747185,  0.        ], dtype=float32), 'agent-2': array([ 1.        , -0.06850648,  0.564708  ], dtype=float32)}
# reward:  {'agent-0': -0.2911658973976792, 'agent-1': 0.0, 'agent-2': 0.161398094156171}
#
# action:  {'agent-0': array([ 0.799489  , -0.24669552,  0.        ], dtype=float32), 'agent-1': array([-0.2890901, -1.       ,  0.5075751], dtype=float32), 'agent-2': array([-0.05024374, -0.9585722 ,  0.54280806], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': -0.08768536427097295, 'agent-2': -0.19306724861642977}
#
# action:  {'agent-0': array([-1.        , -0.21398115,  0.7873866 ], dtype=float32), 'agent-1': array([0.40992248, 0.02137649, 0.96693796], dtype=float32), 'agent-2': array([-1.        , -0.30083638,  0.45036975], dtype=float32)}
# reward:  {'agent-0': -0.443092624988207, 'agent-1': -0.5407083039555616, 'agent-2': -0.0361564836951942}
#
# action:  {'agent-0': array([-1.        ,  0.55182827,  1.        ], dtype=float32), 'agent-1': array([-1.       ,  0.1314292,  0.       ], dtype=float32), 'agent-2': array([-1.        , -0.20835298,  0.794152  ], dtype=float32)}
# reward:  {'agent-0': 0.20397758778731223, 'agent-1': 0.0, 'agent-2': -0.04230934809839759}
#
# action:  {'agent-0': array([0.4981358 , 1.        , 0.73720205], dtype=float32), 'agent-1': array([-1.       ,  0.8522308,  0.6563279], dtype=float32), 'agent-2': array([-0.17537546,  0.5617728 ,  0.24940115], dtype=float32)}
# reward:  {'agent-0': 0.5050048799639733, 'agent-1': 0.6448287927214285, 'agent-2': 0.24487479428606207}
#
# action:  {'agent-0': array([-0.0358851, -0.7684916,  0.9753052], dtype=float32), 'agent-1': array([ 1.       , -0.9295959,  1.       ], dtype=float32), 'agent-2': array([-1.       ,  1.       ,  0.5415614], dtype=float32)}
# reward:  {'agent-0': -0.7340784673982519, 'agent-1': -0.9897388328871983, 'agent-2': -0.036779121041680796}
#
# action:  {'agent-0': array([ 0.6599765 , -0.56499887,  0.46371305], dtype=float32), 'agent-1': array([0.980628  , 0.9929061 , 0.13827151], dtype=float32), 'agent-2': array([-0.71927005, -0.14711124,  0.6063019 ], dtype=float32)}
# reward:  {'agent-0': -0.18050834416832728, 'agent-1': 0.01384916048856688, 'agent-2': 0.09510164995621295}
#
# action:  {'agent-0': array([-0.26336432, -0.00533044,  0.6680193 ], dtype=float32), 'agent-1': array([0.19333482, 0.1778512 , 1.        ], dtype=float32), 'agent-2': array([-0.23037344,  0.16654956,  0.        ], dtype=float32)}
# reward:  {'agent-0': -0.20792904601635875, 'agent-1': 0.0010291702623419496, 'agent-2': 0.0}
#
# action:  {'agent-0': array([0.33867538, 1.        , 1.        ], dtype=float32), 'agent-1': array([-0.55911833,  1.        ,  0.991855  ], dtype=float32), 'agent-2': array([-1., -1.,  1.], dtype=float32)}
# reward:  {'agent-0': 0.9980300923121614, 'agent-1': 0.9501007787008025, 'agent-2': -0.45836191634803747}
#
# action:  {'agent-0': array([-0.654447,  1.      ,  1.      ], dtype=float32), 'agent-1': array([ 0.41845787, -1.        ,  1.        ], dtype=float32), 'agent-2': array([-0.05949891, -1.        ,  1.        ], dtype=float32)}
# reward:  {'agent-0': -0.22411501370451958, 'agent-1': -0.9212016431628296, 'agent-2': -0.9999861188574872}
#
# action:  {'agent-0': array([ 1.        , -1.        ,  0.23578203], dtype=float32), 'agent-1': array([-1.        , -1.        ,  0.20062235], dtype=float32), 'agent-2': array([0.20384693, 1.        , 0.19792703], dtype=float32)}
# reward:  {'agent-0': 0.12932497582779234, 'agent-1': -0.0033159857961742034, 'agent-2': 0.19576434489853511}
#
# action:  {'agent-0': array([-0.660534  , -0.08338797,  0.70208174], dtype=float32), 'agent-1': array([1.       , 1.       , 0.5981949], dtype=float32), 'agent-2': array([-1.        ,  0.7602098 ,  0.15856451], dtype=float32)}
# reward:  {'agent-0': 0.2124091821832934, 'agent-1': -0.0008802340909426221, 'agent-2': 0.08853065659790715}
#
# action:  {'agent-0': array([ 0.4535302 , -0.221807  ,  0.36068332], dtype=float32), 'agent-1': array([-0.05276364, -0.42516446,  0.6433723 ], dtype=float32), 'agent-2': array([-0.93396664,  0.19472909,  1.        ], dtype=float32)}
# reward:  {'agent-0': 7.645080179388776, 'agent-1': -0.3925530627054048, 'agent-2': 0.09782830517864305}
#
# action:  {'agent-0': array([-1.        , -1.        ,  0.03143477], dtype=float32), 'agent-1': array([0.55056286, 0.84075236, 0.6059467 ], dtype=float32), 'agent-2': array([0.2257024 , 0.7132251 , 0.24272549], dtype=float32)}
# reward:  {'agent-0': 7.2784072234920565, 'agent-1': 0.11822935869486528, 'agent-2': 0.2397668871505747}
#
# action:  {'agent-0': array([ 0.3648305, -1.       ,  0.6466093], dtype=float32), 'agent-1': array([ 0.81391275, -0.31953245,  1.        ], dtype=float32), 'agent-2': array([-0.49201357,  1.        ,  0.        ], dtype=float32)}
# reward:  {'agent-0': -0.5517955727719563, 'agent-1': -0.9356890088310976, 'agent-2': 0.0}
#
# action:  {'agent-0': array([0.13873339, 0.68370724, 0.80428755], dtype=float32), 'agent-1': array([ 1.       , -0.5420776,  1.       ], dtype=float32), 'agent-2': array([0.16685331, 0.16430044, 0.7505398 ], dtype=float32)}
# reward:  {'agent-0': 0.3266009552553637, 'agent-1': -0.9770313073053973, 'agent-2': 0.5901177628686405}
#
# action:  {'agent-0': array([ 0.00299573, -1.        ,  0.65922487], dtype=float32), 'agent-1': array([-1.        ,  1.        ,  0.84171224], dtype=float32), 'agent-2': array([ 0.20266247, -0.6500685 ,  0.75855464], dtype=float32)}
# reward:  {'agent-0': -0.16498454228407589, 'agent-1': 0.8386832974344856, 'agent-2': -0.7006013055993119}
#
# action:  {'agent-0': array([ 0.7237983 , -0.63868773,  0.73556805], dtype=float32), 'agent-1': array([-1.       ,  1.       ,  0.5799873], dtype=float32), 'agent-2': array([-0.15969175,  0.00361407,  0.6816908 ], dtype=float32)}
# reward:  {'agent-0': -0.3256141835077475, 'agent-1': 0.5776495221837266, 'agent-2': -0.058466350929984756}
#
# action:  {'agent-0': array([-0.05809253,  0.30854082,  0.11694711], dtype=float32), 'agent-1': array([-1.        ,  1.        ,  0.14385045], dtype=float32), 'agent-2': array([-0.4791155,  1.       ,  1.       ], dtype=float32)}
# reward:  {'agent-0': 0.1035748154232472, 'agent-1': 0.14323474476108444, 'agent-2': 0.818425774038193}
#
# action:  {'agent-0': array([0.6871424 , 0.06933999, 0.50650656], dtype=float32), 'agent-1': array([-0.8107617 ,  0.4411502 ,  0.25460505], dtype=float32), 'agent-2': array([1.        , 0.33794892, 0.22068805], dtype=float32)}
# reward:  {'agent-0': 0.20607236334612544, 'agent-1': 0.24972549454615667, 'agent-2': 0.10757732689520516}
#
# action:  {'agent-0': array([-0.23715723, -0.5652697 ,  0.87733376], dtype=float32), 'agent-1': array([-1.        , -0.48896003,  1.        ], dtype=float32), 'agent-2': array([1.        , 1.        , 0.99213374], dtype=float32)}
# reward:  {'agent-0': -0.8758984725435397, 'agent-1': 0.3694628986433912, 'agent-2': -0.37308780841254396}
#
# action:  {'agent-0': array([0.21196914, 0.82173693, 1.        ], dtype=float32), 'agent-1': array([1.       , 1.       , 0.3567801], dtype=float32), 'agent-2': array([ 0.8662604 , -0.28575635,  0.37072062], dtype=float32)}
# reward:  {'agent-0': 0.9967784711981693, 'agent-1': -0.007935414184480294, 'agent-2': 0.08250879755107121}
#
# action:  {'agent-0': array([0.26777554, 0.84350836, 0.4121071 ], dtype=float32), 'agent-1': array([0.916476 , 0.7301973, 0.739053 ], dtype=float32), 'agent-2': array([ 0.24463499, -0.1192525 ,  0.        ], dtype=float32)}
# reward:  {'agent-0': 0.18571602767323725, 'agent-1': -0.13504715701018633, 'agent-2': 0.0}
#
# action:  {'agent-0': array([-0.18426573, -1.        ,  0.15133381], dtype=float32), 'agent-1': array([1.       , 1.       , 0.6071913], dtype=float32), 'agent-2': array([0.32532513, 1.        , 0.91496783], dtype=float32)}
# reward:  {'agent-0': 2.7643898493222907, 'agent-1': -0.07901710907752602, 'agent-2': -0.8861393415246024}
#
# action:  {'agent-0': array([0.17000842, 0.30384684, 0.1837362 ], dtype=float32), 'agent-1': array([ 1.        , -1.        ,  0.58859235], dtype=float32), 'agent-2': array([ 1.        , -0.13986647,  0.01718187], dtype=float32)}
# reward:  {'agent-0': -0.10768971581750364, 'agent-1': -0.5816883630939831, 'agent-2': 0.0015448035993106402}
#
# action:  {'agent-0': array([0.26468408, 0.1557405 , 0.06070602], dtype=float32), 'agent-1': array([-0.65819   ,  0.95167387,  0.5752628 ], dtype=float32), 'agent-2': array([-0.17036915,  0.76214623,  0.        ], dtype=float32)}
# reward:  {'agent-0': -0.046276399714113126, 'agent-1': 0.5427264530918823, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 1.        , -0.43715096,  0.26335567], dtype=float32), 'agent-1': array([-0.42428082,  1.        ,  0.        ], dtype=float32), 'agent-2': array([-1.        ,  0.03597426,  1.        ], dtype=float32)}
# reward:  {'agent-0': 0.016388140708590626, 'agent-1': 0.0, 'agent-2': 0.06974594226387865}
#
# action:  {'agent-0': array([-0.6738452 ,  0.05669248,  0.        ], dtype=float32), 'agent-1': array([0.07858348, 1.        , 0.        ], dtype=float32), 'agent-2': array([ 0.89053106, -0.01909673,  0.        ], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': 0.0, 'agent-2': 0.0}
#
# action:  {'agent-0': array([-0.83791137, -0.32430196,  0.0413003 ], dtype=float32), 'agent-1': array([-1.       ,  0.8440962,  0.8054148], dtype=float32), 'agent-2': array([ 0.8320968, -1.       ,  0.7368957], dtype=float32)}
# reward:  {'agent-0': 0.02755821056284624, 'agent-1': 0.8025298263393505, 'agent-2': 0.4991721294315514}
#
# action:  {'agent-0': array([0.9283745 , 0.18347168, 0.3565866 ], dtype=float32), 'agent-1': array([-0.26086795,  1.        ,  0.        ], dtype=float32), 'agent-2': array([-0.37648916, -0.4126451 ,  0.5203326 ], dtype=float32)}
# reward:  {'agent-0': -0.19229804597863165, 'agent-1': 0.0, 'agent-2': 0.4232802046686608}
#
# action:  {'agent-0': array([-1.        , -1.        ,  0.77913404], dtype=float32), 'agent-1': array([1., 1., 1.], dtype=float32), 'agent-2': array([ 0.8813944 , -0.54588926,  0.        ], dtype=float32)}
# reward:  {'agent-0': -0.03627571734751456, 'agent-1': -0.21666554574990293, 'agent-2': 0.0}
#
# action:  {'agent-0': array([-0.06705838, -1.        ,  0.39284384], dtype=float32), 'agent-1': array([-1.        , -1.        ,  0.34960067], dtype=float32), 'agent-2': array([0.17456412, 0.01376987, 0.9736787 ], dtype=float32)}
# reward:  {'agent-0': -0.37565968117825754, 'agent-1': 0.08592173367479106, 'agent-2': -0.1583352467919923}
#
# action:  {'agent-0': array([0.8284286 , 0.25406027, 0.6213063 ], dtype=float32), 'agent-1': array([0.15650845, 0.58591616, 0.41561195], dtype=float32), 'agent-2': array([-0.00348473, -0.8266379 ,  0.9437647 ], dtype=float32)}
# reward:  {'agent-0': 0.3969766036371478, 'agent-1': 0.11209653875939196, 'agent-2': 0.1612362558369238}
#
# action:  {'agent-0': array([-0.21712494,  0.33629417,  0.05067533], dtype=float32), 'agent-1': array([-0.73239696,  1.        ,  1.        ], dtype=float32), 'agent-2': array([-0.72126025, -0.79676986,  1.        ], dtype=float32)}
# reward:  {'agent-0': 0.02773339416723175, 'agent-1': 0.15996820191991645, 'agent-2': -0.780765696294262}
#
# action:  {'agent-0': array([-0.37703502, -0.13980329,  0.        ], dtype=float32), 'agent-1': array([1.        , 1.        , 0.70503086], dtype=float32), 'agent-2': array([1.        , 0.65968466, 1.        ], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': 0.2398618040741507, 'agent-2': 0.5939116567577187}
#
# action:  {'agent-0': array([-0.10370934, -0.09987921,  0.5296118 ], dtype=float32), 'agent-1': array([1.        , 0.29027402, 0.09998256], dtype=float32), 'agent-2': array([-0.7627539,  1.       ,  0.       ], dtype=float32)}
# reward:  {'agent-0': -0.4880553677459716, 'agent-1': 0.0775064337104947, 'agent-2': 0.0}
#
# action:  {'agent-0': array([0.63634217, 1.        , 1.        ], dtype=float32), 'agent-1': array([0.02147925, 0.54604053, 0.32365662], dtype=float32), 'agent-2': array([-0.11289465, -0.32726526,  0.19031745], dtype=float32)}
# reward:  {'agent-0': 0.6416869701194834, 'agent-1': -0.10897029901160415, 'agent-2': -0.18100189917666398}
#
# action:  {'agent-0': array([-0.3141656, -1.       ,  0.       ], dtype=float32), 'agent-1': array([-1., -1.,  0.], dtype=float32), 'agent-2': array([1.        , 0.6902833 , 0.74526817], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': 0.0, 'agent-2': 0.4183319320017507}
#
# action:  {'agent-0': array([ 1.        , -0.7740494 ,  0.89671385], dtype=float32), 'agent-1': array([0.12521803, 1.        , 0.        ], dtype=float32), 'agent-2': array([-0.67209554,  0.6135328 ,  0.7597333 ], dtype=float32)}
# reward:  {'agent-0': 8.305377639950464, 'agent-1': 0.0, 'agent-2': 0.16311617988708704}
#
# action:  {'agent-0': array([-0.48763448, -0.39179617,  0.5124052 ], dtype=float32), 'agent-1': array([ 0.3769436, -1.       ,  1.       ], dtype=float32), 'agent-2': array([-0.1116935 ,  0.00303054,  0.5609011 ], dtype=float32)}
# reward:  {'agent-0': -0.47078555095743724, 'agent-1': -0.36556732579724205, 'agent-2': 0.010561738542255839}
#
# action:  {'agent-0': array([0.64305997, 1.        , 0.4327577 ], dtype=float32), 'agent-1': array([-0.6109104,  0.6966876,  1.       ], dtype=float32), 'agent-2': array([ 1., -1.,  0.], dtype=float32)}
# reward:  {'agent-0': 0.6031425577529769, 'agent-1': 0.14956443565101019, 'agent-2': 0.0}
#
# action:  {'agent-0': array([-1.,  1.,  1.], dtype=float32), 'agent-1': array([-1.        , -0.97295433,  0.74393284], dtype=float32), 'agent-2': array([0.95240355, 0.2511549 , 0.        ], dtype=float32)}
# reward:  {'agent-0': -0.24509665472454145, 'agent-1': -0.2663815337706943, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 0.22486591, -0.52779055,  0.21754584], dtype=float32), 'agent-1': array([ 1.        , -1.        ,  0.63999206], dtype=float32), 'agent-2': array([-0.3186854 , -0.07816851,  1.        ], dtype=float32)}
# reward:  {'agent-0': 0.15168532568060478, 'agent-1': 3.593011757245977, 'agent-2': -0.020460439452225643}
#
# action:  {'agent-0': array([ 0.03733635, -0.88228   ,  0.5738836 ], dtype=float32), 'agent-1': array([-1.        , -1.        ,  0.67472506], dtype=float32), 'agent-2': array([-0.63232785, -0.28049445,  0.6135348 ], dtype=float32)}
# reward:  {'agent-0': -0.229352031351711, 'agent-1': -0.17530993372010784, 'agent-2': -0.3514426921276712}
#
# action:  {'agent-0': array([ 0.14014792, -0.21544689,  0.32729426], dtype=float32), 'agent-1': array([0.0785315, 0.6349683, 1.       ], dtype=float32), 'agent-2': array([-0.12353206,  0.7036153 ,  0.        ], dtype=float32)}
# reward:  {'agent-0': -0.17097316316464095, 'agent-1': -0.3753928679971992, 'agent-2': 0.0}
#
# action:  {'agent-0': array([1.        , 1.        , 0.78983724], dtype=float32), 'agent-1': array([-0.12810314, -1.        ,  0.        ], dtype=float32), 'agent-2': array([0.4059131 , 0.46049416, 1.        ], dtype=float32)}
# reward:  {'agent-0': 0.3344454124280478, 'agent-1': 0.0, 'agent-2': 0.2150997970311046}
#
# action:  {'agent-0': array([ 0.7781651, -1.       ,  1.       ], dtype=float32), 'agent-1': array([-1.,  1.,  1.], dtype=float32), 'agent-2': array([-0.7934833, -0.3695191,  1.       ], dtype=float32)}
# reward:  {'agent-0': 0.04625041444496247, 'agent-1': -0.9411733022970132, 'agent-2': 0.04788658985293459}
#
# action:  {'agent-0': array([0.8791503 , 0.08635736, 0.42071393], dtype=float32), 'agent-1': array([0.93244386, 1.        , 1.        ], dtype=float32), 'agent-2': array([0.74543893, 0.4382758 , 0.6918883 ], dtype=float32)}
# reward:  {'agent-0': 0.05626259901550945, 'agent-1': 0.3740256081291413, 'agent-2': 0.07837724175849736}
#
# action:  {'agent-0': array([ 1.       , -0.7486669,  0.8773657], dtype=float32), 'agent-1': array([1., 1., 1.], dtype=float32), 'agent-2': array([0.33193314, 0.07938623, 1.        ], dtype=float32)}
# reward:  {'agent-0': -0.008697991876651656, 'agent-1': 0.4966185427154226, 'agent-2': -0.3740236792102003}
#
# action:  {'agent-0': array([-0.4901629 , -0.95961   ,  0.12321526], dtype=float32), 'agent-1': array([1.        , 0.33771396, 1.        ], dtype=float32), 'agent-2': array([0.10560846, 0.6635673 , 0.38785642], dtype=float32)}
# reward:  {'agent-0': 9.010624233145302, 'agent-1': 0.4440055069858708, 'agent-2': -0.38717718959214587}
#
# action:  {'agent-0': array([-0.2524928,  0.5830407,  0.5817386], dtype=float32), 'agent-1': array([-1., -1.,  1.], dtype=float32), 'agent-2': array([-0.6330366 , -0.31921124,  0.5918055 ], dtype=float32)}
# reward:  {'agent-0': -0.26225765377961174, 'agent-1': -0.11995090899182159, 'agent-2': 0.3299248445519112}
#
# action:  {'agent-0': array([-0.6957983 , -0.14888752,  0.00824082], dtype=float32), 'agent-1': array([0.17719972, 0.39072013, 0.07534826], dtype=float32), 'agent-2': array([ 0.2826388 , -0.42084908,  1.        ], dtype=float32)}
# reward:  {'agent-0': 0.006237306663678055, 'agent-1': 0.013289659670318699, 'agent-2': 0.4978960420035534}
#
# action:  {'agent-0': array([-0.6127288 , -1.        ,  0.30389032], dtype=float32), 'agent-1': array([ 1., -1.,  1.], dtype=float32), 'agent-2': array([ 1.       , -0.9311483,  1.       ], dtype=float32)}
# reward:  {'agent-0': 2.04400938799847, 'agent-1': -0.23193665311463363, 'agent-2': -0.6463910440917502}
#
# action:  {'agent-0': array([-1.       , -0.8268138,  0.4474806], dtype=float32), 'agent-1': array([ 0.80254626, -1.        ,  1.        ], dtype=float32), 'agent-2': array([1.        , 0.61029124, 0.21313807], dtype=float32)}
# reward:  {'agent-0': -0.4352058814346833, 'agent-1': -0.8387885532893797, 'agent-2': 0.11148872917487829}
#
# action:  {'agent-0': array([0.15529656, 0.06213546, 0.5367285 ], dtype=float32), 'agent-1': array([ 1.       , -1.       ,  0.2946498], dtype=float32), 'agent-2': array([0.96370363, 0.52843094, 0.669539  ], dtype=float32)}
# reward:  {'agent-0': 7.522900471240291, 'agent-1': -0.26698092686145536, 'agent-2': 0.3016444152019524}
#
# action:  {'agent-0': array([ 0.19288158, -1.        ,  0.36028555], dtype=float32), 'agent-1': array([-1.        , -0.9896867 ,  0.40181923], dtype=float32), 'agent-2': array([-1.       ,  0.4328494,  0.       ], dtype=float32)}
# reward:  {'agent-0': -0.23168519158217826, 'agent-1': 0.16415817892004902, 'agent-2': 0.0}
#
# action:  {'agent-0': array([-0.69513345,  1.        ,  1.        ], dtype=float32), 'agent-1': array([-0.6108191,  0.2013104,  1.       ], dtype=float32), 'agent-2': array([-0.20031542,  0.5055556 ,  1.        ], dtype=float32)}
# reward:  {'agent-0': 0.18210382817746762, 'agent-1': 0.997523174491727, 'agent-2': -0.21770546592665418}
#
# action:  {'agent-0': array([1.        , 0.5676763 , 0.42139897], dtype=float32), 'agent-1': array([-0.20420611, -1.        ,  0.20474714], dtype=float32), 'agent-2': array([-1.       , -0.6011018,  0.       ], dtype=float32)}
# reward:  {'agent-0': -0.3802343877281391, 'agent-1': -0.040706991970692386, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 0.2728374 , -1.        ,  0.11771631], dtype=float32), 'agent-1': array([ 0.10735953, -0.679228  ,  1.        ], dtype=float32), 'agent-2': array([1.        , 1.        , 0.23734707], dtype=float32)}
# reward:  {'agent-0': 0.0742467113076124, 'agent-1': -0.5698926565226117, 'agent-2': -0.1611070953215119}
#
# action:  {'agent-0': array([-0.68772835,  0.22197199,  0.76319194], dtype=float32), 'agent-1': array([-0.29391098, -0.1735655 ,  1.        ], dtype=float32), 'agent-2': array([ 0.05519629, -1.        ,  0.30853656], dtype=float32)}
# reward:  {'agent-0': 0.2098689514979064, 'agent-1': 0.4886368223969022, 'agent-2': 0.30853030530064096}
#
# action:  {'agent-0': array([ 0.72029746, -0.79869896,  1.        ], dtype=float32), 'agent-1': array([-1.        ,  1.        ,  0.37357074], dtype=float32), 'agent-2': array([1.        , 0.36681175, 0.73298335], dtype=float32)}
# reward:  {'agent-0': 0.08896299172063671, 'agent-1': 0.3644171163910883, 'agent-2': -0.19234923373901047}
#
# action:  {'agent-0': array([-0.60683733, -0.28533614,  0.77584565], dtype=float32), 'agent-1': array([-0.25171173, -0.35008514,  0.        ], dtype=float32), 'agent-2': array([-0.72261906,  0.21927512,  0.        ], dtype=float32)}
# reward:  {'agent-0': -0.6814091500267718, 'agent-1': 0.0, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 0.9716487 , -0.13759834,  0.12210476], dtype=float32), 'agent-1': array([ 0.5171226, -0.2947713,  0.6034395], dtype=float32), 'agent-2': array([ 0.02070713, -1.        ,  0.81570023], dtype=float32)}
# reward:  {'agent-0': 0.05619005539126043, 'agent-1': -0.6029485354260053, 'agent-2': 0.44172732471017184}
#
# action:  {'agent-0': array([0.5543362, 0.8139204, 0.7009188], dtype=float32), 'agent-1': array([-0.21347785,  0.5607046 ,  0.74939203], dtype=float32), 'agent-2': array([-0.34318966, -0.6525236 ,  0.78523767], dtype=float32)}
# reward:  {'agent-0': 9.8854098078935, 'agent-1': 0.5866933256258484, 'agent-2': -0.6573414921119927}
#
# action:  {'agent-0': array([ 1.        , -0.41777778,  0.        ], dtype=float32), 'agent-1': array([1.        , 0.01271081, 1.        ], dtype=float32), 'agent-2': array([-1.        ,  0.40487802,  0.7551052 ], dtype=float32)}
# reward:  {'agent-0': 9.192797150738699, 'agent-1': -0.8762126334574507, 'agent-2': 0.31290111568887724}
#
# action:  {'agent-0': array([ 0.40124905, -0.7601025 ,  1.        ], dtype=float32), 'agent-1': array([0.07000995, 0.8498087 , 1.        ], dtype=float32), 'agent-2': array([1.        , 1.        , 0.30054906], dtype=float32)}
# reward:  {'agent-0': -0.3960800636627866, 'agent-1': 0.33659168187983823, 'agent-2': 0.20811799991358804}
#
# action:  {'agent-0': array([-1.        ,  1.        ,  0.78786594], dtype=float32), 'agent-1': array([-1.        , -1.        ,  0.47737247], dtype=float32), 'agent-2': array([0.24636078, 0.36011648, 1.        ], dtype=float32)}
# reward:  {'agent-0': 0.0864141663470317, 'agent-1': 0.17820702590538318, 'agent-2': -0.14655230523075247}
#
# action:  {'agent-0': array([ 0.06895041, -1.        ,  0.19330269], dtype=float32), 'agent-1': array([0.45679975, 1.        , 0.3383522 ], dtype=float32), 'agent-2': array([-0.7274216,  1.       ,  0.       ], dtype=float32)}
# reward:  {'agent-0': -0.14655012373076737, 'agent-1': -0.007048181475083126, 'agent-2': 0.0}
#
# action:  {'agent-0': array([ 0.18662131, -0.6922382 ,  0.38094637], dtype=float32), 'agent-1': array([ 0.2762723, -0.6053105,  1.       ], dtype=float32), 'agent-2': array([0.707428  , 0.92015636, 0.        ], dtype=float32)}
# reward:  {'agent-0': -0.22850938082321548, 'agent-1': -0.7515548563548116, 'agent-2': 0.0}
#
# action:  {'agent-0': array([-0.33643854, -1.        ,  0.4459104 ], dtype=float32), 'agent-1': array([-0.52772295,  1.        ,  1.        ], dtype=float32), 'agent-2': array([-0.44291568, -0.00367707,  0.2983185 ], dtype=float32)}
# reward:  {'agent-0': -0.4166124035598102, 'agent-1': 0.7894066962829669, 'agent-2': -0.02055624713359272}
#
# action:  {'agent-0': array([ 0.17742276, -1.        ,  1.        ], dtype=float32), 'agent-1': array([ 0.47714472, -1.        ,  1.        ], dtype=float32), 'agent-2': array([-1.        ,  0.9723847 ,  0.09841329], dtype=float32)}
# reward:  {'agent-0': -0.6066291227877283, 'agent-1': -0.7648956499566442, 'agent-2': -0.07259068981450945}
#
# action:  {'agent-0': array([-0.3127843,  1.       ,  0.5969839], dtype=float32), 'agent-1': array([-0.32086098, -0.11619538,  0.        ], dtype=float32), 'agent-2': array([1.       , 1.       , 0.6182607], dtype=float32)}
# reward:  {'agent-0': 0.2905635356944405, 'agent-1': 0.0, 'agent-2': -0.40092720374857826}
#
# action:  {'agent-0': array([-1.       , -1.       ,  0.7780303], dtype=float32), 'agent-1': array([-1.        ,  0.01625764,  0.637722  ], dtype=float32), 'agent-2': array([ 0.5758655 , -0.07540405,  0.09666666], dtype=float32)}
# reward:  {'agent-0': -0.7766535370369114, 'agent-1': 0.5740560564461727, 'agent-2': 0.023068430442258148}
#
# action:  {'agent-0': array([0.70224476, 1.        , 0.5454939 ], dtype=float32), 'agent-1': array([-1.       ,  1.       ,  0.4151472], dtype=float32), 'agent-2': array([-1.        , -0.01629448,  0.6919503 ], dtype=float32)}
# reward:  {'agent-0': 0.5423683791636025, 'agent-1': 0.3951365287723725, 'agent-2': -0.042521500494505204}
#
# action:  {'agent-0': array([1.       , 1.       , 0.3998826], dtype=float32), 'agent-1': array([0.58959293, 0.15906513, 1.        ], dtype=float32), 'agent-2': array([0.65636027, 0.49490106, 0.9029901 ], dtype=float32)}
# reward:  {'agent-0': 0.3989581494704506, 'agent-1': -0.7644350955190404, 'agent-2': -0.48242057883514633}
#
# action:  {'agent-0': array([0.14064717, 1.        , 0.19388032], dtype=float32), 'agent-1': array([-1.        ,  1.        ,  0.37880883], dtype=float32), 'agent-2': array([1., 1., 0.], dtype=float32)}
# reward:  {'agent-0': 0.16288784233948306, 'agent-1': 0.35120819363006284, 'agent-2': 0.0}
#
# action:  {'agent-0': array([-0.20908189,  0.8649925 ,  0.860096  ], dtype=float32), 'agent-1': array([-0.1740855,  0.7817826,  1.       ], dtype=float32), 'agent-2': array([-0.39724725, -0.52944696,  0.5101297 ], dtype=float32)}
# reward:  {'agent-0': 0.5301012259173721, 'agent-1': 0.5434563086427353, 'agent-2': 0.37322215230785893}
#
# action:  {'agent-0': array([ 0.52475536, -0.4194461 ,  0.5452614 ], dtype=float32), 'agent-1': array([-0.8272527 , -0.32628733,  0.9772621 ], dtype=float32), 'agent-2': array([-1.        ,  0.20145214,  0.30716556], dtype=float32)}
# reward:  {'agent-0': -0.006697227018005236, 'agent-1': -0.20310901826497663, 'agent-2': -0.08157767010791694}
#
# action:  {'agent-0': array([ 0.6581676 , -0.02317852,  0.53505623], dtype=float32), 'agent-1': array([ 0.59462404, -1.        ,  0.26041782], dtype=float32), 'agent-2': array([-1.        , -0.46524066,  0.16327661], dtype=float32)}
# reward:  {'agent-0': 0.33546503673377437, 'agent-1': 0.207986774770891, 'agent-2': 0.062183138905329116}
#
# action:  {'agent-0': array([-0.10328233,  0.58403707,  1.        ], dtype=float32), 'agent-1': array([0.7124922, 1.       , 0.       ], dtype=float32), 'agent-2': array([ 0.1730752 , -0.59521973,  0.6057614 ], dtype=float32)}
# reward:  {'agent-0': -0.1741371397872502, 'agent-1': 0.0, 'agent-2': 0.5885709141585238}
#
# action:  {'agent-0': array([-1.        ,  0.01229882,  0.        ], dtype=float32), 'agent-1': array([-1.,  1.,  0.], dtype=float32), 'agent-2': array([ 1.       , -0.9824152,  0.9068646], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': 0.0, 'agent-2': 0.356136251453794}
#
# action:  {'agent-0': array([ 0.55711484, -0.84898937,  0.5677652 ], dtype=float32), 'agent-1': array([0.15149164, 0.15647328, 1.        ], dtype=float32), 'agent-2': array([-0.7151185 ,  0.19111967,  0.74843025], dtype=float32)}
# reward:  {'agent-0': 0.17073454329185722, 'agent-1': 0.11321137400245007, 'agent-2': 0.0821138223645832}
#
# action:  {'agent-0': array([ 0.5216366 , -0.07743722,  0.03271875], dtype=float32), 'agent-1': array([-1., -1.,  0.], dtype=float32), 'agent-2': array([-1.       , -0.6993137,  1.       ], dtype=float32)}
# reward:  {'agent-0': -0.01751648111313031, 'agent-1': 0.0, 'agent-2': -0.40584100996316863}
#
# action:  {'agent-0': array([ 0.0193814, -0.9455385,  0.8036318], dtype=float32), 'agent-1': array([-1.        ,  0.44165635,  0.96375394], dtype=float32), 'agent-2': array([0.80277395, 0.52189445, 0.3103314 ], dtype=float32)}
# reward:  {'agent-0': -0.06976216379483624, 'agent-1': -0.6635997173269192, 'agent-2': 0.1759382005932295}
#
# action:  {'agent-0': array([-0.04938751, -0.9985269 ,  0.7340183 ], dtype=float32), 'agent-1': array([0.13087046, 1.        , 0.        ], dtype=float32), 'agent-2': array([1.        , 0.02741301, 0.20410436], dtype=float32)}
# reward:  {'agent-0': -0.5390477969304062, 'agent-1': 0.0, 'agent-2': 0.006428026908871232}
#
# action:  {'agent-0': array([-0.9540224 , -0.02623141,  0.        ], dtype=float32), 'agent-1': array([0.9415326, 0.5685644, 0.7492825], dtype=float32), 'agent-2': array([0.48586273, 1.        , 0.23427254], dtype=float32)}
# reward:  {'agent-0': 0.0, 'agent-1': 0.5180595206082792, 'agent-2': 0.20958866035122448}
#
# action:  {'agent-0': array([0.64351785, 1.        , 1.        ], dtype=float32), 'agent-1': array([0.15756238, 0.78839993, 0.00301632], dtype=float32), 'agent-2': array([-0.53270066,  1.        ,  0.7254516 ], dtype=float32)}
# reward:  {'agent-0': 0.7576573359806211, 'agent-1': -0.00011587294723547359, 'agent-2': -0.44575907066107767}
#
# action:  {'agent-0': array([-0.92026705,  0.268826  ,  0.27034792], dtype=float32), 'agent-1': array([ 1., -1.,  1.], dtype=float32), 'agent-2': array([-0.2551694,  1.       ,  0.6030129], dtype=float32)}
# reward:  {'agent-0': 5.490749967707075, 'agent-1': -0.28060946608905546, 'agent-2': -0.5799219526522155}
#
# action:  {'agent-0': array([-1., -1.,  0.], dtype=float32), 'agent-1': array([1., 1., 1.], dtype=float32), 'agent-2': array([0.7539377 , 0.09071553, 1.        ], dtype=float32)}
# reward:  {'agent-0': 5.406635550402541, 'agent-1': -0.5145717334769433, 'agent-2': -0.10030401647568254}
#
# action:  {'agent-0': array([-1.        , -0.61899185,  0.        ], dtype=float32), 'agent-1': array([-1.        , -0.06569141,  1.        ], dtype=float32), 'agent-2': array([ 0.45081854, -0.07426769,  0.18997023], dtype=float32)}
# reward:  {'agent-0': 5.406635550402541, 'agent-1': 0.9598623084707789, 'agent-2': 0.04692003772238351}
#
# action:  {'agent-0': array([0.45150232, 0.18175733, 0.870337  ], dtype=float32), 'agent-1': array([ 1.        , -0.44186252,  1.        ], dtype=float32), 'agent-2': array([-1.        , -0.32173514,  0.        ], dtype=float32)}
# reward:  {'agent-0': -0.7566045383670765, 'agent-1': -0.9846519945709993, 'agent-2': 0.0}
#
# action:  {'agent-0': array([-1.      , -0.463624,  1.      ], dtype=float32), 'agent-1': array([ 0.21530902, -0.15942335,  1.        ], dtype=float32), 'agent-2': array([-0.42386776,  1.        ,  0.57995266], dtype=float32)}
# reward:  {'agent-0': 0.618432660080412, 'agent-1': -0.9313735801757126, 'agent-2': -0.5515066043916299}
#
# action:  {'agent-0': array([-0.41328073, -0.2128886 ,  0.87876797], dtype=float32), 'agent-1': array([-0.14390087,  1.        ,  0.74512744], dtype=float32), 'agent-2': array([ 1.       , -0.3578521,  1.       ], dtype=float32)}
# reward:  {'agent-0': -0.8294979032845351, 'agent-1': 0.28626937581898737, 'agent-2': 0.4551299423200472}
#
# action:  {'agent-0': array([-1.        , -0.30799556,  0.1633408 ], dtype=float32), 'agent-1': array([-0.6773523,  1.       ,  0.       ], dtype=float32), 'agent-2': array([ 1.        , -0.6761326 ,  0.76340103], dtype=float32)}
# reward:  {'agent-0': -0.14062349452589196, 'agent-1': 0.0, 'agent-2': 0.5502655812288673}
#
# action:  {'agent-0': array([-0.18271726,  1.        ,  0.21201208], dtype=float32), 'agent-1': array([-0.9532164 ,  0.50019765,  1.        ], dtype=float32), 'agent-2': array([-1.        , -0.17144108,  0.00922978], dtype=float32)}
# reward:  {'agent-0': 0.13095805451907694, 'agent-1': 0.9630691295823866, 'agent-2': -0.0006373614455412735}
#
# ...
# reward:  {'agent-0': 0.26780561545433024, 'agent-1': -0.37544826729560477, 'agent-2': -0.28262728362666145}
#
# action:  {'agent-0': array([1.        , 1.        , 0.79558086], dtype=float32), 'agent-1': array([ 0.1718198 , -0.39321786,  1.        ], dtype=float32), 'agent-2': array([-1.        , -0.13819718,  0.39265743], dtype=float32)}
# reward:  {'agent-0': 0.4773925371223626, 'agent-1': 0.16392890957832762, 'agent-2': 0.00296751646872373}
#
# action:  {'agent-0': array([0.8375287, 1.       , 0.5859756], dtype=float32), 'agent-1': array([-0.29733926,  0.48844445,  0.73755085], dtype=float32), 'agent-2': array([1.        , 0.13480389, 0.        ], dtype=float32)}
# reward:  {'agent-0': -0.5749509627082645, 'agent-1': -0.05247974852612991, 'agent-2': 0.0}
#
# action:  {'agent-0': array([0.18498433, 0.14064538, 1.        ], dtype=float32), 'agent-1': array([0.9703921 , 1.        , 0.33512574], dtype=float32), 'agent-2': array([-0.3146032 , -0.7620243 ,  0.89743507], dtype=float32)}
# reward:  {'agent-0': -0.9230444547806851, 'agent-1': 0.14037779631983405, 'agent-2': -0.23207066145538846}
#
# action:  {'agent-0': array([-1.        , -0.86149365,  0.4638758 ], dtype=float32), 'agent-1': array([-0.47751188, -1.        ,  0.08596188], dtype=float32), 'agent-2': array([ 0.04528797, -0.44198024,  0.9497566 ], dtype=float32)}
# reward:  {'agent-0': 0.4398377893188279, 'agent-1': -0.01016598082323128, 'agent-2': -0.9492661083586693}
#
# action:  {'agent-0': array([ 0.2263143 , -0.90312743,  0.6056335 ], dtype=float32), 'agent-1': array([1., 1., 1.], dtype=float32), 'agent-2': array([-1.        ,  1.        ,  0.05235374], dtype=float32)}
# reward:  {'agent-0': 0.42418856775279856, 'agent-1': -0.09765003850063536, 'agent-2': 0.03951243747120259}
#
# action:  {'agent-0': array([-0.69852954,  0.41877985,  0.55609006], dtype=float32), 'agent-1': array([-0.24684286, -1.        ,  1.        ], dtype=float32), 'agent-2': array([1.        , 1.        , 0.65746284], dtype=float32)}
# reward:  {'agent-0': 0.001831168364896385, 'agent-1': -0.050316198439015025, 'agent-2': 0.42090588608408197}
#
# action:  {'agent-0': array([-0.37601197, -0.79878974,  1.        ], dtype=float32), 'agent-1': array([ 1., -1.,  1.], dtype=float32), 'agent-2': array([-1.      ,  0.274925,  1.      ], dtype=float32)}
# reward:  {'agent-0': 0.5502971464806556, 'agent-1': -0.9109784648742281, 'agent-2': 0.3320457175606535}
#
# action:  {'agent-0': array([0.5239681 , 0.9017873 , 0.90937877], dtype=float32), 'agent-1': array([1., 1., 1.], dtype=float32), 'agent-2': array([ 1.       , -0.4504633,  0.6537198], dtype=float32)}
# reward:  {'agent-0': -0.46299150262876587, 'agent-1': -0.43150043152822803, 'agent-2': -0.29988543109146804}
#
# action:  {'agent-0': array([-1.       , -0.7603351,  0.4485149], dtype=float32), 'agent-1': array([-1.        ,  1.        ,  0.50615436], dtype=float32), 'agent-2': array([-1.        , -0.04677832,  0.65765274], dtype=float32)}
# reward:  {'agent-0': 0.41249854945138686, 'agent-1': 0.44526827425193893, 'agent-2': 0.0021515603702173536}
#
# action:  {'agent-0': array([0.10990667, 0.97593844, 0.5932355 ], dtype=float32), 'agent-1': array([-1.       , -1.       ,  0.7547454], dtype=float32), 'agent-2': array([0.7500799 , 1.        , 0.35536718], dtype=float32)}
# reward:  {'agent-0': -0.5496147072595097, 'agent-1': 0.345887710939186, 'agent-2': 0.27771314406352765}
#
# action:  {'agent-0': array([-1.        , -0.6026293 ,  0.16112232], dtype=float32), 'agent-1': array([-0.57035995, -1.        ,  0.8708863 ], dtype=float32), 'agent-2': array([-0.39594197,  0.6272968 ,  0.93024313], dtype=float32)}
# reward:  {'agent-0': 0.1378012963785782, 'agent-1': 0.12041881593731496, 'agent-2': 0.5864420804759831}
#
# action:  {'agent-0': array([-0.50567603,  0.37360203,  0.36600503], dtype=float32), 'agent-1': array([-1.        , -0.01720721,  0.35940295], dtype=float32), 'agent-2': array([ 0.58792317, -1.        ,  0.9954555 ], dtype=float32)}
# reward:  {'agent-0': -0.06312814478243922, 'agent-1': 0.32455578250348793, 'agent-2': -0.6581933583290134}
#
# action:  {'agent-0': array([ 0.36481476, -0.7156391 ,  0.98097575], dtype=float32), 'agent-1': array([1.       , 1.       , 0.7279977], dtype=float32), 'agent-2': array([0.65300095, 0.6940541 , 0.        ], dtype=float32)}
# reward:  {'agent-0': 0.5663204400778952, 'agent-1': -0.2723193430497908, 'agent-2': 0.0}
#
# action:  {'agent-0': array([-0.35510445,  0.56899047,  0.874125  ], dtype=float32), 'agent-1': array([-0.54879963, -1.        ,  0.7362456 ], dtype=float32), 'agent-2': array([0.26144695, 0.91801846, 0.27851626], dtype=float32)}
# reward:  {'agent-0': -0.43949871512060135, 'agent-1': 0.07157413923999378, 'agent-2': 0.264152408692615}
#
# action:  {'agent-0': array([0.19128597, 0.4837104 , 0.6260884 ], dtype=float32), 'agent-1': array([-0.513782,  1.      ,  1.      ], dtype=float32), 'agent-2': array([-0.25585747,  1.        ,  0.26378626], dtype=float32)}
# reward:  {'agent-0': -0.62449228220847, 'agent-1': 0.517697205806444, 'agent-2': 0.25832957870153095}
#
# action:  {'agent-0': array([-0.03537649, -0.15312982,  0.57345724], dtype=float32), 'agent-1': array([0.86720884, 1.        , 0.5654785 ], dtype=float32), 'agent-2': array([-0.52773213,  1.        ,  1.        ], dtype=float32)}
# reward:  {'agent-0': 0.559040915451039, 'agent-1': 0.053708387398145874, 'agent-2': -0.4141673382943516}
#
# action:  {'agent-0': array([-0.46354795, -0.5354213 ,  0.05111277], dtype=float32), 'agent-1': array([0.24369884, 1.        , 1.        ], dtype=float32), 'agent-2': array([ 0.59894824, -0.73412985,  0.782915  ], dtype=float32)}
# reward:  {'agent-0': 0.049440051184980405, 'agent-1': 2.329892746915507, 'agent-2': 3.4033676076855266}
#
# action:  {'agent-0': array([-0.1462776, -1.       ,  1.       ], dtype=float32), 'agent-1': array([ 1.        , -0.21898174,  0.7028948 ], dtype=float32), 'agent-2': array([ 0.79323196, -0.678152  ,  0.05881858], dtype=float32)}
# reward:  {'agent-0': 0.32850006800195075, 'agent-1': -0.7028681921439084, 'agent-2': 9.16203216066342}
#
# action:  {'agent-0': array([-0.35538685, -0.6224304 ,  0.78747493], dtype=float32), 'agent-1': array([-1.        ,  0.28033602,  0.        ], dtype=float32), 'agent-2': array([-0.51563346,  0.48627877,  1.        ], dtype=float32)}
# reward:  {'agent-0': -0.7870691985185108, 'agent-1': 0.0, 'agent-2': -0.6889619465713217}
#
# action:  {'agent-0': array([0.78556347, 0.3457557 , 0.18387148], dtype=float32), 'agent-1': array([-1.       , -0.1312995,  0.663023 ], dtype=float32), 'agent-2': array([-0.21584368, -1.        ,  0.03390539], dtype=float32)}
# reward:  {'agent-0': 0.14474527882999944, 'agent-1': 0.6191687244787225, 'agent-2': 0.03329234082961996}
#
# action:  {'agent-0': array([-0.8725444 , -0.31958997,  0.9444728 ], dtype=float32), 'agent-1': array([-0.09570563,  0.02044797,  1.        ], dtype=float32), 'agent-2': array([-1.        , -0.49843383,  1.        ], dtype=float32)}
# reward:  {'agent-0': -0.685649276303602, 'agent-1': -0.7548184389337731, 'agent-2': 0.5059234429987036}
#
# action:  {'agent-0': array([-0.9019835,  1.       ,  0.8379285], dtype=float32), 'agent-1': array([-1.        , -0.10676497,  0.44877052], dtype=float32), 'agent-2': array([ 1.        , -0.39188492,  0.769043  ], dtype=float32)}
# reward:  {'agent-0': 0.37056710314204544, 'agent-1': -0.41905121427020653, 'agent-2': 0.08227086438517617}
#
# action:  {'agent-0': array([-1.       ,  1.       ,  0.5037932], dtype=float32), 'agent-1': array([0.76227915, 0.06271803, 1.        ], dtype=float32), 'agent-2': array([ 0.39603925, -1.        ,  0.7900028 ], dtype=float32)}
# reward:  {'agent-0': 0.23066998892590895, 'agent-1': 0.9452133554632951, 'agent-2': -0.727432930862081}
#
# action:  {'agent-0': array([ 0.5586934 , -0.0580045 ,  0.11358547], dtype=float32), 'agent-1': array([ 0.6067655, -1.       ,  0.       ], dtype=float32), 'agent-2': array([1.       , 0.5659882, 1.       ], dtype=float32)}
# reward:  {'agent-0': 0.021164497363908907, 'agent-1': 0.0, 'agent-2': 0.46411401754898485}
#
# action:  {'agent-0': array([ 0.39482903, -0.12884188,  1.        ], dtype=float32), 'agent-1': array([ 0.35240793, -1.        ,  1.        ], dtype=float32), 'agent-2': array([ 1.        , -0.89922273,  0.74115264], dtype=float32)}
# reward:  {'agent-0': 0.037234532404418985, 'agent-1': 0.1258830744395958, 'agent-2': -0.5474408136251547}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[183], line 16
#      14 out = ""
#      15 for i in range(trainin_steps):
# ---> 16     result = algo.train()
#      17     clear_output()
#      18     out += ppo_result_format(result) + "\n"
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/tune/trainable/trainable.py:328, in Trainable.train(self)
#     326 start = time.time()
#     327 try:
# --> 328     result = self.step()
#     329 except Exception as e:
#     330     skipped = skip_exceptions(e)
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:873, in Algorithm.step(self)
#     863     (
#     864         train_results,
#     865         eval_results,
#     866         train_iter_ctx,
#     867     ) = self._run_one_training_iteration_and_evaluation_in_parallel()
#     869 # - No evaluation necessary, just run the next training iteration.
#     870 # - We have to evaluate in this training iteration, but no parallelism ->
#     871 #   evaluate after the training iteration is entirely done.
#     872 else:
# --> 873     train_results, train_iter_ctx = self._run_one_training_iteration()
#     875 # Sequential: Train (already done above), then evaluate.
#     876 if evaluate_this_iter and not self.config.evaluation_parallel_to_training:
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:3156, in Algorithm._run_one_training_iteration(self)
#    3154             # Try to train one step.
#    3155             with self._timers[TRAINING_STEP_TIMER]:
# -> 3156                 results = self.training_step()
#    3158 return results, train_iter_ctx
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/rllib/algorithms/ppo/ppo.py:428, in PPO.training_step(self)
#     424     return self._training_step_new_api_stack()
#     425 # Old and hybrid API stacks (Policy, RolloutWorker, Connector, maybe RLModule,
#     426 # maybe Learner).
#     427 else:
# --> 428     return self._training_step_old_and_hybrid_api_stacks()
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/rllib/algorithms/ppo/ppo.py:562, in PPO._training_step_old_and_hybrid_api_stacks(self)
#     557     train_batch = synchronous_parallel_sample(
#     558         worker_set=self.workers,
#     559         max_agent_steps=self.config.total_train_batch_size,
#     560     )
#     561 else:
# --> 562     train_batch = synchronous_parallel_sample(
#     563         worker_set=self.workers,
#     564         max_env_steps=self.config.total_train_batch_size,
#     565     )
#     566 train_batch = train_batch.as_multi_agent()
#     567 self._counters[NUM_AGENT_STEPS_SAMPLED] += train_batch.agent_steps()
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/rllib/execution/rollout_ops.py:97, in synchronous_parallel_sample(worker_set, max_agent_steps, max_env_steps, concat, sample_timeout_s, _uses_new_env_runners, _return_metrics)
#      94         stats_dicts = [worker_set.local_worker().get_metrics()]
#      95 # Loop over remote workers' `sample()` method in parallel.
#      96 else:
# ---> 97     sampled_data = worker_set.foreach_worker(
#      98         (
#      99             (lambda w: w.sample())
#     100             if not _return_metrics
#     101             else (lambda w: (w.sample(), w.get_metrics()))
#     102         ),
#     103         local_worker=False,
#     104         timeout_seconds=sample_timeout_s,
#     105     )
#     106     # Nothing was returned (maybe all workers are stalling) or no healthy
#     107     # remote workers left: Break.
#     108     # There is no point staying in this loop, since we will not be able to
#     109     # get any new samples if we don't have any healthy remote workers left.
#     110     if not sampled_data or worker_set.num_healthy_remote_workers() <= 0:
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/rllib/env/env_runner_group.py:840, in EnvRunnerGroup.foreach_worker(self, func, local_worker, healthy_only, remote_worker_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     837 if not self._worker_manager.actor_ids():
#     838     return local_result
# --> 840 remote_results = self._worker_manager.foreach_actor(
#     841     func,
#     842     healthy_only=healthy_only,
#     843     remote_actor_ids=remote_worker_ids,
#     844     timeout_seconds=timeout_seconds,
#     845     return_obj_refs=return_obj_refs,
#     846     mark_healthy=mark_healthy,
#     847 )
#     849 _handle_remote_call_result_errors(
#     850     remote_results, self._ignore_env_runner_failures
#     851 )
#     853 # With application errors handled, return good results.
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/rllib/utils/actor_manager.py:622, in FaultTolerantActorManager.foreach_actor(self, func, healthy_only, remote_actor_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     616 remote_calls = self._call_actors(
#     617     func=func,
#     618     remote_actor_ids=remote_actor_ids,
#     619 )
#     621 # Collect remote request results (if available given timeout and/or errors).
# --> 622 _, remote_results = self._fetch_result(
#     623     remote_actor_ids=remote_actor_ids,
#     624     remote_calls=remote_calls,
#     625     tags=[None] * len(remote_calls),
#     626     timeout_seconds=timeout_seconds,
#     627     return_obj_refs=return_obj_refs,
#     628     mark_healthy=mark_healthy,
#     629 )
#     631 return remote_results
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/rllib/utils/actor_manager.py:476, in FaultTolerantActorManager._fetch_result(self, remote_actor_ids, remote_calls, tags, timeout_seconds, return_obj_refs, mark_healthy)
#     473 if not remote_calls:
#     474     return [], RemoteCallResults()
# --> 476 ready, _ = ray.wait(
#     477     remote_calls,
#     478     num_returns=len(remote_calls),
#     479     timeout=timeout,
#     480     # Make sure remote results are fetched locally in parallel.
#     481     fetch_local=not return_obj_refs,
#     482 )
#     484 # Remote data should already be fetched to local object store at this point.
#     485 remote_results = RemoteCallResults()
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/_private/auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/rayEnv/lib/python3.11/site-packages/ray/_private/worker.py:2854, in wait(ray_waitables, num_returns, timeout, fetch_local)
#    2852 timeout = timeout if timeout is not None else 10**6
#    2853 timeout_milliseconds = int(timeout * 1000)
# -> 2854 ready_ids, remaining_ids = worker.core_worker.wait(
#    2855     ray_waitables,
#    2856     num_returns,
#    2857     timeout_milliseconds,
#    2858     worker.current_task_id,
#    2859     fetch_local,
#    2860 )
#    2861 return ready_ids, remaining_ids
#
# File python/ray/_raylet.pyx:3812, in ray._raylet.CoreWorker.wait()
#
# File python/ray/_raylet.pyx:571, in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %%
save_algo(algo, "ring_formation?agents=3&algo=PPO&phase=2")
# Out:
# An Algorithm checkpoint has been created inside directory: 'TrainingResult(checkpoint=Checkpoint(filesystem=local, path=/mnt/c/Users/nicol/Desktop/Università/tesi/experiments/RL_experiments/algos/ring_formation?agents=3&algo=PPO&phase=2), metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 12.446995903137658, 'cur_kl_coeff': 2.2781249999999997, 'cur_lr': 0.0005000000000000001, 'total_loss': 2.6672143841369285, 'policy_loss': -0.007560958999965806, 'vf_loss': 2.646884426019258, 'vf_explained_var': 0.4825471475927366, 'kl': 0.0122429251908923, 'entropy': 3.7913157107101547, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 256.0, 'num_grad_updates_lifetime': 84960.5, 'diff_num_grad_updates_vs_sampler_policy': 1439.5}}, 'num_env_steps_sampled': 491520, 'num_env_steps_trained': 491520, 'num_agent_steps_sampled': 1474560, 'num_agent_steps_trained': 1474560}, 'sampler_results': {'episode_reward_max': 131.43353781728902, 'episode_reward_min': -601.0922972197295, 'episode_reward_mean': -133.4812542358517, 'episode_len_mean': 300.0, 'episode_media': {}, 'episodes_this_iter': 28, 'episodes_timesteps_total': 30000, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-255.78645589728558, -282.46561963741397, -154.6367102399672, -487.71248535726727, -3.3999845028912645, -283.3598084584491, -93.73146166052096, -91.89899730105704, -3.301915092624813, -362.3340336346797, 131.43353781728902, -601.0922972197295, -313.47965576083743, -74.96866341267132, -215.70232240798498, -275.15811687541344, -230.95163649526194, -275.051283882767, -331.9556655621941, 8.970002808110037, -93.37995914255329, -97.01806725920439, -68.73384440999983, -114.7515637665567, -191.9335785353675, -95.3763477843529, -19.79456022770904, -124.74168554165934, -20.366815466975677, -0.5678923426023395, 17.30219647782282, -282.8067079433526, -373.56967540796643, 53.84785125457641, -348.1003197324698, -121.44484834344246, 1.309795821860197, -161.9728655910109, -262.5294989806954, -140.4018430581644, 40.99042075550675, -266.4390691652505, -1.998562930051429, -14.495488583676238, 46.666365390443794, -295.27140026440753, -271.4191863993012, 87.32436850845794, -253.30756933685714, -28.14058573625301, -87.73720436320615, -183.0589077591878, -165.65768977679951, 5.853030872008281, -256.66157916045216, 90.44146701048702, -166.9230622555383, 68.64382530818878, -159.9665080509423, -91.50493789032568, -147.12350454147614, -197.56451479293466, -6.181918425683339, 105.88249081656014, -136.76222888629817, -364.9998327994669, -211.34747714625365, -159.04429536833706, -252.53154091414964, -14.769025243462739, -48.182393215031226, -288.46169702865615, 35.14338495566232, -177.29161824550465, -15.63437600930163, -11.520812522675179, 78.4362505580195, -222.64447722507143, -255.04293333497748, -94.91801721340153, 60.143636378182975, -347.64712516541437, 1.9413601551946966, 63.104164441326795, -381.0547512667386, -328.83992017586934, -73.92511695902373, -139.77266894647073, -67.4313691326493, -79.48450364603744, -160.44819263600135, -85.06132584579376, 48.21365871570563, -280.7610088774634, -79.99330649094732, -40.61406750166953, -127.46902117619939, -3.7150120710285215, -358.71489395302564, -37.76134626821314], 'episode_lengths': [300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.5770071262703882, ' ...

# %%
simulate_episode(RenderableRingFormation(config), algo, steps=300, sleep_between_frames=0.03)
# Out:
# CanvasWithBorders(height=300, width=300)

# %% [markdown]
# ### 3 agents, SAC

# %%
from ray.tune.registry import register_env

config = EnvironmentConfiguration(3, 10, 50, max_steps=500, cache_size=2)
env = RingFormation(config)
register_env("ring_formation?agents=3&algo=SAC", lambda _: RingFormation(config))

# %%
from ray.rllib.algorithms.sac import SACConfig
from ray.tune.logger import pretty_print
from gymnasium.wrappers.time_limit import TimeLimit

trainin_steps = 30

algo = (
    SACConfig()
    .training(gamma = 0.925, 
            lr = 0.0005,
            train_batch_size = 4096*2, 
            #entropy_coeff=0.005,
    )
    #.env_runners(num_env_runners=4)
    .resources(num_gpus=0)
    .environment(env="ring_formation?agents=3&algo=SAC")
    .build()
)
clear_output()

out = ""
for i in range(trainin_steps):
    result = algo.train()
    clear_output()
    out += sac_result_format(result) + "\n"
    print(out)
    simulate_episode(RenderableRingFormation(config), algo, 200, sleep_between_frames=0.03, print_reward=True, print_action=True, print_ob = True)
# Out:
# iteration [1] => episode_reward_mean: nan, episode_len_mean: nan
# iteration [2] => episode_reward_mean: nan, episode_len_mean: nan
# iteration [3] => episode_reward_mean: -70.76117451354, episode_len_mean: 500.0
# iteration [4] => episode_reward_mean: -70.76117451354, episode_len_mean: 500.0
# iteration [5] => episode_reward_mean: -74.599750876038, episode_len_mean: 500.0
# iteration [6] => episode_reward_mean: -74.599750876038, episode_len_mean: 500.0
# CanvasWithBorders(height=300, width=300)
# obs:  {'agent-0': array([-1.2090671,  2.6523044, -2.6928694,  3.4329107, -0.7853982,
#         3.2205396, -1.2090671,  2.6523044, -2.6928694,  3.4329107,
#        -0.7853982,  3.2205396], dtype=float32), 'agent-1': array([ 0.02104952,  3.48657   , -0.09065989,  3.8106866 ,  0.44872335,
#         3.4329107 ,  0.02104952,  3.48657   , -0.09065989,  3.8106866 ,
#         0.44872335,  3.4329107 ], dtype=float32), 'agent-2': array([2.7798634, 2.6523044, 2.3561945, 3.2205396, 3.050933 , 3.8106866,
#        2.7798634, 2.6523044, 2.3561945, 3.2205396, 3.050933 , 3.8106866],
#       dtype=float32)}
# action:  {'agent-0': array([2.748429  , 0.07747126], dtype=float32), 'agent-1': array([1.3803537 , 0.35695222], dtype=float32), 'agent-2': array([-1.709255 ,  0.8173977], dtype=float32)}
# reward:  {'agent-0': 0.05296291724707025, 'agent-1': -0.07684920888441127, 'agent-2': 0.1565842108373534}
#
# obs:  {'agent-0': array([-1.2133633,  2.648564 , -2.6947944,  3.4345775, -0.7866336,
#         3.2176776, -1.2090671,  2.6523044, -2.6928694,  3.4329107,
#        -0.7853982,  3.2205396], dtype=float32), 'agent-1': array([ 0.03204165,  3.4889193 , -0.08262748,  3.8115048 ,  0.45821583,
#         3.439807  ,  0.02104952,  3.48657   , -0.09065989,  3.8106866 ,
#         0.44872335,  3.4329107 ], dtype=float32), 'agent-2': array([2.841076 , 2.6412058, 2.3838842, 3.2010367, 3.069394 , 3.8117173,
#        2.7798634, 2.6523044, 2.3561945, 3.2205396, 3.050933 , 3.8106866],
#       dtype=float32)}
# action:  {'agent-0': array([2.6745794, 0.5886482], dtype=float32), 'agent-1': array([2.4127667 , 0.98090994], dtype=float32), 'agent-2': array([2.2474768, 0.9278167], dtype=float32)}
# reward:  {'agent-0': 0.4258824615523764, 'agent-1': 0.703043679890083, 'agent-2': -0.7788532745481831}
#
# obs:  {'agent-0': array([-1.2448193,  2.6179686, -2.7006528,  3.4528632, -0.7662739,
#         3.1748188, -1.2133633,  2.648564 , -2.6947944,  3.4345775,
#        -0.7866336,  3.2176776], dtype=float32), 'agent-1': array([ 0.05382892,  3.4672189 , -0.05028468,  3.7955713 ,  0.486713  ,
#         3.4300072 ,  0.03204165,  3.4889193 , -0.08262748,  3.8115048 ,
#         0.45821583,  3.439807  ], dtype=float32), 'agent-2': array([2.803485 , 2.6952326, 2.3775826, 3.234957 , 3.0621536, 3.8265305,
#        2.841076 , 2.6412058, 2.3838842, 3.2010367, 3.069394 , 3.8117173],
#       dtype=float32)}
# action:  {'agent-0': array([-0.56085205,  0.9700606 ], dtype=float32), 'agent-1': array([-1.5736328,  0.6431389], dtype=float32), 'agent-2': array([1.8669841 , 0.53890395], dtype=float32)}
# reward:  {'agent-0': -0.7658166095692085, 'agent-1': 0.029777311573536025, 'agent-2': -0.32602685009035604}
#
# obs:  {'agent-0': array([-1.1993107,  2.6723309, -2.642766 ,  3.4254003, -0.763064 ,
#         3.2500846, -1.2448193,  2.6179686, -2.7006528,  3.4528632,
#        -0.7662739,  3.1748188], dtype=float32), 'agent-1': array([ 0.03312615,  3.4662893 , -0.08052803,  3.810455  ,  0.45170525,
#         3.4318366 ,  0.05382892,  3.4672189 , -0.05028468,  3.7955713 ,
#         0.486713  ,  3.4300072 ], dtype=float32), 'agent-2': array([2.7727704, 2.7170093, 2.3596666, 3.2314553, 3.0642254, 3.8137383,
#        2.803485 , 2.6952326, 2.3775826, 3.234957 , 3.0621536, 3.8265305],
#       dtype=float32)}
# action:  {'agent-0': array([-2.4747143 ,  0.20060712], dtype=float32), 'agent-1': array([2.7437146, 0.8963583], dtype=float32), 'agent-2': array([-1.5872054 ,  0.55137014], dtype=float32)}
# reward:  {'agent-0': -0.05976073917090652, 'agent-1': 0.8120618695964552, 'agent-2': 0.180714420606515}
#
# obs:  {'agent-0': array([-1.2134923,  2.6764512, -2.660667 ,  3.421921 , -0.7813873,
#         3.2672284, -1.1993107,  2.6723309, -2.642766 ,  3.4254003,
#        -0.763064 ,  3.2500846], dtype=float32), 'agent-1': array([ 0.04552427,  3.4405992 , -0.08561572,  3.7958982 ,  0.503552  ,
#         3.396737  ,  0.03312615,  3.4662893 , -0.08052803,  3.810455  ,
#         0.45170525,  3.4318366 ], dtype=float32), 'agent-2': array([2.809863 , 2.7049973, 2.3841891, 3.2537932, 3.0621727, 3.814056 ,
#        2.7727704, 2.7170093, 2.3596666, 3.2314553, 3.0642254, 3.8137383],
#       dtype=float32)}
# action:  {'agent-0': array([2.7185328, 0.6618142], dtype=float32), 'agent-1': array([-3.0346336e+00,  5.5250525e-04], dtype=float32), 'agent-2': array([2.254728 , 0.8145745], dtype=float32)}
# reward:  {'agent-0': 0.45715055254697745, 'agent-1': 0.00055146292316266, 'agent-2': -0.6985402605098496}
#
# obs:  {'agent-0': array([-1.2494677,  2.6444907, -2.6548934,  3.4166133, -0.7745527,
#         3.2283297, -1.2134923,  2.6764512, -2.660667 ,  3.421921 ,
#        -0.7813873,  3.2672284], dtype=float32), 'agent-1': array([ 0.04552315,  3.4405816 , -0.07296804,  3.7951074 ,  0.5046817 ,
#         3.4033265 ,  0.04552427,  3.4405992 , -0.08561572,  3.7958982 ,
#         0.503552  ,  3.396737  ], dtype=float32), 'agent-2': array([2.7805588, 2.750651 , 2.3723605, 3.2834878, 3.0551825, 3.8077037,
#        2.809863 , 2.7049973, 2.3841891, 3.2537932, 3.0621727, 3.814056 ],
#       dtype=float32)}
# action:  {'agent-0': array([-2.5470872 ,  0.24253541], dtype=float32), 'agent-1': array([-2.027732  ,  0.03813231], dtype=float32), 'agent-2': array([-1.8489791 ,  0.46995795], dtype=float32)}
# reward:  {'agent-0': -0.06750904798735391, 'agent-1': 0.018345328074730105, 'agent-2': 0.03138912218108025}
#
# obs:  {'agent-0': array([-1.2672368 ,  2.6492753 , -2.654008  ,  3.4244807 , -0.78770924,
#         3.2581148 , -1.2494677 ,  2.6444907 , -2.6548934 ,  3.4166133 ,
#        -0.7745527 ,  3.2283297 ], dtype=float32), 'agent-1': array([ 0.04441607,  3.4399934 , -0.08721992,  3.8073854 ,  0.48594597,
#         3.415583  ,  0.04552315,  3.4405816 , -0.07296804,  3.7951074 ,
#         0.5046817 ,  3.4033265 ], dtype=float32), 'agent-2': array([2.8125958, 2.7486434, 2.380009 , 3.2513502, 3.0656323, 3.8097315,
#        2.7805588, 2.750651 , 2.3723605, 3.2834878, 3.0551825, 3.8077037],
#       dtype=float32)}
# action:  {'agent-0': array([0.04790998, 0.27872825], dtype=float32), 'agent-1': array([-0.9345677 ,  0.89864117], dtype=float32), 'agent-2': array([-0.45838022,  0.87096095], dtype=float32)}
# reward:  {'agent-0': -0.07323442593830798, 'agent-1': -0.510382922587695, 'agent-2': 0.8632222150422262}
#
# obs:  {'agent-0': array([-1.2468323 ,  2.6544397 , -2.6507356 ,  3.4152231 , -0.76299304,
#         3.256781  , -1.2672368 ,  2.6492753 , -2.654008  ,  3.4244807 ,
#        -0.78770924,  3.2581148 ], dtype=float32), 'agent-1': array([ 0.02011792,  3.4562263 , -0.09196401,  3.8224728 ,  0.45703003,
#         3.4282548 ,  0.04441607,  3.4399934 , -0.08721992,  3.8073854 ,
#         0.48594597,  3.415583  ], dtype=float32), 'agent-2': array([2.8207636, 2.6917992, 2.359253 , 3.2167711, 3.0723183, 3.7913697,
#        2.8125958, 2.7486434, 2.380009 , 3.2513502, 3.0656323, 3.8097315],
#       dtype=float32)}
# action:  {'agent-0': array([0.6385596, 0.5602609], dtype=float32), 'agent-1': array([0.25323534, 0.4359722 ], dtype=float32), 'agent-2': array([1.4535644, 0.7028415], dtype=float32)}
# reward:  {'agent-0': 0.16248680741589716, 'agent-1': -0.42434255130483933, 'agent-2': -0.1591419274635566}
#
# obs:  {'agent-0': array([-1.2060102 ,  2.6429448 , -2.6842272 ,  3.4017313 , -0.7509819 ,
#         3.2280762 , -1.2468323 ,  2.6544397 , -2.6507356 ,  3.4152231 ,
#        -0.76299304,  3.256781  ], dtype=float32), 'agent-1': array([ 0.02335411,  3.4695249 , -0.08159374,  3.8136737 ,  0.45778495,
#         3.4337947 ,  0.02011792,  3.4562263 , -0.09196401,  3.8224728 ,
#         0.45703003,  3.4282548 ], dtype=float32), 'agent-2': array([2.7712855, 2.7025247, 2.3451183, 3.2414863, 3.040729 , 3.8041694,
#        2.8207636, 2.6917992, 2.359253 , 3.2167711, 3.0723183, 3.7913697],
#       dtype=float32)}
# action:  {'agent-0': array([1.074117  , 0.20100594], dtype=float32), 'agent-1': array([-1.4820094 ,  0.23820367], dtype=float32), 'agent-2': array([-2.9048774,  0.8193978], dtype=float32)}
# reward:  {'agent-0': 0.1300204318482603, 'agent-1': -0.01648245625323952, 'agent-2': -0.6804972670717735}
#
# obs:  {'agent-0': array([-1.194209 ,  2.6336508, -2.6912162,  3.4104772, -0.7660973,
#         3.2425735, -1.2060102,  2.6429448, -2.6842272,  3.4017313,
#        -0.7509819,  3.2280762], dtype=float32), 'agent-1': array([ 0.01572046,  3.470038  , -0.10272997,  3.8142307 ,  0.4467863 ,
#         3.4130852 ,  0.02335411,  3.4695249 , -0.08159374,  3.8136737 ,
#         0.45778495,  3.4337947 ], dtype=float32), 'agent-2': array([2.8033097, 2.7471325, 2.395298 , 3.2618864, 3.0501044, 3.8302057,
#        2.7712855, 2.7025247, 2.3451183, 3.2414863, 3.040729 , 3.8041694],
#       dtype=float32)}
# action:  {'agent-0': array([-2.1612976,  0.8735168], dtype=float32), 'agent-1': array([-2.7044454 ,  0.07255745], dtype=float32), 'agent-2': array([-2.081512  ,  0.23601341], dtype=float32)}
# reward:  {'agent-0': -0.5151467166047556, 'agent-1': 0.0661949469214278, 'agent-2': -0.04234153659464113}
#
# obs:  {'agent-0': array([-1.2477411 ,  2.6699784 , -2.683913  ,  3.4323707 , -0.77281904,
#         3.26551   , -1.194209  ,  2.6336508 , -2.6912162 ,  3.4104772 ,
#        -0.7660973 ,  3.2425735 ], dtype=float32), 'agent-1': array([ 0.01476523,  3.467976  , -0.09750202,  3.8297904 ,  0.44275907,
#         3.4053125 ,  0.01572046,  3.470038  , -0.10272997,  3.8142307 ,
#         0.4467863 ,  3.4130852 ], dtype=float32), 'agent-2': array([2.8191922, 2.7498436, 2.4122713, 3.2580035, 3.0496893, 3.8332136,
#        2.8033097, 2.7471325, 2.395298 , 3.2618864, 3.0501044, 3.8302057],
#       dtype=float32)}
# action:  {'agent-0': array([-2.8476453 ,  0.02335677], dtype=float32), 'agent-1': array([-0.3746817 ,  0.31282073], dtype=float32), 'agent-2': array([-1.9569688 ,  0.25750476], dtype=float32)}
# reward:  {'agent-0': 0.0006594892612223902, 'agent-1': -0.28962136402661187, 'agent-2': -0.018663180455911643}
#
# obs:  {'agent-0': array([-1.2494783 ,  2.6699328 , -2.6839905 ,  3.4307702 , -0.7645592 ,
#         3.2627738 , -1.2477411 ,  2.6699784 , -2.683913  ,  3.4323707 ,
#        -0.77281904,  3.26551   ], dtype=float32), 'agent-1': array([ 0.01097806,  3.476966  , -0.09462959,  3.838349  ,  0.45004052,
#         3.4368486 ,  0.01476523,  3.467976  , -0.09750202,  3.8297904 ,
#         0.44275907,  3.4053125 ], dtype=float32), 'agent-2': array([2.8367238, 2.7510362, 2.387403 , 3.2596169, 3.054329 , 3.8334846,
#        2.8191922, 2.7498436, 2.4122713, 3.2580035, 3.0496893, 3.8332136],
#       dtype=float32)}
# action:  {'agent-0': array([-1.7794588,  0.6619289], dtype=float32), 'agent-1': array([2.9846866, 0.688974 ], dtype=float32), 'agent-2': array([-0.8081026 ,  0.21696097], dtype=float32)}
# reward:  {'agent-0': -0.5751188808730046, 'agent-1': 0.679071430518956, 'agent-2': 0.18968547228646493}
#
# obs:  {'agent-0': array([-1.2733577 ,  2.7089908 , -2.6745203 ,  3.4506698 , -0.77728593,
#         3.2725348 , -1.2494783 ,  2.6699328 , -2.6839905 ,  3.4307702 ,
#        -0.7645592 ,  3.2627738 ], dtype=float32), 'agent-1': array([ 0.01473023,  3.4557586 , -0.08817229,  3.8250706 ,  0.46321696,
#         3.4193172 ,  0.01097806,  3.476966  , -0.09462959,  3.838349  ,
#         0.45004052,  3.4368486 ], dtype=float32), 'agent-2': array([2.8439553, 2.7388484, 2.3870587, 3.2508106, 3.0555308, 3.8364449,
#        2.8367238, 2.7510362, 2.387403 , 3.2596169, 3.054329 , 3.8334846],
#       dtype=float32)}
# action:  {'agent-0': array([1.1920602, 0.7638117], dtype=float32), 'agent-1': array([-2.2191236,  0.8856709], dtype=float32), 'agent-2': array([-3.095708  ,  0.37661302], dtype=float32)}
# reward:  {'agent-0': 0.5872406986526446, 'agent-1': 0.5370742208363701, 'agent-2': -0.35515181187859746}
#
# obs:  {'agent-0': array([-1.2377496 ,  2.669093  , -2.6780574 ,  3.4141405 , -0.7487139 ,
#         3.253277  , -1.2733577 ,  2.7089908 , -2.6745203 ,  3.4506698 ,
#        -0.77728593,  3.2725348 ], dtype=float32), 'agent-1': array([-0.00842672,  3.4386616 , -0.10190977,  3.8112411 ,  0.4675185 ,
#         3.4067469 ,  0.01473023,  3.4557586 , -0.08817229,  3.8250706 ,
#         0.46321696,  3.4193172 ], dtype=float32), 'agent-2': array([2.852512 , 2.7615476, 2.3754349, 3.2740796, 3.0577135, 3.829653 ,
#        2.8439553, 2.7388484, 2.3870587, 3.2508106, 3.0555308, 3.8364449],
#       dtype=float32)}
# action:  {'agent-0': array([-0.19075513,  0.09476474], dtype=float32), 'agent-1': array([2.5985487, 0.9111837], dtype=float32), 'agent-2': array([-0.45214534,  0.5874466 ], dtype=float32)}
# reward:  {'agent-0': -0.04764890211848538, 'agent-1': 0.7803703055583711, 'agent-2': 0.5793344930565123}
#
# obs:  {'agent-0': array([-1.2316597,  2.6723902, -2.6897907,  3.3851886, -0.7360687,
#         3.26657  , -1.2377496,  2.669093 , -2.6780574,  3.4141405,
#        -0.7487139,  3.253277 ], dtype=float32), 'agent-1': array([ 0.00738395,  3.4132864 , -0.09175123,  3.801255  ,  0.47696808,
#         3.3711526 , -0.00842672,  3.4386616 , -0.10190977,  3.8112411 ,
#         0.4675185 ,  3.4067469 ], dtype=float32), 'agent-2': array([2.859207 , 2.7242503, 2.3968284, 3.2417026, 3.0455205, 3.807284 ,
#        2.852512 , 2.7615476, 2.3754349, 3.2740796, 3.0577135, 3.829653 ],
#       dtype=float32)}
# action:  {'agent-0': array([-2.1137   ,  0.4216566], dtype=float32), 'agent-1': array([2.2645953 , 0.10535002], dtype=float32), 'agent-2': array([-0.40365005,  0.15612873], dtype=float32)}
# reward:  {'agent-0': -0.2718504863824993, 'agent-1': 0.06665415862219604, 'agent-2': 0.15496954411157482}
#
# obs:  {'agent-0': array([-1.2553433,  2.6909974, -2.6547856,  3.3809369, -0.7594441,
#         3.2482414, -1.2316597,  2.6723902, -2.6897907,  3.3851886,
#        -0.7360687,  3.26657  ], dtype=float32), 'agent-1': array([ 0.01016537,  3.411089  , -0.08522174,  3.7872312 ,  0.48273498,
#         3.3678286 ,  0.00738395,  3.4132864 , -0.09175123,  3.801255  ,
#         0.47696808,  3.3711526 ], dtype=float32), 'agent-2': array([2.8605473, 2.714033 , 2.3967314, 3.2390974, 3.0557652, 3.7855473,
#        2.859207 , 2.7242503, 2.3968284, 3.2417026, 3.0455205, 3.807284 ],
#       dtype=float32)}
# action:  {'agent-0': array([-1.7008584 ,  0.24460134], dtype=float32), 'agent-1': array([2.2902076, 0.9648969], dtype=float32), 'agent-2': array([-2.2766602,  0.4778653], dtype=float32)}
# reward:  {'agent-0': -0.2211232402564267, 'agent-1': 0.6190517225083596, 'agent-2': -0.2035874086027345}
#
# obs:  {'agent-0': array([-1.2628899,  2.705881 , -2.6441746,  3.3850596, -0.7696334,
#         3.2481992, -1.2553433,  2.6909974, -2.6547856,  3.3809369,
#        -0.7594441,  3.2482414], dtype=float32), 'agent-1': array([ 0.0356994 ,  3.3904452 , -0.06824753,  3.768073  ,  0.523801  ,
#         3.3732607 ,  0.01016537,  3.411089  , -0.08522174,  3.7872312 ,
#         0.48273498,  3.3678286 ], dtype=float32), 'agent-2': array([2.8910124, 2.7274344, 2.3993523, 3.2416825, 3.066486 , 3.7902138,
#        2.8605473, 2.714033 , 2.3967314, 3.2390974, 3.0557652, 3.7855473],
#       dtype=float32)}
# action:  {'agent-0': array([1.9226606, 0.7671065], dtype=float32), 'agent-1': array([-2.9107902,  0.7163181], dtype=float32), 'agent-2': array([-1.6256055,  0.7670572], dtype=float32)}
# reward:  {'agent-0': 0.7663224200136032, 'agent-1': 0.7023832023062546, 'agent-2': 0.129212400653838}
#
# obs:  {'agent-0': array([-1.2654433,  2.6533248, -2.6377118,  3.3740532, -0.7359247,
#         3.2203217, -1.2628899,  2.705881 , -2.6441746,  3.3850596,
#        -0.7696334,  3.2481992], dtype=float32), 'agent-1': array([ 0.03073559,  3.366495  , -0.06411985,  3.7587986 ,  0.53831124,
#         3.3547835 ,  0.0356994 ,  3.3904452 , -0.06824753,  3.768073  ,
#         0.523801  ,  3.3732607 ], dtype=float32), 'agent-2': array([2.944157 , 2.7189496, 2.4155562, 3.2281814, 3.100375 , 3.7747424,
#        2.8910124, 2.7274344, 2.3993523, 3.2416825, 3.066486 , 3.7902138],
#       dtype=float32)}
# action:  {'agent-0': array([1.7285879 , 0.34833837], dtype=float32), 'agent-1': array([0.02746415, 0.57199675], dtype=float32), 'agent-2': array([-2.0606577 ,  0.20575407], dtype=float32)}
# reward:  {'agent-0': 0.34445080765903313, 'agent-1': -0.5719937489339628, 'agent-2': -0.06067836209002664}
#
# obs:  {'agent-0': array([-1.2614598 ,  2.6287708 , -2.6426225 ,  3.3460026 , -0.70096964,
#         3.1903083 , -1.2654433 ,  2.6533248 , -2.6377118 ,  3.3740532 ,
#        -0.7359247 ,  3.2203217 ], dtype=float32), 'agent-1': array([ 0.03067004,  3.3860424 , -0.04482526,  3.772007  ,  0.50141335,
#         3.3678212 ,  0.03073559,  3.366495  , -0.06411985,  3.7587986 ,
#         0.53831124,  3.3547835 ], dtype=float32), 'agent-2': array([2.9580076, 2.722943 , 2.4395   , 3.1993473, 3.1002066, 3.7608638,
#        2.944157 , 2.7189496, 2.4155562, 3.2281814, 3.100375 , 3.7747424],
#       dtype=float32)}
# action:  {'agent-0': array([2.4351976 , 0.28205222], dtype=float32), 'agent-1': array([1.8267314 , 0.92700124], dtype=float32), 'agent-2': array([-0.80073166,  0.24738812], dtype=float32)}
# reward:  {'agent-0': 0.23883114145979434, 'agent-1': 0.19265923886270642, 'agent-2': 0.20102241773815877}
#
# obs:  {'agent-0': array([-1.2732402 ,  2.6113846 , -2.661308  ,  3.3674436 , -0.6921449 ,
#         3.176872  , -1.2614598 ,  2.6287708 , -2.6426225 ,  3.3460026 ,
#        -0.70096964,  3.1903083 ], dtype=float32), 'agent-1': array([ 0.06254089,  3.3795009 , -0.01949784,  3.7680311 ,  0.5217225 ,
#         3.3717332 ,  0.03067004,  3.3860424 , -0.04482526,  3.772007  ,
#         0.50141335,  3.3678212 ], dtype=float32), 'agent-2': array([2.9682164, 2.7096517, 2.4504383, 3.178377 , 3.1051543, 3.7699356,
#        2.9580076, 2.722943 , 2.4395   , 3.1993473, 3.1002066, 3.7608638],
#       dtype=float32)}
# action:  {'agent-0': array([-1.156953  ,  0.92672557], dtype=float32), 'agent-1': array([2.870826 , 0.9468652], dtype=float32), 'agent-2': array([0.01963234, 0.40329286], dtype=float32)}
# reward:  {'agent-0': -0.9208936708734168, 'agent-1': 0.8930075771450596, 'agent-2': 0.39558481059843054}
#
# obs:  {'agent-0': array([-1.2652982 ,  2.67682   , -2.5967245 ,  3.3786488 , -0.70864135,
#         3.2010105 , -1.2732402 ,  2.6113846 , -2.661308  ,  3.3674436 ,
#        -0.6921449 ,  3.176872  ], dtype=float32), 'agent-1': array([ 0.07382122,  3.3486087 , -0.00955636,  3.7425146 ,  0.5365482 ,
#         3.3520772 ,  0.06254089,  3.3795009 , -0.01949784,  3.7680311 ,
#         0.5217225 ,  3.3717332 ], dtype=float32), 'agent-2': array([2.9625401, 2.6829686, 2.4388947, 3.1536584, 3.1258924, 3.754583 ,
#        2.9682164, 2.7096517, 2.4504383, 3.178377 , 3.1051543, 3.7699356],
#       dtype=float32)}
# action:  {'agent-0': array([-2.949536  ,  0.56741846], dtype=float32), 'agent-1': array([-0.7526696,  0.039534 ], dtype=float32), 'agent-2': array([1.2289684 , 0.96616507], dtype=float32)}
# reward:  {'agent-0': 0.0524419645554044, 'agent-1': -0.026798131693688276, 'agent-2': 0.12288114213636447}
#
# obs:  {'agent-0': array([-1.3071135 ,  2.6732066 , -2.5792387 ,  3.374816  , -0.7397677 ,
#         3.1745076 , -1.2652982 ,  2.67682   , -2.5967245 ,  3.3786488 ,
#        -0.70864135,  3.2010105 ], dtype=float32), 'agent-1': array([ 0.07276339,  3.34955   , -0.01049974,  3.7336137 ,  0.5683863 ,
#         3.3569129 ,  0.07382122,  3.3486087 , -0.00955636,  3.7425146 ,
#         0.5365482 ,  3.3520772 ], dtype=float32), 'agent-2': array([2.8918889, 2.6745331, 2.3834083, 3.2040403, 3.1091905, 3.7256038,
#        2.9625401, 2.6829686, 2.4388947, 3.1536584, 3.1258924, 3.754583 ],
#       dtype=float32)}
# action:  {'agent-0': array([-0.20568967,  0.1243968 ], dtype=float32), 'agent-1': array([-1.9401327 ,  0.34257853], dtype=float32), 'agent-2': array([-2.443009 ,  0.1163727], dtype=float32)}
# reward:  {'agent-0': -0.05672241678504797, 'agent-1': 0.144815058692636, 'agent-2': -0.06818329260703138}
#
# obs:  {'agent-0': array([-1.2989216 ,  2.6771145 , -2.5775266 ,  3.3720937 , -0.77511483,
#         3.19504   , -1.3071135 ,  2.6732066 , -2.5792387 ,  3.374816  ,
#        -0.7397677 ,  3.1745076 ], dtype=float32), 'agent-1': array([ 0.06143967,  3.3444538 , -0.04104755,  3.723625  ,  0.55367607,
#         3.3657427 ,  0.07276339,  3.34955   , -0.01049974,  3.7336137 ,
#         0.5683863 ,  3.3569129 ], dtype=float32), 'agent-2': array([2.898854 , 2.6792226, 2.3685687, 3.191205 , 3.1104615, 3.7284045,
#        2.8918889, 2.6745331, 2.3834083, 3.2040403, 3.1091905, 3.7256038],
#       dtype=float32)}
# action:  {'agent-0': array([-2.301369 ,  0.6927053], dtype=float32), 'agent-1': array([1.5301082 , 0.95493066], dtype=float32), 'agent-2': array([-2.208275  ,  0.46808225], dtype=float32)}
# reward:  {'agent-0': -0.38508322147655427, 'agent-1': -0.11379253364291486, 'agent-2': -0.1867950852401723}
#
# obs:  {'agent-0': array([-1.3408494 ,  2.7032487 , -2.5780523 ,  3.3854277 , -0.79967767,
#         3.1970534 , -1.2989216 ,  2.6771145 , -2.5775266 ,  3.3720937 ,
#        -0.77511483,  3.19504   ], dtype=float32), 'agent-1': array([ 0.09604212,  3.3484604 , -0.01553775,  3.726008  ,  0.58454025,
#         3.3814385 ,  0.06143967,  3.3444538 , -0.04104755,  3.723625  ,
#         0.55367607,  3.3657427 ], dtype=float32), 'agent-2': array([2.9302595, 2.6919584, 2.3912811, 3.1931639, 3.1119692, 3.7320776,
#        2.898854 , 2.6792226, 2.3685687, 3.191205 , 3.1104615, 3.7284045],
#       dtype=float32)}
# action:  {'agent-0': array([-2.7505696,  0.8578771], dtype=float32), 'agent-1': array([-2.717465  ,  0.05534631], dtype=float32), 'agent-2': array([2.6120865 , 0.55541086], dtype=float32)}
# reward:  {'agent-0': -0.16305197461680798, 'agent-1': 0.05238838806282331, 'agent-2': -0.528590394367896}
#
# obs:  {'agent-0': array([-1.4009778 ,  2.714112  , -2.5567112 ,  3.4315681 , -0.81418735,
#         3.1809208 , -1.3408494 ,  2.7032487 , -2.5780523 ,  3.3854277 ,
#        -0.79967767,  3.1970534 ], dtype=float32), 'agent-1': array([ 0.09539139,  3.346618  , -0.0067772 ,  3.7313938 ,  0.5908798 ,
#         3.4021697 ,  0.09604212,  3.3484604 , -0.01553775,  3.726008  ,
#         0.58454025,  3.3814385 ], dtype=float32), 'agent-2': array([2.9180996, 2.727143 , 2.3674185, 3.2159839, 3.1286566, 3.7440672,
#        2.9302595, 2.6919584, 2.3912811, 3.1931639, 3.1119692, 3.7320776],
#       dtype=float32)}
# action:  {'agent-0': array([-2.3782582,  0.9876026], dtype=float32), 'agent-1': array([-0.40083528,  0.7685946 ], dtype=float32), 'agent-2': array([2.7940104 , 0.32938448], dtype=float32)}
# reward:  {'agent-0': -0.5752139509399221, 'agent-1': -0.6782749676273632, 'agent-2': -0.32690863278225457}
#
# obs:  {'agent-0': array([-1.4568285 ,  2.7515194 , -2.55074   ,  3.4608157 , -0.8493969 ,
#         3.203691  , -1.4009778 ,  2.714112  , -2.5567112 ,  3.4315681 ,
#        -0.81418735,  3.1809208 ], dtype=float32), 'agent-1': array([ 0.08236132,  3.3702147 , -0.0204278 ,  3.7596192 ,  0.5640264 ,
#         3.443667  ,  0.09539139,  3.346618  , -0.0067772 ,  3.7313938 ,
#         0.5908798 ,  3.4021697 ], dtype=float32), 'agent-2': array([2.9153104, 2.7482994, 2.3401332, 3.2147903, 3.1254878, 3.750227 ,
#        2.9180996, 2.727143 , 2.3674185, 3.2159839, 3.1286566, 3.7440672],
#       dtype=float32)}
# action:  {'agent-0': array([2.9985197, 0.9007102], dtype=float32), 'agent-1': array([2.264952  , 0.15008706], dtype=float32), 'agent-2': array([2.8708212 , 0.81011266], dtype=float32)}
# reward:  {'agent-0': 0.20272167604126423, 'agent-1': 0.08593100929808983, 'agent-2': -0.8093531449997418}
#
# obs:  {'agent-0': array([-1.5170928 ,  2.738495  , -2.589758  ,  3.4951952 , -0.86774254,
#         3.187621  , -1.4568285 ,  2.7515194 , -2.55074   ,  3.4608157 ,
#        -0.8493969 ,  3.203691  ], dtype=float32), 'agent-1': array([ 0.08674952,  3.367256  , -0.02024929,  3.7645814 ,  0.5750453 ,
#         3.4735801 ,  0.08236132,  3.3702147 , -0.0204278 ,  3.7596192 ,
#         0.5640264 ,  3.443667  ], dtype=float32), 'agent-2': array([2.9129746, 2.7988293, 2.3166506, 3.2424994, 3.1140409, 3.78487  ,
#        2.9153104, 2.7482994, 2.3401332, 3.2147903, 3.1254878, 3.750227 ],
#       dtype=float32)}
# action:  {'agent-0': array([2.6138356, 0.3194126], dtype=float32), 'agent-1': array([2.3159225, 0.9185896], dtype=float32), 'agent-2': array([2.7138073 , 0.10831854], dtype=float32)}
# reward:  {'agent-0': 0.17294281354121033, 'agent-1': 0.5524047384629327, 'agent-2': -0.10619204739389687}
#
# obs:  {'agent-0': array([-1.5357718 ,  2.7272484 , -2.5939052 ,  3.4991214 , -0.8529603 ,
#         3.2028344 , -1.5170928 ,  2.738495  , -2.589758  ,  3.4951952 ,
#        -0.86774254,  3.187621  ], dtype=float32), 'agent-1': array([ 0.1132257 ,  3.348023  , -0.00933613,  3.7680736 ,  0.58488595,
#         3.4897068 ,  0.08674952,  3.367256  , -0.02024929,  3.7645814 ,
#         0.5750453 ,  3.4735801 ], dtype=float32), 'agent-2': array([2.9115949, 2.8052735, 2.2947452, 3.219034 , 3.1156783, 3.784885 ,
#        2.9129746, 2.7988293, 2.3166506, 3.2424994, 3.1140409, 3.78487  ],
#       dtype=float32)}
# action:  {'agent-0': array([-2.6317759 ,  0.03044546], dtype=float32), 'agent-1': array([-1.7548742 ,  0.70489764], dtype=float32), 'agent-2': array([2.7696588, 0.6014687], dtype=float32)}
# reward:  {'agent-0': -0.013943881377212364, 'agent-1': 0.19815845749448613, 'agent-2': -0.5956447499921538}
#
# obs:  {'agent-0': array([-1.5376648,  2.72816  , -2.5657446,  3.4949691, -0.8523319,
#         3.2065828, -1.5357718,  2.7272484, -2.5939052,  3.4991214,
#        -0.8529603,  3.2028344], dtype=float32), 'agent-1': array([ 0.08848863,  3.3410325 , -0.0267965 ,  3.7676778 ,  0.5596575 ,
#         3.4793131 ,  0.1132257 ,  3.348023  , -0.00933613,  3.7680736 ,
#         0.58488595,  3.4897068 ], dtype=float32), 'agent-2': array([2.906319 , 2.8406703, 2.3019588, 3.2282796, 3.1262658, 3.78325  ,
#        2.9115949, 2.8052735, 2.2947452, 3.219034 , 3.1156783, 3.784885 ],
#       dtype=float32)}
# action:  {'agent-0': array([-2.5779657 ,  0.15972215], dtype=float32), 'agent-1': array([1.4969475, 0.2260099], dtype=float32), 'agent-2': array([-0.5177827,  0.980299 ], dtype=float32)}
# reward:  {'agent-0': -0.08147281199409662, 'agent-1': -0.03744052252789132, 'agent-2': 0.9389803643468699}
#
# obs:  {'agent-0': array([-1.5472414,  2.733469 , -2.581963 ,  3.4851573, -0.8473678,
#         3.2269871, -1.5376648,  2.72816  , -2.5657446,  3.4949691,
#        -0.8523319,  3.2065828], dtype=float32), 'agent-1': array([ 0.0966629 ,  3.342357  , -0.02627692,  3.7809134 ,  0.56537354,
#         3.484378  ,  0.08848863,  3.3410325 , -0.0267965 ,  3.7676778 ,
#         0.5596575 ,  3.4793131 ], dtype=float32), 'agent-2': array([2.9243124, 2.7842865, 2.2873762, 3.19056  , 3.1209588, 3.7607756,
#        2.906319 , 2.8406703, 2.3019588, 3.2282796, 3.1262658, 3.78325  ],
#       dtype=float32)}
# action:  {'agent-0': array([-2.484225 ,  0.6743672], dtype=float32), 'agent-1': array([-2.7835436 ,  0.25111386], dtype=float32), 'agent-2': array([-1.8855956 ,  0.87773764], dtype=float32)}
# reward:  {'agent-0': -0.40935631710118336, 'agent-1': 0.24250634210062216, 'agent-2': -0.11042153670768862}
#
# obs:  {'agent-0': array([-1.5839761 ,  2.7597268 , -2.5743177 ,  3.5095568 , -0.88996387,
#         3.1885257 , -1.5472414 ,  2.733469  , -2.581963  ,  3.4851573 ,
#        -0.8473678 ,  3.2269871 ], dtype=float32), 'agent-1': array([ 0.09426331,  3.3337467 , -0.0174526 ,  3.7556186 ,  0.5670048 ,
#         3.4817376 ,  0.0966629 ,  3.342357  , -0.02627692,  3.7809134 ,
#         0.56537354,  3.484378  ], dtype=float32), 'agent-2': array([ 2.9814444,  2.7910843,  2.313447 ,  3.1711392, -3.1370068,
#         3.7672677,  2.9243124,  2.7842865,  2.2873762,  3.19056  ,
#         3.1209588,  3.7607756], dtype=float32)}
# action:  {'agent-0': array([1.6841118 , 0.83555716], dtype=float32), 'agent-1': array([2.0672195, 0.734175 ], dtype=float32), 'agent-2': array([-2.8211813 ,  0.19017711], dtype=float32)}
# reward:  {'agent-0': 0.8284833720250582, 'agent-1': 0.2788327969284019, 'agent-2': -0.16888679672267237}
#
# obs:  {'agent-0': array([-1.5915235 ,  2.7058506 , -2.5962734 ,  3.4913142 , -0.83629435,
#         3.1399379 , -1.5839761 ,  2.7597268 , -2.5743177 ,  3.5095568 ,
#        -0.88996387,  3.1885257 ], dtype=float32), 'agent-1': array([ 0.11950853,  3.3237538 ,  0.01802656,  3.7538047 ,  0.5916032 ,
#         3.5040345 ,  0.09426331,  3.3337467 , -0.0174526 ,  3.7556186 ,
#         0.5670048 ,  3.4817376 ], dtype=float32), 'agent-2': array([ 2.987128 ,  2.801393 ,  2.2916415,  3.1722264, -3.1376665,
#         3.766    ,  2.9814444,  2.7910843,  2.313447 ,  3.1711392,
#        -3.1370068,  3.7672677], dtype=float32)}
# action:  {'agent-0': array([-0.7369778 ,  0.65421414], dtype=float32), 'agent-1': array([3.073827 , 0.4655308], dtype=float32), 'agent-2': array([-1.9192334 ,  0.11805552], dtype=float32)}
# reward:  {'agent-0': -0.43798600822819544, 'agent-1': 0.4572484066725302, 'agent-2': -0.023189344454120686}
#
# obs:  {'agent-0': array([-1.557261  ,  2.734694  , -2.5533538 ,  3.48762   , -0.82582724,
#         3.1709952 , -1.5915235 ,  2.7058506 , -2.5962734 ,  3.4913142 ,
#        -0.83629435,  3.1399379 ], dtype=float32), 'agent-1': array([0.1228032 , 3.3071477 , 0.02035801, 3.747172  , 0.5771074 ,
#        3.4812436 , 0.11950853, 3.3237538 , 0.01802656, 3.7538047 ,
#        0.5916032 , 3.5040345 ], dtype=float32), 'agent-2': array([ 2.9946063,  2.8028002,  2.3178809,  3.1409302, -3.1195846,
#         3.7590432,  2.987128 ,  2.801393 ,  2.2916415,  3.1722264,
#        -3.1376665,  3.766    ], dtype=float32)}
# action:  {'agent-0': array([1.6883285, 0.5939193], dtype=float32), 'agent-1': array([3.123111 , 0.0622783], dtype=float32), 'agent-2': array([-2.7980394 ,  0.32904664], dtype=float32)}
# reward:  {'agent-0': 0.5905728670447914, 'agent-1': 0.061656287401525844, 'agent-2': -0.2910063799640632}
#
# obs:  {'agent-0': array([-1.5617241 ,  2.6956036 , -2.5612512 ,  3.4679437 , -0.8054889 ,
#         3.1484861 , -1.557261  ,  2.734694  , -2.5533538 ,  3.48762   ,
#        -0.82582724,  3.1709952 ], dtype=float32), 'agent-1': array([0.12313734, 3.3048873 , 0.02307749, 3.7467117 , 0.5984489 ,
#        3.4747446 , 0.1228032 , 3.3071477 , 0.02035801, 3.747172  ,
#        0.5771074 , 3.4812436 ], dtype=float32), 'agent-2': array([ 3.0044289,  2.820293 ,  2.3335648,  3.174261 , -3.1160948,
#         3.7555125,  2.9946063,  2.8028002,  2.3178809,  3.1409302,
#        -3.1195846,  3.7590432], dtype=float32)}
# action:  {'agent-0': array([2.5514896, 0.0648568], dtype=float32), 'agent-1': array([-2.6356926 ,  0.46652538], dtype=float32), 'agent-2': array([-1.5100946,  0.6569941], dtype=float32)}
# reward:  {'agent-0': 0.03647264848210341, 'agent-1': 0.43217782613759326, 'agent-2': 0.11590016827031313}
#
# obs:  {'agent-0': array([-1.5656114,  2.6931386, -2.5620444,  3.4671278, -0.7926901,
#         3.1516216, -1.5617241,  2.6956036, -2.5612512,  3.4679437,
#        -0.8054889,  3.1484861], dtype=float32), 'agent-1': array([0.11638728, 3.288898  , 0.02034151, 3.7443316 , 0.5826259 ,
#        3.4517045 , 0.12313734, 3.3048873 , 0.02307749, 3.7467117 ,
#        0.5984489 , 3.4747446 ], dtype=float32), 'agent-2': array([ 3.0455601,  2.8133626,  2.369179 ,  3.133184 , -3.1002738,
#         3.7536368,  3.0044289,  2.820293 ,  2.3335648,  3.174261 ,
#        -3.1160948,  3.7555125], dtype=float32)}
# action:  {'agent-0': array([1.7923744 , 0.49491757], dtype=float32), 'agent-1': array([2.924225 , 0.4464337], dtype=float32), 'agent-2': array([-1.9805388 ,  0.62474364], dtype=float32)}
# reward:  {'agent-0': 0.48295055611879256, 'agent-1': 0.4213778389158662, 'agent-2': -0.2039193804231605}
#
# obs:  {'agent-0': array([-1.5736041,  2.659912 , -2.5761597,  3.4470923, -0.7603897,
#         3.1121745, -1.5656114,  2.6931386, -2.5620444,  3.4671278,
#        -0.7926901,  3.1516216], dtype=float32), 'agent-1': array([0.12214696, 3.273058  , 0.03899631, 3.733553  , 0.59123087,
#        3.4426386 , 0.11638728, 3.288898  , 0.02034151, 3.7443316 ,
#        0.5826259 , 3.4517045 ], dtype=float32), 'agent-2': array([ 3.0830145,  2.825524 ,  2.3955953,  3.121001 , -3.0917687,
#         3.7502747,  3.0455601,  2.8133626,  2.369179 ,  3.133184 ,
#        -3.1002738,  3.7536368], dtype=float32)}
# action:  {'agent-0': array([-1.7764806 ,  0.62693703], dtype=float32), 'agent-1': array([1.8616378 , 0.96054906], dtype=float32), 'agent-2': array([-2.6359446 ,  0.34689763], dtype=float32)}
# reward:  {'agent-0': -0.6146528119073871, 'agent-1': 0.14350920175137816, 'agent-2': -0.2941939341108668}
#
# obs:  {'agent-0': array([-1.5826857 ,  2.702011  , -2.551125  ,  3.4512231 , -0.75789744,
#         3.1173089 , -1.5736041 ,  2.659912  , -2.5761597 ,  3.4470923 ,
#        -0.7603897 ,  3.1121745 ], dtype=float32), 'agent-1': array([0.15965965, 3.2676053 , 0.07552363, 3.7349613 , 0.60624385,
#        3.446113  , 0.12214696, 3.273058  , 0.03899631, 3.733553  ,
#        0.59123087, 3.4426386 ], dtype=float32), 'agent-2': array([ 3.0944912,  2.842813 ,  2.4241385,  3.1081247, -3.0852354,
#         3.7474911,  3.0830145,  2.825524 ,  2.3955953,  3.121001 ,
#        -3.0917687,  3.7502747], dtype=float32)}
# action:  {'agent-0': array([-1.1799762 ,  0.62417185], dtype=float32), 'agent-1': array([-2.4832463,  0.0507457], dtype=float32), 'agent-2': array([-1.7331907 ,  0.67248183], dtype=float32)}
# reward:  {'agent-0': -0.5763052409556266, 'agent-1': 0.04455376538964728, 'agent-2': -0.09109294840382987}
#
# obs:  {'agent-0': array([-1.5657982 ,  2.7399359 , -2.50174   ,  3.4652367 , -0.75453013,
#         3.146733  , -1.5826857 ,  2.702011  , -2.551125  ,  3.4512231 ,
#        -0.75789744,  3.1173089 ], dtype=float32), 'agent-1': array([0.1586967 , 3.2659066 , 0.07835946, 3.74146   , 0.6201714 ,
#        3.4590075 , 0.15965965, 3.2676053 , 0.07552363, 3.7349613 ,
#        0.60624385, 3.446113  ], dtype=float32), 'agent-2': array([ 3.1355987,  2.8481061,  2.4253063,  3.1060066, -3.046773 ,
#         3.7463908,  3.0944912,  2.842813 ,  2.4241385,  3.1081247,
#        -3.0852354,  3.7474911], dtype=float32)}
# action:  {'agent-0': array([-2.725772  ,  0.19048741], dtype=float32), 'agent-1': array([-0.14161706,  0.7088052 ], dtype=float32), 'agent-2': array([-2.9788928 ,  0.17818448], dtype=float32)}
# reward:  {'agent-0': -0.07712087973250625, 'agent-1': -0.6779310792329198, 'agent-2': -0.17568237190408809}
#
# obs:  {'agent-0': array([-1.5777901 ,  2.7449036 , -2.50313   ,  3.4694493 , -0.736991  ,
#         3.127362  , -1.5657982 ,  2.7399359 , -2.50174   ,  3.4652367 ,
#        -0.75453013,  3.146733  ], dtype=float32), 'agent-1': array([0.1505952 , 3.291449  , 0.09022279, 3.7615378 , 0.6239436 ,
#        3.4794056 , 0.1586967 , 3.2659066 , 0.07835946, 3.74146   ,
#        0.6201714 , 3.4590075 ], dtype=float32), 'agent-2': array([ 3.1374195,  2.858236 ,  2.4188554,  3.1356714, -3.0471349,
#         3.7495692,  3.1355987,  2.8481061,  2.4253063,  3.1060066,
#        -3.046773 ,  3.7463908], dtype=float32)}
# action:  {'agent-0': array([2.600416  , 0.13158152], dtype=float32), 'agent-1': array([-3.0497165,  0.6891247], dtype=float32), 'agent-2': array([0.6545253, 0.6678784], dtype=float32)}
# reward:  {'agent-0': 0.06655076112009795, 'agent-1': 0.6879045612918127, 'agent-2': 0.5228977244793285}
#
# obs:  {'agent-0': array([-1.5856025,  2.7406182, -2.522708 ,  3.486737 , -0.7317633,
#         3.126574 , -1.5777901,  2.7449036, -2.50313  ,  3.4694493,
#        -0.736991 ,  3.127362 ], dtype=float32), 'agent-1': array([0.15220042, 3.2655258 , 0.09050623, 3.7495773 , 0.6339406 ,
#        3.4668136 , 0.1505952 , 3.291449  , 0.09022279, 3.7615378 ,
#        0.6239436 , 3.4794056 ], dtype=float32), 'agent-2': array([ 3.1117187,  2.8277783,  2.3808675,  3.1272676, -3.0596404,
#         3.7525425,  3.1374195,  2.858236 ,  2.4188554,  3.1356714,
#        -3.0471349,  3.7495692], dtype=float32)}
# action:  {'agent-0': array([-0.6157234,  0.381505 ], dtype=float32), 'agent-1': array([0.20777845, 0.5438387 ], dtype=float32), 'agent-2': array([-1.9702096,  0.837972 ], dtype=float32)}
# reward:  {'agent-0': -0.21906742717606598, 'agent-1': -0.5430166896444817, 'agent-2': -0.3214858941228371}
#
# obs:  {'agent-0': array([-1.5642173 ,  2.7546556 , -2.4998825 ,  3.4646645 , -0.75952536,
#         3.138128  , -1.5856025 ,  2.7406182 , -2.522708  ,  3.486737  ,
#        -0.7317633 ,  3.126574  ], dtype=float32), 'agent-1': array([0.15337422, 3.2860446 , 0.08343266, 3.7490292 , 0.6229777 ,
#        3.4837697 , 0.15220042, 3.2655258 , 0.09050623, 3.7495773 ,
#        0.6339406 , 3.4668136 ], dtype=float32), 'agent-2': array([-3.1233003,  2.846614 ,  2.4161646,  3.109072 , -3.0418358,
#         3.7456086,  3.1117187,  2.8277783,  2.3808675,  3.1272676,
#        -3.0596404,  3.7525425], dtype=float32)}
# action:  {'agent-0': array([-0.8158622,  0.2097036], dtype=float32), 'agent-1': array([-1.235365  ,  0.28926903], dtype=float32), 'agent-2': array([0.49795365, 0.69883037], dtype=float32)}
# reward:  {'agent-0': -0.15435732178449335, 'agent-1': -0.05394212167490764, 'agent-2': 0.6166371269431234}
#
# obs:  {'agent-0': array([-1.5546213 ,  2.7644296 , -2.500528  ,  3.479253  , -0.72438973,
#         3.1349862 , -1.5642173 ,  2.7546556 , -2.4998825 ,  3.4646645 ,
#        -0.75952536,  3.138128  ], dtype=float32), 'agent-1': array([0.1423434 , 3.28806   , 0.09444863, 3.759887  , 0.6256315 ,
#        3.4774177 , 0.15337422, 3.2860446 , 0.08343266, 3.7490292 ,
#        0.6229777 , 3.4837697 ], dtype=float32), 'agent-2': array([ 3.1392274,  2.8101678,  2.3876085,  3.1157491, -3.0469859,
#         3.743174 , -3.1233003,  2.846614 ,  2.4161646,  3.109072 ,
#        -3.0418358,  3.7456086], dtype=float32)}
# action:  {'agent-0': array([2.8796093, 0.7923287], dtype=float32), 'agent-1': array([-1.7687593,  0.5569611], dtype=float32), 'agent-2': array([-2.2028816 ,  0.19757625], dtype=float32)}
# reward:  {'agent-0': 0.19776771651685898, 'agent-1': 0.180518055207461, 'agent-2': -0.11716681899338255}
#
# obs:  {'agent-0': array([-1.6065711 ,  2.7518897 , -2.5287254 ,  3.4920044 , -0.77236927,
#         3.0939848 , -1.5546213 ,  2.7644296 , -2.500528  ,  3.479253  ,
#        -0.72438973,  3.1349862 ], dtype=float32), 'agent-1': array([0.1218416 , 3.281299  , 0.07481808, 3.7411928 , 0.62011933,
#        3.4638858 , 0.1423434 , 3.28806   , 0.09444863, 3.759887  ,
#        0.6256315 , 3.4774177 ], dtype=float32), 'agent-2': array([-3.1338062,  2.817196 ,  2.3960342,  3.1239657, -3.0502021,
#         3.7479098,  3.1392274,  2.8101678,  2.3876085,  3.1157491,
#        -3.0469859,  3.743174 ], dtype=float32)}
# action:  {'agent-0': array([-1.9808251 ,  0.09716052], dtype=float32), 'agent-1': array([1.7712858 , 0.36911216], dtype=float32), 'agent-2': array([1.4208472 , 0.30802178], dtype=float32)}
# reward:  {'agent-0': -0.0904778555619945, 'agent-1': 0.02635357750982692, 'agent-2': 0.04543452131435188}
#
# obs:  {'agent-0': array([-1.6089771 ,  2.757646  , -2.5392885 ,  3.482246  , -0.76739657,
#         3.0943055 , -1.6065711 ,  2.7518897 , -2.5287254 ,  3.4920044 ,
#        -0.77236927,  3.0939848 ], dtype=float32), 'agent-1': array([0.13622499, 3.2803082 , 0.08734301, 3.7432144 , 0.61142665,
#        3.484189  , 0.1218416 , 3.281299  , 0.07481808, 3.7411928 ,
#        0.62011933, 3.4638858 ], dtype=float32), 'agent-2': array([ 3.129983 ,  2.8144765,  2.366649 ,  3.100851 , -3.0704157,
#         3.742614 , -3.1338062,  2.817196 ,  2.3960342,  3.1239657,
#        -3.0502021,  3.7479098], dtype=float32)}
# action:  {'agent-0': array([-2.956406  ,  0.09028545], dtype=float32), 'agent-1': array([-0.8394189,  0.3173073], dtype=float32), 'agent-2': array([0.57847595, 0.30676538], dtype=float32)}
# reward:  {'agent-0': -0.020261715991555462, 'agent-1': -0.1792334640295543, 'agent-2': 0.25394504991830047}
#
# obs:  {'agent-0': array([-1.6149328 ,  2.7589307 , -2.5297441 ,  3.4892404 , -0.782714  ,
#         3.10011   , -1.6089771 ,  2.757646  , -2.5392885 ,  3.482246  ,
#        -0.76739657,  3.0943055 ], dtype=float32), 'agent-1': array([0.12602614, 3.2870278 , 0.07396744, 3.7460945 , 0.6030938 ,
#        3.487923  , 0.13622499, 3.2803082 , 0.08734301, 3.7432144 ,
#        0.61142665, 3.484189  ], dtype=float32), 'agent-2': array([ 3.1189206,  2.799139 ,  2.3482275,  3.0995948, -3.065109 ,
#         3.7351193,  3.129983 ,  2.8144765,  2.366649 ,  3.100851 ,
#        -3.0704157,  3.742614 ], dtype=float32)}
# action:  {'agent-0': array([0.739882 , 0.8989911], dtype=float32), 'agent-1': array([0.8108182 , 0.61085254], dtype=float32), 'agent-2': array([-0.7392249,  0.9353248], dtype=float32)}
# reward:  {'agent-0': 0.6204921311849318, 'agent-1': -0.47598100399673626, 'agent-2': 0.6924959209238928}
#
# obs:  {'agent-0': array([-1.5699707,  2.718823 , -2.5436504,  3.4629273, -0.7544921,
#         3.0995657, -1.6149328,  2.7589307, -2.5297441,  3.4892404,
#        -0.782714 ,  3.10011  ], dtype=float32), 'agent-1': array([0.14075164, 3.3046565 , 0.0802791 , 3.7504451 , 0.60585123,
#        3.5085044 , 0.12602614, 3.2870278 , 0.07396744, 3.7460945 ,
#        0.6030938 , 3.487923  ], dtype=float32), 'agent-2': array([-3.1225705,  2.756078 ,  2.342015 ,  3.054237 , -3.0544913,
#         3.7244287,  3.1189206,  2.799139 ,  2.3482275,  3.0995948,
#        -3.065109 ,  3.7351193], dtype=float32)}
# action:  {'agent-0': array([0.42843795, 0.41484433], dtype=float32), 'agent-1': array([-1.7460724 ,  0.04942256], dtype=float32), 'agent-2': array([0.4971447 , 0.13385731], dtype=float32)}
# reward:  {'agent-0': 0.16694384105280946, 'agent-1': 0.015318136226170509, 'agent-2': 0.11871685495363593}
#
# obs:  {'agent-0': array([-1.5429952 ,  2.7077515 , -2.53725   ,  3.4688265 , -0.73637795,
#         3.0640144 , -1.5699707 ,  2.718823  , -2.5436504 ,  3.4629273 ,
#        -0.7544921 ,  3.0995657 ], dtype=float32), 'agent-1': array([0.13896033, 3.304094  , 0.09582539, 3.7351432 , 0.60091907,
#        3.480407  , 0.14075164, 3.3046565 , 0.0802791 , 3.7504451 ,
#        0.60585123, 3.5085044 ], dtype=float32), 'agent-2': array([-3.1267834,  2.748506 ,  2.3801057,  3.054548 , -3.0458817,
#         3.7325144, -3.1225705,  2.756078 ,  2.342015 ,  3.054237 ,
#        -3.0544913,  3.7244287], dtype=float32)}
# action:  {'agent-0': array([2.8270953, 0.5465906], dtype=float32), 'agent-1': array([-2.233902  ,  0.19374347], dtype=float32), 'agent-2': array([-2.9929323,  0.5024837], dtype=float32)}
# reward:  {'agent-0': 0.1738714443555125, 'agent-1': 0.13891386691555851, 'agent-2': -0.4981378855608565}
#
# obs:  {'agent-0': array([-1.5802555 ,  2.696089  , -2.5522075 ,  3.4781418 , -0.75399697,
#         3.038479  , -1.5429952 ,  2.7077515 , -2.53725   ,  3.4688265 ,
#        -0.73637795,  3.0640144 ], dtype=float32), 'agent-1': array([0.13379662, 3.2989783 , 0.09107946, 3.7290118 , 0.6013301 ,
#        3.4619646 , 0.13896033, 3.304094  , 0.09582539, 3.7351432 ,
#        0.60091907, 3.480407  ], dtype=float32), 'agent-2': array([-3.1223476,  2.7799006,  2.4179065,  3.0768015, -3.0463912,
#         3.744139 , -3.1267834,  2.748506 ,  2.3801057,  3.054548 ,
#        -3.0458817,  3.7325144], dtype=float32)}
# action:  {'agent-0': array([-2.6032667 ,  0.02422726], dtype=float32), 'agent-1': array([0.24632668, 0.31165934], dtype=float32), 'agent-2': array([0.18360662, 0.58822495], dtype=float32)}
# reward:  {'agent-0': -0.01263296302936645, 'agent-1': -0.30971134529993805, 'agent-2': 0.5799788301683453}
#
# obs:  {'agent-0': array([-1.5817505 ,  2.696941  , -2.5541878 ,  3.4731987 , -0.73560566,
#         3.0531294 , -1.5802555 ,  2.696089  , -2.5522075 ,  3.4781418 ,
#        -0.75399697,  3.038479  ], dtype=float32), 'agent-1': array([0.13512252, 3.3103483 , 0.09293982, 3.7482696 , 0.5841339 ,
#        3.4815288 , 0.13379662, 3.2989783 , 0.09107946, 3.7290118 ,
#        0.6013301 , 3.4619646 ], dtype=float32), 'agent-2': array([-3.1289685,  2.7432525,  2.3835752,  3.0367239, -3.0511403,
#         3.726991 , -3.1223476,  2.7799006,  2.4179065,  3.0768015,
#        -3.0463912,  3.744139 ], dtype=float32)}
# action:  {'agent-0': array([1.3648512 , 0.63464934], dtype=float32), 'agent-1': array([1.583719  , 0.14045656], dtype=float32), 'agent-2': array([1.0869424, 0.367749 ], dtype=float32)}
# reward:  {'agent-0': 0.6220501216563417, 'agent-1': -0.017489002023371114, 'agent-2': 0.17153113141492504}
#
# obs:  {'agent-0': array([-1.5724432 ,  2.654103  , -2.5718634 ,  3.4684181 , -0.73150516,
#         3.0206354 , -1.5817505 ,  2.696941  , -2.5541878 ,  3.4731987 ,
#        -0.73560566,  3.0531294 ], dtype=float32), 'agent-1': array([0.14040077, 3.3109865 , 0.0950622 , 3.7346432 , 0.58783686,
#        3.484611  , 0.13512252, 3.3103483 , 0.09293982, 3.7482696 ,
#        0.5841339 , 3.4815288 ], dtype=float32), 'agent-2': array([ 3.131707 ,  2.7321513,  2.3646443,  3.0413477, -3.0575435,
#         3.729609 , -3.1289685,  2.7432525,  2.3835752,  3.0367239,
#        -3.0511403,  3.726991 ], dtype=float32)}
# action:  {'agent-0': array([-2.5233612,  0.1918559], dtype=float32), 'agent-1': array([-2.7920437,  0.2886523], dtype=float32), 'agent-2': array([0.28913665, 0.8149588 ], dtype=float32)}
# reward:  {'agent-0': -0.1123711526687714, 'agent-1': 0.28229329593087016, 'agent-2': 0.7766741477780776}
#
# obs:  {'agent-0': array([-1.5841633 ,  2.6619787 , -2.5677636 ,  3.476678  , -0.7593062 ,
#         3.023345  , -1.5724432 ,  2.654103  , -2.5718634 ,  3.4684181 ,
#        -0.73150516,  3.0206354 ], dtype=float32), 'agent-1': array([0.13810715, 3.3006349 , 0.08564255, 3.7231436 , 0.5756324 ,
#        3.4619484 , 0.14040077, 3.3109865 , 0.0950622 , 3.7346432 ,
#        0.58783686, 3.484611  ], dtype=float32), 'agent-2': array([ 3.1140394,  2.6802838,  2.3553002,  3.0055432, -3.0581923,
#         3.710517 ,  3.131707 ,  2.7321513,  2.3646443,  3.0413477,
#        -3.0575435,  3.729609 ], dtype=float32)}
# action:  {'agent-0': array([-1.489704  ,  0.04323974], dtype=float32), 'agent-1': array([0.74499893, 0.42479384], dtype=float32), 'agent-2': array([1.3856523 , 0.29416576], dtype=float32)}
# reward:  {'agent-0': -0.043047603578180826, 'agent-1': -0.35004441826959365, 'agent-2': 0.04305046930037726}
#
# obs:  {'agent-0': array([-1.5838583 ,  2.6649792 , -2.5644734 ,  3.468584  , -0.79760426,
#         3.0056646 , -1.5841633 ,  2.6619787 , -2.5677636 ,  3.476678  ,
#        -0.7593062 ,  3.023345  ], dtype=float32), 'agent-1': array([0.14725637, 3.3134549 , 0.08803499, 3.711913  , 0.5781657 ,
#        3.480918  , 0.13810715, 3.3006349 , 0.08564255, 3.7231436 ,
#        0.5756324 , 3.4619484 ], dtype=float32), 'agent-2': array([ 3.092591 ,  2.6773286,  2.3329675,  3.0124238, -3.06729  ,
#         3.7017963,  3.1140394,  2.6802838,  2.3553002,  3.0055432,
#        -3.0581923,  3.710517 ], dtype=float32)}
# action:  {'agent-0': array([-1.5309458 ,  0.99171937], dtype=float32), 'agent-1': array([3.0195725 , 0.23991996], dtype=float32), 'agent-2': array([-0.821502,  0.674067], dtype=float32)}
# reward:  {'agent-0': -0.9904272182678504, 'agent-1': 0.23119651113141515, 'agent-2': 0.4742767218787698}
#
# obs:  {'agent-0': array([-1.5802052 ,  2.7316418 , -2.5356543 ,  3.4974449 , -0.8425621 ,
#         3.0504985 , -1.5838583 ,  2.6649792 , -2.5644734 ,  3.468584  ,
#        -0.79760426,  3.0056646 ], dtype=float32), 'agent-1': array([0.14968799, 3.305006  , 0.08214808, 3.7042289 , 0.5843138 ,
#        3.4759111 , 0.14725637, 3.3134549 , 0.08803499, 3.711913  ,
#        0.5781657 , 3.480918  ], dtype=float32), 'agent-2': array([ 3.1285884,  2.6441803,  2.3319755,  2.980427 , -3.047251 ,
#         3.6998072,  3.092591 ,  2.6773286,  2.3329675,  3.0124238,
#        -3.06729  ,  3.7017963], dtype=float32)}
# action:  {'agent-0': array([-2.805071  ,  0.87734354], dtype=float32), 'agent-1': array([0.91755605, 0.01056516], dtype=float32), 'agent-2': array([2.6268113, 0.3740231], dtype=float32)}
# reward:  {'agent-0': -0.3207058752698284, 'agent-1': -0.0076015306539041205, 'agent-2': -0.3291245497990296}
#
# obs:  {'agent-0': array([-1.6364636 ,  2.7523086 , -2.537914  ,  3.517427  , -0.88569504,
#         3.00245   , -1.5802052 ,  2.7316418 , -2.5356543 ,  3.4974449 ,
#        -0.8425621 ,  3.0504985 ], dtype=float32), 'agent-1': array([0.14996749, 3.305285  , 0.09585273, 3.6941755 , 0.61105007,
# ...
# reward:  {'agent-0': 0.2580201385774057, 'agent-1': 0.9329330153089082, 'agent-2': -0.03530674571142356}
#
# obs:  {'agent-0': array([-1.6979278 ,  2.817745  , -2.3129015 ,  3.5525246 , -0.73696774,
#         3.194803  , -1.6802504 ,  2.8330417 , -2.3132296 ,  3.5586305 ,
#        -0.7344751 ,  3.2191157 ], dtype=float32), 'agent-1': array([0.4252141 , 3.134984  , 0.22367361, 3.7223904 , 0.85361767,
#        3.5302935 , 0.42136094, 3.174765  , 0.22317773, 3.7497425 ,
#        0.8427505 , 3.5460005 ], dtype=float32), 'agent-2': array([ 3.1359746,  3.0137248,  2.4038963,  3.2110002, -2.9154806,
#         3.7455251,  3.135517 ,  3.0119894,  2.4141662,  3.2141066,
#        -2.9209094,  3.75314  ], dtype=float32)}
# action:  {'agent-0': array([1.5799091, 0.5012182], dtype=float32), 'agent-1': array([-3.041763 ,  0.7279272], dtype=float32), 'agent-2': array([-1.4266926,  0.9232105], dtype=float32)}
# reward:  {'agent-0': 0.49642143880899603, 'agent-1': 0.6884601709145137, 'agent-2': 0.11604775066042095}
#
# obs:  {'agent-0': array([-1.702394  ,  2.7876399 , -2.309681  ,  3.5178533 , -0.7197189 ,
#         3.1817536 , -1.6979278 ,  2.817745  , -2.3129015 ,  3.5525246 ,
#        -0.73696774,  3.194803  ], dtype=float32), 'agent-1': array([0.43613926, 3.104578  , 0.22595477, 3.70567   , 0.85733724,
#        3.5129921 , 0.4252141 , 3.134984  , 0.22367361, 3.7223904 ,
#        0.85361767, 3.5302935 ], dtype=float32), 'agent-2': array([-3.0997632,  3.0080097,  2.4318104,  3.1664007, -2.89517  ,
#         3.7252934,  3.1359746,  3.0137248,  2.4038963,  3.2110002,
#        -2.9154806,  3.7455251], dtype=float32)}
# action:  {'agent-0': array([-2.5123227,  0.4319681], dtype=float32), 'agent-1': array([2.8094847, 0.5417635], dtype=float32), 'agent-2': array([1.6796062 , 0.13299164], dtype=float32)}
# reward:  {'agent-0': -0.301012316019019, 'agent-1': 0.386209719452836, 'agent-2': -0.009358359774235936}
#
# obs:  {'agent-0': array([-1.7225224,  2.8060024, -2.2974207,  3.514411 , -0.7117219,
#         3.1481397, -1.702394 ,  2.7876399, -2.309681 ,  3.5178533,
#        -0.7197189,  3.1817536], dtype=float32), 'agent-1': array([0.45414087, 3.0871074 , 0.25666308, 3.6966426 , 0.8626977 ,
#        3.4956393 , 0.43613926, 3.104578  , 0.22595477, 3.70567   ,
#        0.85733724, 3.5129921 ], dtype=float32), 'agent-2': array([-3.1066542,  3.0084717,  2.444541 ,  3.1566088, -2.8958092,
#         3.7073343, -3.0997632,  3.0080097,  2.4318104,  3.1664007,
#        -2.89517  ,  3.7252934], dtype=float32)}
# action:  {'agent-0': array([2.8687327 , 0.53737867], dtype=float32), 'agent-1': array([-2.9668467 ,  0.40461028], dtype=float32), 'agent-2': array([-2.0092154 ,  0.10668263], dtype=float32)}
# reward:  {'agent-0': 0.055746456636235564, 'agent-1': 0.3886171920766657, 'agent-2': -0.04886769639151822}
#
# obs:  {'agent-0': array([-1.7569716,  2.802627 , -2.2968953,  3.5152242, -0.7262854,
#         3.1313922, -1.7225224,  2.8060024, -2.2974207,  3.514411 ,
#        -0.7117219,  3.1481397], dtype=float32), 'agent-1': array([0.45957726, 3.069214  , 0.25413194, 3.6861012 , 0.86759156,
#        3.4989111 , 0.45414087, 3.0871074 , 0.25666308, 3.6966426 ,
#        0.8626977 , 3.4956393 ], dtype=float32), 'agent-2': array([-3.1017356,  3.0108812,  2.4304094,  3.151076 , -2.88619  ,
#         3.6978517, -3.1066542,  3.0084717,  2.444541 ,  3.1566088,
#        -2.8958092,  3.7073343], dtype=float32)}
# action:  {'agent-0': array([3.091149 , 0.1193209], dtype=float32), 'agent-1': array([-1.8844283 ,  0.02853289], dtype=float32), 'agent-2': array([0.9666016 , 0.59495425], dtype=float32)}
# reward:  {'agent-0': -0.016596692614983866, 'agent-1': 0.019918219116551228, 'agent-2': 0.35126252446571016}
#
# obs:  {'agent-0': array([-1.7645968,  2.8036332, -2.2920115,  3.5079966, -0.725016 ,
#         3.125992 , -1.7569716,  2.802627 , -2.2968953,  3.5152242,
#        -0.7262854,  3.1313922], dtype=float32), 'agent-1': array([0.4585814 , 3.0682883 , 0.2556226 , 3.6874244 , 0.8521262 ,
#        3.5049887 , 0.45957726, 3.069214  , 0.25413194, 3.6861012 ,
#        0.86759156, 3.4989111 ], dtype=float32), 'agent-2': array([-3.1268394,  2.9934309,  2.393066 ,  3.1334682, -2.8954284,
#         3.6765065, -3.1017356,  3.0108812,  2.4304094,  3.151076 ,
#        -2.88619  ,  3.6978517], dtype=float32)}
# action:  {'agent-0': array([1.0072801 , 0.75630814], dtype=float32), 'agent-1': array([-1.5497626,  0.6313094], dtype=float32), 'agent-2': array([2.4299033 , 0.32381746], dtype=float32)}
# reward:  {'agent-0': 0.7026813121211948, 'agent-1': 0.25942073347148664, 'agent-2': -0.24327205610505587}
#
# obs:  {'agent-0': array([-1.7461324 ,  2.7601252 , -2.296127  ,  3.4845722 , -0.71784484,
#         3.123824  , -1.7645968 ,  2.8036332 , -2.2920115 ,  3.5079966 ,
#        -0.725016  ,  3.125992  ], dtype=float32), 'agent-1': array([0.43033275, 3.0561519 , 0.22948982, 3.6726835 , 0.8358458 ,
#        3.4932566 , 0.4585814 , 3.0682883 , 0.2556226 , 3.6874244 ,
#        0.8521262 , 3.5049887 ], dtype=float32), 'agent-2': array([-3.1380434,  3.0055487,  2.3901467,  3.143537 , -2.9029012,
#         3.680856 , -3.1268394,  2.9934309,  2.393066 ,  3.1334682,
#        -2.8954284,  3.6765065], dtype=float32)}
# action:  {'agent-0': array([2.9077456, 0.7271316], dtype=float32), 'agent-1': array([-1.2808284 ,  0.87751794], dtype=float32), 'agent-2': array([2.8090231, 0.7727108], dtype=float32)}
# reward:  {'agent-0': 0.024681538502232314, 'agent-1': 0.10401839713042094, 'agent-2': -0.7311011220320687}
#
# obs:  {'agent-0': array([-1.7952745 ,  2.758562  , -2.3300858 ,  3.4814343 , -0.7335514 ,
#         3.109774  , -1.7461324 ,  2.7601252 , -2.296127  ,  3.4845722 ,
#        -0.71784484,  3.123824  ], dtype=float32), 'agent-1': array([0.38718048, 3.0512438 , 0.20002665, 3.6792798 , 0.80721396,
#        3.4564643 , 0.43033275, 3.0561519 , 0.22948982, 3.6726835 ,
#        0.8358458 , 3.4932566 ], dtype=float32), 'agent-2': array([ 3.1323528,  3.041107 ,  2.4365864,  3.1686301, -2.9292822,
#         3.694058 , -3.1380434,  3.0055487,  2.3901467,  3.143537 ,
#        -2.9029012,  3.680856 ], dtype=float32)}
# action:  {'agent-0': array([-0.5817783 ,  0.87332463], dtype=float32), 'agent-1': array([-1.8384957 ,  0.03183973], dtype=float32), 'agent-2': array([0.34346867, 0.5408678 ], dtype=float32)}
# reward:  {'agent-0': -0.3276168530025938, 'agent-1': 0.01937658558892963, 'agent-2': 0.5066735414600672}
#
# obs:  {'agent-0': array([-1.7410816,  2.7791147, -2.3268917,  3.4630783, -0.7146918,
#         3.177836 , -1.7952745,  2.758562 , -2.3300858,  3.4814343,
#        -0.7335514,  3.109774 ], dtype=float32), 'agent-1': array([0.3859255 , 3.0503268 , 0.18931177, 3.6956425 , 0.78651667,
#        3.4673204 , 0.38718048, 3.0512438 , 0.20002665, 3.6792798 ,
#        0.80721396, 3.4564643 ], dtype=float32), 'agent-2': array([ 3.1227326,  3.0165992,  2.400056 ,  3.1299024, -2.9536867,
#         3.6826367,  3.1323528,  3.041107 ,  2.4365864,  3.1686301,
#        -2.9292822,  3.694058 ], dtype=float32)}
# action:  {'agent-0': array([1.221513  , 0.10604388], dtype=float32), 'agent-1': array([1.6068194 , 0.08312443], dtype=float32), 'agent-2': array([1.0127728 , 0.65427125], dtype=float32)}
# reward:  {'agent-0': 0.10433768575047075, 'agent-1': -0.02864686651005499, 'agent-2': 0.32765831669584244}
#
# obs:  {'agent-0': array([-1.739823 ,  2.772615 , -2.3287396,  3.4591396, -0.7310973,
#         3.1652493, -1.7410816,  2.7791147, -2.3268917,  3.4630783,
#        -0.7146918,  3.177836 ], dtype=float32), 'agent-1': array([0.38980064, 3.0516822 , 0.18928857, 3.6826017 , 0.81613034,
#        3.464027  , 0.3859255 , 3.0503268 , 0.18931177, 3.6956425 ,
#        0.78651667, 3.4673204 ], dtype=float32), 'agent-2': array([ 3.0933237,  3.0004244,  2.37799  ,  3.1721578, -2.9669814,
#         3.6711335,  3.1227326,  3.0165992,  2.400056 ,  3.1299024,
#        -2.9536867,  3.6826367], dtype=float32)}
# action:  {'agent-0': array([2.4756258, 0.5684341], dtype=float32), 'agent-1': array([0.75465083, 0.4452753 ], dtype=float32), 'agent-2': array([-2.137782 ,  0.2982505], dtype=float32)}
# reward:  {'agent-0': 0.26252113766467033, 'agent-1': -0.4165797078252922, 'agent-2': -0.14960573035135027}
#
# obs:  {'agent-0': array([-1.7737339 ,  2.7560716 , -2.3451378 ,  3.4627392 , -0.76173025,
#         3.146328  , -1.739823  ,  2.772615  , -2.3287396 ,  3.4591396 ,
#        -0.7310973 ,  3.1652493 ], dtype=float32), 'agent-1': array([0.39752546, 3.0711863 , 0.18304847, 3.6808908 , 0.81391966,
#        3.4748325 , 0.38980064, 3.0516822 , 0.18928857, 3.6826017 ,
#        0.81613034, 3.464027  ], dtype=float32), 'agent-2': array([ 3.1067839,  3.007842 ,  2.3951066,  3.168058 , -2.9591327,
#         3.6765678,  3.0933237,  3.0004244,  2.37799  ,  3.1721578,
#        -2.9669814,  3.6711335], dtype=float32)}
# action:  {'agent-0': array([1.272217  , 0.24757797], dtype=float32), 'agent-1': array([-2.165729 ,  0.8224317], dtype=float32), 'agent-2': array([2.8223083, 0.51076  ], dtype=float32)}
# reward:  {'agent-0': 0.24642719998183615, 'agent-1': 0.6835985025853795, 'agent-2': -0.49075266264955175}
#
# obs:  {'agent-0': array([-1.7721024 ,  2.7402894 , -2.3493783 ,  3.4697692 , -0.73845285,
#         3.1393213 , -1.7737339 ,  2.7560716 , -2.3451378 ,  3.4627392 ,
#        -0.76173025,  3.146328  ], dtype=float32), 'agent-1': array([0.37491384, 3.0389774 , 0.17345217, 3.6714683 , 0.79103994,
#        3.4512677 , 0.39752546, 3.0711863 , 0.18304847, 3.6808908 ,
#        0.81391966, 3.4748325 ], dtype=float32), 'agent-2': array([ 3.09952  ,  3.0317953,  2.402428 ,  3.1637928, -2.9592483,
#         3.6971626,  3.1067839,  3.007842 ,  2.3951066,  3.168058 ,
#        -2.9591327,  3.6765678], dtype=float32)}
# action:  {'agent-0': array([2.0949056 , 0.96596575], dtype=float32), 'agent-1': array([-1.272776  ,  0.35729325], dtype=float32), 'agent-2': array([2.6991103 , 0.60307086], dtype=float32)}
# reward:  {'agent-0': 0.707852193441683, 'agent-1': 0.024251160011804274, 'agent-2': -0.5567304861120341}
#
# obs:  {'agent-0': array([-1.8186139 ,  2.6935196 , -2.38534   ,  3.4367025 , -0.7153025 ,
#         3.1197224 , -1.7721024 ,  2.7402894 , -2.3493783 ,  3.4697692 ,
#        -0.73845285,  3.1393213 ], dtype=float32), 'agent-1': array([0.3569751 , 3.0378156 , 0.15809067, 3.6840818 , 0.776802  ,
#        3.4389696 , 0.37491384, 3.0389774 , 0.17345217, 3.6714683 ,
#        0.79103994, 3.4512677 ], dtype=float32), 'agent-2': array([ 3.0879347,  3.0582917,  2.4197292,  3.1836534, -2.983171 ,
#         3.6952655,  3.09952  ,  3.0317953,  2.402428 ,  3.1637928,
#        -2.9592483,  3.6971626], dtype=float32)}
# action:  {'agent-0': array([1.0914118, 0.5483117], dtype=float32), 'agent-1': array([-1.729069  ,  0.69062805], dtype=float32), 'agent-2': array([-1.5238048 ,  0.96939665], dtype=float32)}
# reward:  {'agent-0': 0.5330786032320916, 'agent-1': 0.3310581890769022, 'agent-2': 0.07438482804539603}
#
# obs:  {'agent-0': array([-1.8091168,  2.6567948, -2.4023669,  3.4148602, -0.6838265,
#         3.1399903, -1.8186139,  2.6935196, -2.38534  ,  3.4367025,
#        -0.7153025,  3.1197224], dtype=float32), 'agent-1': array([0.32619664, 3.0218174 , 0.13258769, 3.6914747 , 0.73100764,
#        3.4140623 , 0.3569751 , 3.0378156 , 0.15809067, 3.6840818 ,
#        0.776802  , 3.4389696 ], dtype=float32), 'agent-2': array([ 3.1356602,  3.054792 ,  2.466341 ,  3.1165643, -2.9677062,
#         3.6992874,  3.0879347,  3.0582917,  2.4197292,  3.1836534,
#        -2.983171 ,  3.6952655], dtype=float32)}
# action:  {'agent-0': array([0.12908316, 0.305084  ], dtype=float32), 'agent-1': array([2.7641604 , 0.16802311], dtype=float32), 'agent-2': array([2.211714  , 0.02020466], dtype=float32)}
# reward:  {'agent-0': 0.10650003235672045, 'agent-1': 0.12781294227287532, 'agent-2': -0.012183287031703571}
#
# obs:  {'agent-0': array([-1.7874533 ,  2.6492932 , -2.4113052 ,  3.3885813 , -0.64031076,
#         3.1217847 , -1.8091168 ,  2.6567948 , -2.4023669 ,  3.4148602 ,
#        -0.6838265 ,  3.1399903 ], dtype=float32), 'agent-1': array([0.3318    , 3.0155718 , 0.1594222 , 3.6902347 , 0.7295152 ,
#        3.394523  , 0.32619664, 3.0218174 , 0.13258769, 3.6914747 ,
#        0.73100764, 3.4140623 ], dtype=float32), 'agent-2': array([ 3.1348631,  3.055366 ,  2.4911358,  3.1129887, -2.984819 ,
#         3.694069 ,  3.1356602,  3.054792 ,  2.466341 ,  3.1165643,
#        -2.9677062,  3.6992874], dtype=float32)}
# action:  {'agent-0': array([0.8832853, 0.290632 ], dtype=float32), 'agent-1': array([2.3047664, 0.3742386], dtype=float32), 'agent-2': array([2.9878762, 0.1667797], dtype=float32)}
# reward:  {'agent-0': 0.2583312528878636, 'agent-1': 0.14340353243532888, 'agent-2': -0.16499591207155362}
#
# obs:  {'agent-0': array([-1.7772213 ,  2.63086   , -2.4075534 ,  3.376283  , -0.62721115,
#         3.1233237 , -1.7874533 ,  2.6492932 , -2.4113052 ,  3.3885813 ,
#        -0.64031076,  3.1217847 ], dtype=float32), 'agent-1': array([0.349684  , 3.0085177 , 0.16704534, 3.6854072 , 0.74866045,
#        3.3861609 , 0.3318    , 3.0155718 , 0.1594222 , 3.6902347 ,
#        0.7295152 , 3.394523  ], dtype=float32), 'agent-2': array([ 3.1336656,  3.063108 ,  2.5045865,  3.1291146, -2.9839368,
#         3.6944222,  3.1348631,  3.055366 ,  2.4911358,  3.1129887,
#        -2.984819 ,  3.694069 ], dtype=float32)}
# action:  {'agent-0': array([-0.08886313,  0.70053685], dtype=float32), 'agent-1': array([0.44803858, 0.49482822], dtype=float32), 'agent-2': array([-2.5070672,  0.9305634], dtype=float32)}
# reward:  {'agent-0': 0.06327971964988599, 'agent-1': -0.4924965345340553, 'agent-2': -0.7523874601913789}
#
# obs:  {'agent-0': array([-1.7229381 ,  2.6262925 , -2.3756115 ,  3.3603606 , -0.60784566,
#         3.1559732 , -1.7772213 ,  2.63086   , -2.4075534 ,  3.376283  ,
#        -0.62721115,  3.1233237 ], dtype=float32), 'agent-1': array([0.35214427, 3.032539  , 0.16918832, 3.7011817 , 0.74220425,
#        3.3924093 , 0.349684  , 3.0085177 , 0.16704534, 3.6854072 ,
#        0.74866045, 3.3861609 ], dtype=float32), 'agent-2': array([-3.12315  ,  3.097672 ,  2.5578027,  3.1430373, -2.965344 ,
#         3.7099564,  3.1336656,  3.063108 ,  2.5045865,  3.1291146,
#        -2.9839368,  3.6944222], dtype=float32)}
# action:  {'agent-0': array([-0.8227334 ,  0.31442112], dtype=float32), 'agent-1': array([0.9776218, 0.9285356], dtype=float32), 'agent-2': array([1.4649479 , 0.09553817], dtype=float32)}
# reward:  {'agent-0': -0.1977273633879406, 'agent-1': -0.7599549029937052, 'agent-2': 0.011631357755952365}
#
# obs:  {'agent-0': array([-1.7040174 ,  2.640496  , -2.3699641 ,  3.3767574 , -0.5726061 ,
#         3.1821103 , -1.7229381 ,  2.6262925 , -2.3756115 ,  3.3603606 ,
#        -0.60784566,  3.1559732 ], dtype=float32), 'agent-1': array([0.37865388, 3.0685086 , 0.19576593, 3.7372527 , 0.76736444,
#        3.407095  , 0.35214427, 3.032539  , 0.16918832, 3.7011817 ,
#        0.74220425, 3.3924093 ], dtype=float32), 'agent-2': array([-3.1276357,  3.0971467,  2.5686586,  3.1711934, -2.9643247,
#         3.7209136, -3.12315  ,  3.097672 ,  2.5578027,  3.1430373,
#        -2.965344 ,  3.7099564], dtype=float32)}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 27
#      25 out += sac_result_format(result) + "\n"
#      26 print(out)
# ---> 27 simulate_episode(RenderableRingFormation(config), algo, 200, sleep_between_frames=0.03, print_reward=True, print_action=True, print_ob = True)
#
# File /mnt/c/Users/nicol/Desktop/Università/tesi/experiments/RL_experiments/utils/simulations.py:16, in simulate_episode(env, policy, steps, sleep_between_frames, print_info, print_action, print_reward, print_ob)
#      13 #actions = {agent: np.array([rnd.random()*2-1, rnd.random()*2-1, 1.0], np.float32) for agent in obs.keys()}
#      14 #actions = {agent: env.action_space.sample() for agent in obs.keys()}
#      15 obs, reward, terminated, _, infos = env.step(actions)
# ---> 16 time.sleep(max(0, sleep_between_frames - (time.time() - last_frame)))
#      17 last_frame = time.time()
#      18 env.render()
#
# KeyboardInterrupt:
